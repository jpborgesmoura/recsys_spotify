# %%
from spotify_keys import *
import pandas as pd
import ast, base64, datetime, json, requests, sqlite3, time

# %% [markdown]
# # Primeiro contato com o dataset de Músicas / Captura da relação de Artistas

# %% [markdown]
# *   Este projeto utilizará o DataSet disponível [neste link do Kaggle](https://www.kaggle.com/datasets/rodolfofigueroa/spotify-12m-songs), onde há mais de 1 milhão de músicas relacionadas
# *   Veja abaixo um exemplo dos dados que temos em mãos

# %%
df_tracks = pd.read_csv('million_tracks_dataset.csv')

# %%
df_tracks.sample(n=5)
# Out:
#                              id  \
# 160013   6YL3vrIIiMK0GOjlVP8PUj
# 1121566  0Jjf0OPQT6qwdr35wTU5Pn
# 707401   4PI4uq7Lko0ih2N6oVBPDh
# 761438   3XsXvPYHEWPlj6W8dyqo27
# 690929   5nkSKdCxpEOnC1VQvCJZIn
#
#                                                       name  \
# 160013   15 Hungarian Peasant Songs, BB 79: No. 15. Old...
# 1121566                                 Voices From Heaven
# 707401                                   You Seem Familiar
# 761438                                  Handle Ya business
# 690929                           I Can See It In Your Eyes
#
#                                                      album  \
# 160013   Bartok: Mikrokosmos (Selection) / Hungarian Pe...
# 1121566                                 Voices From Heaven
# 707401                                                Lift
# 761438                                    The Cause CD/DVD
# 690929   Suitcase - Failed Experiments and Trashed Airc...
#
#                        album_id                             artists  \
# 160013   6f5SZrxGlwGPCDQWYlmwMA  ['Béla Bartók', 'Balazs Szokolay']
# 1121566  58n4PkR9fV7hQdLqxn5tAh                           ['Fancy']
# 707401   0dfuTkBZtoM7Q9YWc4lW8e                     ['Akia Uwanda']
# 761438   1I3QS0Qe1JoHMtpC7lLHiL                           ['Deebo']
# 690929   0nm4DlferXorPSQJJVG9V2                ['Guided By Voices']
#
#                                                 artist_ids  track_number  \
# 160013   ['5zyNXVd952fWOjkdGHCvPd', '6kJSScipaoehxfUqUT...            19
# 1121566                         ['0CZzh950BDSsosMF5Lft5K']             1
# 707401                          ['3NTFVOc9RlUt8MLKBDBb5G']             8
# 761438                          ['0Qs1n3ygTM2FKrkm51basT']             7
# 690929                          ['4oV5EVJ0XFWsJKoOvdRPvl']             9
#
#          disc_number  explicit  danceability  ...  speechiness  acousticness  \
# 160013             1     False         0.224  ...       0.0361        0.9890
# 1121566            1     False         0.681  ...       0.0356        0.0179
# 707401             1     False         0.714  ...       0.0421        0.1700
# 761438             1     False         0.917  ...       0.2040        0.0250
# 690929             2     False         0.356  ...       0.0370        0.6980
#
#          instrumentalness  liveness  valence    tempo  duration_ms  \
# 160013           0.845000    0.1010    0.193   85.192        82520
# 1121566          0.000007    0.3460    0.857  143.051       205947
# 707401           0.118000    0.1180    0.476  143.939       468393
# 761438           0.000025    0.0679    0.665   94.044       240680
# 690929           0.439000    0.2460    0.667  136.111       132747
#
#          time_signature  year  release_date
# 160013              4.0  1993    1993-04-20
# 1121566             4.0  2019    2019-12-06
# 707401              4.0  2017    2017-05-27
# 761438              4.0  2005    2005-10-20
# 690929              4.0  2000          2000
#
# [5 rows x 24 columns]

# %% [markdown]
# Antes de tudo, vamos coletar e separar em uma tabela à parte, o *id* de todos Artistas que contém músicas neste dataset, pois parte de nosso modelo preditivo será feito com base nos dados referentes a eles (seus gêneros e artistas relacionados)
#
#
# ---
#
#
# Em nosso dataset, apesar da coluna *id_artists* aparentar estar salva em formato de Lista, ela é, na verdade, uma String. Por conta disso, vamos trabalha-la da seguinte forma:

# %% [markdown]
# 1.   Retirar todos os caracteres que caracterizam uma Lista (mas que não a tornam uma), e manter apenas o conteúdo que nos interessa, isto é, o *id* dos respetivos artistas
# 2.   Listar os *ids* dos artistas de cada registro, separados pelo limitador (,) e, assim, criar uma lista de fato para cada faixa
# 3.   Utilizar o método *explode*, capaz de replicar o registro de cada faixa, replicando em registros diferentes uma mesma música, de acordo com 1 ou mais artistas que participam dela
# 4.   Assim, ao final conseguiremos coletar o *id* de todos os artistas, presentes em todas as faixas

# %%
for char in ["[", "]", "'", "\""]:
  df_tracks['artist_ids'] = df_tracks['artist_ids'].str.replace(char, "")

df_tracks['artist_ids'] = df_tracks['artist_ids'].str.split(", ")
id_artists = df_tracks.explode('artist_ids')['artist_ids']
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.

# %%
type(id_artists)
# Out:
# pandas.core.series.Series

# %% [markdown]
# *   Deleta eventuais *ids* repetidos, e salva o resultado final em um .csv

# %%
id_artists = id_artists.drop_duplicates()

# %%
id_artists.shape
# Out:
# (140449,)

# %%
id_artists.to_csv('id_artists.csv', index=False)

# %% [markdown]
# # Coletando dados de Artistas e seus Relacionados com a API do Spotify

# %% [markdown]
# *   Nesta etapa, vamos coletar, da API do Spotify, dados das nossas Faixas / Artistas que serão necessários à criação do modelo de recomendação, mas que não estão no dataset que temos em mãos
# *   Pra começar esta etapa, vamos criar uma função em que geramos o chamado *token*, capaz de autenticar a aplicação e permitir acesso à API

# %%
def get_token():

  # Codifica as chaves de acesso à API do Spotify em Base64

  auth = f"{CLIENT_ID}:{CLIENT_SECRET}"
  auth = auth.encode("ascii")
  auth = base64.b64encode(auth)
  auth = auth.decode("ascii")

  # Cria um request para autorização de acesso à API

  headers = { "Authorization" : "Basic " + auth }
  data = { "grant_type" : "client_credentials" }
  response = requests.post("https://accounts.spotify.com/api/token", headers=headers, data=data)

  # Retorna o token de acesso, ou lança um erro caso a resposta do request seja diferente de 'Sucesso' [200]

  if response.status_code == 200:
    rsp = response.json()
    return rsp['access_token']

  else:
      raise Exception(response.reason)

# %% [markdown]
# ## Dados de *Artists* (artistas)

# %% [markdown]
# ### Construindo o DataFrame de Artistas

# %% [markdown]
# 1.   Vamos aqui coletar os dados de mais de 100 mil Artistas da API do Spotify e salvar no arquivo **spotify_artists**!
# 2.   Temos de lidar, porém, com algumas restrições: para manter sua disponibilidade, a API possui formas de manter o controle das aplicações que se utilizam dela, e um desses controles é o [rate limit](https://developer.spotify.com/documentation/web-api/guides/rate-limits/), que impede que uma mesma aplicação faça excessivas requisições dentro de uma janela de 30 segundos.
# 3.   Assim, temos que construir nossa aplicação tendo em mente que não podemos fazer requests deliberadamente ao servidor.
# 4.   Para diminuir a quantidade de consultas a serem enviados ao Spotify, vamos utilizar de um recurso presente em alguns *endpoints* da API, onde podemos, com um único request, coletar os dados de até 50 ids (nesse caso, de Artistas) de uma só vez
# 5.   O método abaixo faz este trabalho, e, quando acontece de atingirmos o chamado *rate limit*, a aplicação fica em stand by por um tempo (estipulado pela própria API), e após esse intervalo, continua novamente a realizar seu trabalho

# %% [markdown]
# *OBS.: As próximas células construiram o arquivo .csv e a tabela
# 'spotify_artists'*

# %% [markdown]
# > Função que busca os Artistas na API

# %%
def get_Spotify_artists(artists_list, token):
  header = { "Authorization" : "Bearer " + token }
  endpoint_url = f"https://api.spotify.com/v1/artists?ids={artists_list}"

  response = requests.get(endpoint_url, headers=header)

  # Retorna com os dados do artista se o request obtiver sucesso
  if response.status_code == 200:
    for endpoint, result in response.json().items() : return result
    

  # Caso atingir a frequência limite de requests, aguarda-se o tempo necessário
  # Logo após, executa-se uma chamada recursiva da função, p/ continuar a coleta dos dados
  elif response.status_code == 429:
    wait = int(response.headers['Retry-After'])
    print(f'Busca pausada por {wait} segundo(s) ...')
    time.sleep(wait)
    token = get_token()
    print(f'Pesquisando ...')
    return get_Spotify_artists(artists_list, token)


  # Retorna com erro para os demais casos
  else : raise Exception(response.reason)

# %% [markdown]
# > Chamada da função criada acima, pra construção do DataFrame *spotify_artists*

# %%
token = get_token()
df_concat = list()
i = 0


print(f'Pesquisa de Artistas iniciada')
start = time.time()
    
for i in range(0, len(id_artists), 50):
  
  # Monta um conjunto de 50 ids de Artistas, para serem coletados no Spotify
  pack = id_artists.iloc[i:i+50]['artist_ids'].to_string(header=False, index=False).split('\n')
  ids = ','.join([str(id) for id in pack]) 

  # Executa a função que busca os dados na API e monta em um DataFrame
  df_concat.extend(get_Spotify_artists(ids, token))
  

end = time.time()
elapsed_time = str(datetime.timedelta( seconds = int(end-start) ))
print(f'\nBusca finalizada! Tempo decorrido: {elapsed_time}')

spotify_artists = pd.DataFrame.from_records(df_concat)
# Out:
# Pesquisa de Artistas iniciada
#
# Busca finalizada! Tempo decorrido: 0:04:29

# %% [markdown]
# > Veja abaixo uma amostra dos dados de Artistas que temos agora

# %%
spotify_artists
# Out:
#                                             external_urls  \
# 0       {'spotify': 'https://open.spotify.com/artist/2...
# 1       {'spotify': 'https://open.spotify.com/artist/7...
# 2       {'spotify': 'https://open.spotify.com/artist/2...
# 3       {'spotify': 'https://open.spotify.com/artist/4...
# 4       {'spotify': 'https://open.spotify.com/artist/1...
# ...                                                   ...
# 140444  {'spotify': 'https://open.spotify.com/artist/4...
# 140445  {'spotify': 'https://open.spotify.com/artist/5...
# 140446  {'spotify': 'https://open.spotify.com/artist/1...
# 140447  {'spotify': 'https://open.spotify.com/artist/0...
# 140448  {'spotify': 'https://open.spotify.com/artist/6...
#
#                                followers  \
# 0       {'href': None, 'total': 4902240}
# 1       {'href': None, 'total': 1818298}
# 2        {'href': None, 'total': 326189}
# 3         {'href': None, 'total': 48172}
# 4        {'href': None, 'total': 643572}
# ...                                  ...
# 140444       {'href': None, 'total': 12}
# 140445    {'href': None, 'total': 11220}
# 140446     {'href': None, 'total': 2876}
# 140447      {'href': None, 'total': 151}
# 140448       {'href': None, 'total': 20}
#
#                                                    genres  \
# 0       [alternative metal, alternative rock, consciou...
# 1       [album rock, classic rock, mellow gold, rock, ...
# 2                      [dance pop, europop, new wave pop]
# 3       [canadian singer-songwriter, classic canadian ...
# 4       [art pop, dark pop, ectofolk, lilith, melancho...
# ...                                                   ...
# 140444                                                 []
# 140445                 [musica jibara, puerto rican folk]
# 140446                                                 []
# 140447                                        [austindie]
# 140448                                                 []
#
#                                                      href  \
# 0       https://api.spotify.com/v1/artists/2d0hyoQ5ynD...
# 1       https://api.spotify.com/v1/artists/77tT1kLj6mC...
# 2       https://api.spotify.com/v1/artists/2U6gqwyl9F3...
# 3       https://api.spotify.com/v1/artists/4sh4MHP7lhr...
# 4       https://api.spotify.com/v1/artists/1KsASRNugxU...
# ...                                                   ...
# 140444  https://api.spotify.com/v1/artists/4CSqFTFO3P0...
# 140445  https://api.spotify.com/v1/artists/5TphiK6LsT4...
# 140446  https://api.spotify.com/v1/artists/1oj9F8x44ah...
# 140447  https://api.spotify.com/v1/artists/0UnmV3m91hx...
# 140448  https://api.spotify.com/v1/artists/6fUcX0Rh7Z1...
#
#                             id  \
# 0       2d0hyoQ5ynDBnkvAbJKORj
# 1       77tT1kLj6mCWtFNqiOmP9H
# 2       2U6gqwyl9F33YxawnFrZG7
# 3       4sh4MHP7lhrSUakxwZzwqz
# 4       1KsASRNugxU85T0u6zSg32
# ...                        ...
# 140444  4CSqFTFO3P0UEBSJ5Iti5H
# 140445  5TphiK6LsT4X5NOZxq3NJB
# 140446  1oj9F8x44ah5gxYecEj8ch
# 140447  0UnmV3m91hxEzspbZtoz5b
# 140448  6fUcX0Rh7Z17l8jAFQlY50
#
#                                                    images  \
# 0       [{'height': 673, 'url': 'https://i.scdn.co/ima...
# 1       [{'height': 640, 'url': 'https://i.scdn.co/ima...
# 2       [{'height': 640, 'url': 'https://i.scdn.co/ima...
# 3       [{'height': 640, 'url': 'https://i.scdn.co/ima...
# 4       [{'height': 640, 'url': 'https://i.scdn.co/ima...
# ...                                                   ...
# 140444  [{'height': 640, 'url': 'https://i.scdn.co/ima...
# 140445  [{'height': 640, 'url': 'https://i.scdn.co/ima...
# 140446  [{'height': 640, 'url': 'https://i.scdn.co/ima...
# 140447  [{'height': 640, 'url': 'https://i.scdn.co/ima...
# 140448                                                 []
#
#                                                 name  popularity    type  \
# 0                           Rage Against The Machine          69  artist
# 1                            Daryl Hall & John Oates          69  artist
# 2                                         Will Young          50  artist
# 3                                     Bruce Cockburn          43  artist
# 4                                          Tori Amos          54  artist
# ...                                              ...         ...     ...
# 140444                                  Barry Knight           3  artist
# 140445                               Trio Vegabajeño          38  artist
# 140446                                           NFL          21  artist
# 140447                                   Maneja Beto           0  artist
# 140448  Ali Dee Theodore for DeeTown Entertainment          19  artist
#
#                                           uri
# 0       spotify:artist:2d0hyoQ5ynDBnkvAbJKORj
# 1       spotify:artist:77tT1kLj6mCWtFNqiOmP9H
# 2       spotify:artist:2U6gqwyl9F33YxawnFrZG7
# 3       spotify:artist:4sh4MHP7lhrSUakxwZzwqz
# 4       spotify:artist:1KsASRNugxU85T0u6zSg32
# ...                                       ...
# 140444  spotify:artist:4CSqFTFO3P0UEBSJ5Iti5H
# 140445  spotify:artist:5TphiK6LsT4X5NOZxq3NJB
# 140446  spotify:artist:1oj9F8x44ah5gxYecEj8ch
# 140447  spotify:artist:0UnmV3m91hxEzspbZtoz5b
# 140448  spotify:artist:6fUcX0Rh7Z17l8jAFQlY50
#
# [140449 rows x 10 columns]

# %% [markdown]
# *   Com a busca de Artistas realizada, foi coletado, para cada um dos ids que tínhamos em mãos, todos os seus dados disponíveis no Spotify, e eles estão mostrados acima
# *   Em meio a todos esses dados, porém, existem aqueles que não serão necessários na construção do modelo de predição (como url, imagens, links)
# *   Nestes casos, vamos retirá-los da nossa base, pois eles não precisam ser salvos
# *   Além disso, em alguns itens da consulta ao Spotify, *numa mesma coluna* vem preenchidos alguns dados importantes (como o número de followers, isto é, seguidores), porém, junto consigo estão vários outros dados que não serão utilizados em nossa aplicação. Assim, faremos uma 'limpeza' nessas colunas também, capturando delas apenas os dados necessários, e descartando o restante

# %%
spotify_artists.columns
# Out:
# Index(['external_urls', 'followers', 'genres', 'href', 'id', 'images', 'name',
#        'popularity', 'type', 'uri'],
#       dtype='object')

# %%
spotify_artists = spotify_artists[['id', 'name', 'followers', 'popularity', 'genres']]

# %%
# O método abaixo é responsável por capturar, dentro da coluna especificada, apenas os dados que selecionamos como importantes p/ a aplicação

def capture(content, column):
  # Identifica o tipo de conteúdo em uma coluna (se é uma Lista, um Dicionário, ou uma String), pois possuirão tratamentos diferentes em cada caso

  if isinstance(content, list):
    itens = []
    # Caso seja uma lista, retorna um conjunto de todos os itens da informação selecionada
    for i in content : itens.append(i[column])
    return itens


  elif isinstance(content, dict):
    # Se for um Dicionário, retorna o valor da chave selecionada
    return content[column]
    

  elif isinstance(content, str):
    # Se for uma string, converte-a string em Dicionário, e, logo após, retorna o valor da chave selecionada
    return ast.literal_eval(content)[column]

# %%
wanted_informations = { 'followers' : 'total' }

# %%
for attribute, data in wanted_informations.items():
  spotify_artists[attribute] = spotify_artists[attribute].apply(lambda x : capture(x, data))
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %% [markdown]
# > Veja agora como ficou nosso conjunto de dados de Artistas

# %%
spotify_artists
# Out:
#                             id                                          name  \
# 0       2d0hyoQ5ynDBnkvAbJKORj                      Rage Against The Machine
# 1       77tT1kLj6mCWtFNqiOmP9H                       Daryl Hall & John Oates
# 2       2U6gqwyl9F33YxawnFrZG7                                    Will Young
# 3       4sh4MHP7lhrSUakxwZzwqz                                Bruce Cockburn
# 4       1KsASRNugxU85T0u6zSg32                                     Tori Amos
# ...                        ...                                           ...
# 140444  4CSqFTFO3P0UEBSJ5Iti5H                                  Barry Knight
# 140445  5TphiK6LsT4X5NOZxq3NJB                               Trio Vegabajeño
# 140446  1oj9F8x44ah5gxYecEj8ch                                           NFL
# 140447  0UnmV3m91hxEzspbZtoz5b                                   Maneja Beto
# 140448  6fUcX0Rh7Z17l8jAFQlY50  Ali Dee Theodore for DeeTown Entertainment
#
#         followers  popularity  \
# 0         4902240          69
# 1         1818298          69
# 2          326189          50
# 3           48172          43
# 4          643572          54
# ...           ...         ...
# 140444         12           3
# 140445      11220          38
# 140446       2876          21
# 140447        151           0
# 140448         20          19
#
#                                                    genres
# 0       [alternative metal, alternative rock, consciou...
# 1       [album rock, classic rock, mellow gold, rock, ...
# 2                      [dance pop, europop, new wave pop]
# 3       [canadian singer-songwriter, classic canadian ...
# 4       [art pop, dark pop, ectofolk, lilith, melancho...
# ...                                                   ...
# 140444                                                 []
# 140445                 [musica jibara, puerto rican folk]
# 140446                                                 []
# 140447                                        [austindie]
# 140448                                                 []
#
# [140449 rows x 5 columns]

# %% [markdown]
# *   Agora temos nossos dados de Artistas num formato razoável, isto é,
# conseguimos buscá-los no Spotify e fazer uma primeira limpeza retirando aquilo que, de antemão, já sabemos que não nos será útil e pode nos economizar gastos (de espaço e processamento)
# *   Então vamos salvar este resultado prévio que já temos, que será usado na construção do nosso modelo preditivo

# %%
spotify_artists.to_csv('spotify_artists_dataset.csv', index=False)

# %% [markdown]
# ### Vinculando os Artistas Relacionados

# %% [markdown]
# 1.   Um dos tipos mais conhecidos de Sistemas de Recomendação são os chamados [Filtragem Colaborativa Baseada em Itens](https://www.analyticsvidhya.com/blog/2021/05/item-based-collaborative-filtering-build-your-own-recommender-system/#:~:text=Conclusion,based%20on%20user%2Fitem%20similarity.)
# 2.   Neste tipo de RecSys, um usuário A1 recebe recomendações baseando-se em itens semelhantes àquilo que ele(a) já consumiu/curtiu e comparando com outros usuários, que tenham gosto parecido com aquilo que o A1 já mostrou no passado.
# 3.   Apesar de a API do Spotify oferecer suporte para buscar músicas curtidas *pelo usuário logado na aplicação (se houver um)*, atualmente, ela não fornece a mesma visão de toda uma comunidade, isto é: é possível implementar uma solução/app que busca as faixas curtidas pelo usuário logado na sessão, porém, não conseguimos comparar, diretamente, suas preferências com os demais usuários da plataforma.
# 4.   A API, porém, nos fornece uma informação próxima a essa: boa parte dos artistas de seu catálogo possuem o registro dos chamados '[Artistas Relacionados](https://developer.spotify.com/documentation/web-api/reference/#/operations/get-an-artists-related-artists)' (Related Artists), que indica, justamente, para cada Artista, quais outros cantores seus fãs também costumam ouvir .
# 5.   Usaremos, então, desta informação disponível para o desenvolvimento do nosso modelo de predição, e o método abaixo faz essa busca.
#
# ---
#
# 6.   Diferente, porém, do que aconteceu anteriormente, para a busca de Artistas Relacionados, não conseguimos fazer um request único que coleta um conjunto de 50 ids, mas sim, esta consulta deverá ser feita artista por artista
# 7.   Implantaremos a mesma sistemática anterior que contorna o problema de rate limit, porém, agora, *executaremos a coleta de forma gradativa*, para que nosso request não atinja o limite de "Gateway Timeout" (pois seriam mais de 100.000 requests feitos ao mesmo tempo, caso tentassemos buscar tudo de uma única vez)
# 8.   Para isso, pegaremos grupos de 5.000 artistas (controlados pelas variáveis *start_point* e *artists_pack* abaixo), e iremos popular nosso conjunto de dados de Artistas Relacionados aos poucos.

# %% [markdown]
# *OBS.: As próximas células construiram o arquivo .csv e a tabela
# 'related_artists'*

# %%
# Vincula o dataset de Artistas (salvo anteriormente) na variável 'spotify_artists' se ela não estiver carregada na sessão do notebook
spotify_artists = pd.read_csv('spotify_artists_dataset.csv')

# %% [markdown]
# > Função que busca os Artistas Relacionados na API

# %%
def get_Spotify_related_artists(artist_id, token):
  header = { "Authorization" : "Bearer " + token }
  endpoint_url = f"https://api.spotify.com/v1/artists/{artist_id}/related-artists"

  response = requests.get(endpoint_url, headers=header)
  
  # Retorna com os dados do artista se o request obtiver sucesso
  if response.status_code == 200:
    for endpoint, result in response.json().items():
      result.insert(0, artist_id)
      return result

    
  # Caso atingir a frequência limite de requests, aguarda-se o tempo necessário
  # Logo após, executa-se uma chamada recursiva da função, p/ continuar a coleta dos dados
  if response.status_code == 429:
    wait = int(response.headers['Retry-After'])
    print(f'Busca pausada por {wait} segundo(s) ...')
    time.sleep(wait)
    token = get_token()
    print(f'Pesquisando ...')
    return get_Spotify_related_artists(artist_id, token)


  # Retorna com erro nos demais casos
  else : raise Exception(response.reason)

# %%
new_related_artists = pd.DataFrame()
related_artists_dataset = pd.read_csv('related_artists_dataset.csv', converters={ 'related_ids': eval , 'related_names': eval , 'related_genres': eval })

# %% [markdown]
# > Chamada da função criada acima, pra *construção gradativa* do DataFrame 'related_artists'

# %% [markdown]
# **ATENÇÃO:  Controle a execução de consulta aos Artistas Relacionados através da variável '*start_point*' abaixo, colocando o nº do index a partir do qual deve prosseguir a busca**

# %%
start_point = 140000
artists_pack = id_artists.iloc[start_point : start_point + 5000]

# %%
token = get_token()
pack_data = list()

# Aqui nosso DataFrame de Artistas Relacionados será populado com um conjunto de 5.000 artistas buscados da API (essa quantidade depende da variável 'artists_pack' acima)
print(f'Pesquisa de Artistas Relacionados iniciada')
start = time.time()

pack_data.extend(artists_pack['artist_ids'].apply(lambda x : get_Spotify_related_artists(x, token)))

end = time.time()
elapsed_time = str(datetime.timedelta( seconds = int(end-start) ))
print(f'\nBusca finalizada! Tempo decorrido: {elapsed_time}')

new_related_artists = new_related_artists.append(pd.DataFrame.from_records(pack_data), ignore_index = True)
# Out:
# Pesquisa de Artistas Relacionados iniciada
# Busca pausada por 1 segundo(s) ...
# Pesquisando ...
# Busca pausada por 1 segundo(s) ...
# Pesquisando ...
# Busca pausada por 1 segundo(s) ...
# Pesquisando ...
# Busca pausada por 1 segundo(s) ...
# Pesquisando ...
#
# Busca finalizada! Tempo decorrido: 0:00:36

# %% [markdown]
# > Observe abaixo como vieram os dados que buscamos da API

# %%
new_related_artists
# Out:
#                          0   \
# 0    6rB1jv0emRIkbLluXskjt9
# 1    5tg5JDw7tQiZdJCShs9rk9
# 2    5kNXUEveFE9nWmio1YoFek
# 3    2i6trCPrjCF625qTXCK0L2
# 4    1zcTB8gtjbKxJmluk0amve
# ..                      ...
# 444  4CSqFTFO3P0UEBSJ5Iti5H
# 445  5TphiK6LsT4X5NOZxq3NJB
# 446  1oj9F8x44ah5gxYecEj8ch
# 447  0UnmV3m91hxEzspbZtoz5b
# 448  6fUcX0Rh7Z17l8jAFQlY50
#
#                                                     1   \
# 0                                                 None
# 1    {'external_urls': {'spotify': 'https://open.sp...
# 2    {'external_urls': {'spotify': 'https://open.sp...
# 3                                                 None
# 4    {'external_urls': {'spotify': 'https://open.sp...
# ..                                                 ...
# 444                                               None
# 445  {'external_urls': {'spotify': 'https://open.sp...
# 446                                               None
# 447  {'external_urls': {'spotify': 'https://open.sp...
# 448                                               None
#
#                                                     2   \
# 0                                                 None
# 1    {'external_urls': {'spotify': 'https://open.sp...
# 2                                                 None
# 3                                                 None
# 4    {'external_urls': {'spotify': 'https://open.sp...
# ..                                                 ...
# 444                                               None
# 445  {'external_urls': {'spotify': 'https://open.sp...
# 446                                               None
# 447  {'external_urls': {'spotify': 'https://open.sp...
# 448                                               None
#
#                                                     3   \
# 0                                                 None
# 1    {'external_urls': {'spotify': 'https://open.sp...
# 2                                                 None
# 3                                                 None
# 4    {'external_urls': {'spotify': 'https://open.sp...
# ..                                                 ...
# 444                                               None
# 445  {'external_urls': {'spotify': 'https://open.sp...
# 446                                               None
# 447  {'external_urls': {'spotify': 'https://open.sp...
# 448                                               None
#
#                                                     4   \
# 0                                                 None
# 1    {'external_urls': {'spotify': 'https://open.sp...
# 2                                                 None
# 3                                                 None
# 4    {'external_urls': {'spotify': 'https://open.sp...
# ..                                                 ...
# 444                                               None
# 445  {'external_urls': {'spotify': 'https://open.sp...
# 446                                               None
# 447  {'external_urls': {'spotify': 'https://open.sp...
# 448                                               None
#
#                                                     5   \
# 0                                                 None
# 1    {'external_urls': {'spotify': 'https://open.sp...
# 2                                                 None
# 3                                                 None
# 4    {'external_urls': {'spotify': 'https://open.sp...
# ..                                                 ...
# 444                                               None
# 445  {'external_urls': {'spotify': 'https://open.sp...
# 446                                               None
# 447  {'external_urls': {'spotify': 'https://open.sp...
# 448                                               None
#
#                                                     6   \
# 0                                                 None
# 1    {'external_urls': {'spotify': 'https://open.sp...
# 2                                                 None
# 3                                                 None
# 4    {'external_urls': {'spotify': 'https://open.sp...
# ..                                                 ...
# 444                                               None
# 445  {'external_urls': {'spotify': 'https://open.sp...
# 446                                               None
# 447  {'external_urls': {'spotify': 'https://open.sp...
# 448                                               None
#
#                                                     7   \
# 0                                                 None
# 1    {'external_urls': {'spotify': 'https://open.sp...
# 2                                                 None
# 3                                                 None
# 4    {'external_urls': {'spotify': 'https://open.sp...
# ..                                                 ...
# 444                                               None
# 445  {'external_urls': {'spotify': 'https://open.sp...
# 446                                               None
# 447  {'external_urls': {'spotify': 'https://open.sp...
# 448                                               None
#
#                                                     8   \
# 0                                                 None
# 1    {'external_urls': {'spotify': 'https://open.sp...
# 2                                                 None
# 3                                                 None
# 4    {'external_urls': {'spotify': 'https://open.sp...
# ..                                                 ...
# 444                                               None
# 445  {'external_urls': {'spotify': 'https://open.sp...
# 446                                               None
# 447  {'external_urls': {'spotify': 'https://open.sp...
# 448                                               None
#
#                                                     9   ...  \
# 0                                                 None  ...
# 1    {'external_urls': {'spotify': 'https://open.sp...  ...
# 2                                                 None  ...
# 3                                                 None  ...
# 4    {'external_urls': {'spotify': 'https://open.sp...  ...
# ..                                                 ...  ...
# 444                                               None  ...
# 445  {'external_urls': {'spotify': 'https://open.sp...  ...
# 446                                               None  ...
# 447  {'external_urls': {'spotify': 'https://open.sp...  ...
# 448                                               None  ...
#
#                                                     11  \
# 0                                                 None
# 1    {'external_urls': {'spotify': 'https://open.sp...
# 2                                                 None
# 3                                                 None
# 4    {'external_urls': {'spotify': 'https://open.sp...
# ..                                                 ...
# 444                                               None
# 445  {'external_urls': {'spotify': 'https://open.sp...
# 446                                               None
# 447  {'external_urls': {'spotify': 'https://open.sp...
# 448                                               None
#
#                                                     12  \
# 0                                                 None
# 1    {'external_urls': {'spotify': 'https://open.sp...
# 2                                                 None
# 3                                                 None
# 4    {'external_urls': {'spotify': 'https://open.sp...
# ..                                                 ...
# 444                                               None
# 445  {'external_urls': {'spotify': 'https://open.sp...
# 446                                               None
# 447  {'external_urls': {'spotify': 'https://open.sp...
# 448                                               None
#
#                                                     13  \
# 0                                                 None
# 1    {'external_urls': {'spotify': 'https://open.sp...
# 2                                                 None
# 3                                                 None
# 4    {'external_urls': {'spotify': 'https://open.sp...
# ..                                                 ...
# 444                                               None
# 445  {'external_urls': {'spotify': 'https://open.sp...
# 446                                               None
# 447  {'external_urls': {'spotify': 'https://open.sp...
# 448                                               None
#
#                                                     14  \
# 0                                                 None
# 1    {'external_urls': {'spotify': 'https://open.sp...
# 2                                                 None
# 3                                                 None
# 4    {'external_urls': {'spotify': 'https://open.sp...
# ..                                                 ...
# 444                                               None
# 445  {'external_urls': {'spotify': 'https://open.sp...
# 446                                               None
# 447  {'external_urls': {'spotify': 'https://open.sp...
# 448                                               None
#
#                                                     15  \
# 0                                                 None
# 1    {'external_urls': {'spotify': 'https://open.sp...
# 2                                                 None
# 3                                                 None
# 4    {'external_urls': {'spotify': 'https://open.sp...
# ..                                                 ...
# 444                                               None
# 445  {'external_urls': {'spotify': 'https://open.sp...
# 446                                               None
# 447  {'external_urls': {'spotify': 'https://open.sp...
# 448                                               None
#
#                                                     16  \
# 0                                                 None
# 1    {'external_urls': {'spotify': 'https://open.sp...
# 2                                                 None
# 3                                                 None
# 4    {'external_urls': {'spotify': 'https://open.sp...
# ..                                                 ...
# 444                                               None
# 445  {'external_urls': {'spotify': 'https://open.sp...
# 446                                               None
# 447  {'external_urls': {'spotify': 'https://open.sp...
# 448                                               None
#
#                                                     17  \
# 0                                                 None
# 1    {'external_urls': {'spotify': 'https://open.sp...
# 2                                                 None
# 3                                                 None
# 4    {'external_urls': {'spotify': 'https://open.sp...
# ..                                                 ...
# 444                                               None
# 445  {'external_urls': {'spotify': 'https://open.sp...
# 446                                               None
# 447  {'external_urls': {'spotify': 'https://open.sp...
# 448                                               None
#
#                                                     18  \
# 0                                                 None
# 1    {'external_urls': {'spotify': 'https://open.sp...
# 2                                                 None
# 3                                                 None
# 4    {'external_urls': {'spotify': 'https://open.sp...
# ..                                                 ...
# 444                                               None
# 445  {'external_urls': {'spotify': 'https://open.sp...
# 446                                               None
# 447  {'external_urls': {'spotify': 'https://open.sp...
# 448                                               None
#
#                                                     19  \
# 0                                                 None
# 1    {'external_urls': {'spotify': 'https://open.sp...
# 2                                                 None
# 3                                                 None
# 4    {'external_urls': {'spotify': 'https://open.sp...
# ..                                                 ...
# 444                                               None
# 445  {'external_urls': {'spotify': 'https://open.sp...
# 446                                               None
# 447  {'external_urls': {'spotify': 'https://open.sp...
# 448                                               None
#
#                                                     20
# 0                                                 None
# 1    {'external_urls': {'spotify': 'https://open.sp...
# 2                                                 None
# 3                                                 None
# 4    {'external_urls': {'spotify': 'https://open.sp...
# ..                                                 ...
# 444                                               None
# 445  {'external_urls': {'spotify': 'https://open.sp...
# 446                                               None
# 447  {'external_urls': {'spotify': 'https://open.sp...
# 448                                               None
#
# [449 rows x 21 columns]

# %% [markdown]
# Precisaremos ajustar este DataFrame de Artistas Relacionados para nossas necessidades antes de salvá-lo em um .csv, e, pra isso, vamos fazê-lo conforme abaixo
#
#
#
# ---
#
#
# *   Ajustaremos o nome da coluna de artista 'principal'
# *   Agregaremos todos os artistas relacionados numa única coluna
# *   Selecionaremos, ao final, somente as colunas necessárias, descartando o restante

# %%
# Este método une todos os artistas relacionados de um determinado id numa lista única, que será salva em uma coluna à parte

def aggregate_related(artist):
  related = list()
  for i in range(1, 21):
     if pd.notna(artist[i]) : related.append(artist[i])

  return related

# %%
new_related_artists.rename(columns = {0 : 'id'}, inplace = True)
new_related_artists['related'] = new_related_artists.apply(aggregate_related, axis = 1)
new_related_artists = new_related_artists[['id', 'related']]

# %%
new_related_artists
# Out:
#                          id                                            related
# 0    6rB1jv0emRIkbLluXskjt9                                                 []
# 1    5tg5JDw7tQiZdJCShs9rk9  [{'external_urls': {'spotify': 'https://open.s...
# 2    5kNXUEveFE9nWmio1YoFek  [{'external_urls': {'spotify': 'https://open.s...
# 3    2i6trCPrjCF625qTXCK0L2                                                 []
# 4    1zcTB8gtjbKxJmluk0amve  [{'external_urls': {'spotify': 'https://open.s...
# ..                      ...                                                ...
# 444  4CSqFTFO3P0UEBSJ5Iti5H                                                 []
# 445  5TphiK6LsT4X5NOZxq3NJB  [{'external_urls': {'spotify': 'https://open.s...
# 446  1oj9F8x44ah5gxYecEj8ch                                                 []
# 447  0UnmV3m91hxEzspbZtoz5b  [{'external_urls': {'spotify': 'https://open.s...
# 448  6fUcX0Rh7Z17l8jAFQlY50                                                 []
#
# [449 rows x 2 columns]

# %% [markdown]
# *   Vamos agora replicar a coluna dos Artistas Relacionados, para que possamos dividir, em colunas distintas, os seus dados de id, nome e gênero, e assim facilitar sua manipulação

# %%
for attribute in ['related_ids', 'related_names', 'related_genres'] : new_related_artists[attribute] = new_related_artists['related']

# %% [markdown]
# *   Da mesma forma que foi feito no DataFrame de Artistas, vamos limpar os dados advindos da consulta, retirando colunas e extraindo algumas informações que são desnecessários ao modelo, e que não precisam ser salvos e consumir espaço em memória

# %%
new_related_artists.columns
# Out:
# Index(['id', 'related', 'related_ids', 'related_names', 'related_genres'], dtype='object')

# %%
new_related_artists = new_related_artists[['id', 'related_ids', 'related_names', 'related_genres']]

# %%
wanted_informations = { 'related_ids' : 'id', 'related_names' : 'name', 'related_genres' : 'genres' }

# %%
for attribute, data in wanted_informations.items():
  new_related_artists[attribute] = new_related_artists[attribute].apply(lambda x : capture(x, data))
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %% [markdown]
# *   Agora vamos juntar todos os gêneros, de todos os artistas relacionados, numa lista única
# *   Além disso, com a integração de diversos artistas relacionados, alguns gêneros irão naturalmente se repetir. Como essa repetição é desnecessária, vamos excluir os gêneros relacionados que estejam repetidos para um mesmo artista

# %%
def clean_related(genres):
  related = [item for conjunct in genres for item in conjunct]
  related = list(dict.fromkeys(related))

  return related

# %%
new_related_artists['related_genres'] = new_related_artists['related_genres'].apply(clean_related)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
new_related_artists
# Out:
#                          id  \
# 0    6rB1jv0emRIkbLluXskjt9
# 1    5tg5JDw7tQiZdJCShs9rk9
# 2    5kNXUEveFE9nWmio1YoFek
# 3    2i6trCPrjCF625qTXCK0L2
# 4    1zcTB8gtjbKxJmluk0amve
# ..                      ...
# 444  4CSqFTFO3P0UEBSJ5Iti5H
# 445  5TphiK6LsT4X5NOZxq3NJB
# 446  1oj9F8x44ah5gxYecEj8ch
# 447  0UnmV3m91hxEzspbZtoz5b
# 448  6fUcX0Rh7Z17l8jAFQlY50
#
#                                            related_ids  \
# 0                                                   []
# 1    [4y5IK8VBswkl40ltpHI5o9, 6wrQP6EAQRd8GLl9tilJd...
# 2                             [0bDFIu2L4jBTpJ1Z6v6Bsu]
# 3                                                   []
# 4    [5HQ8niC4OrnYWqZFvgaiR2, 7Dqkr5jq8RjsIUP5hlnwc...
# ..                                                 ...
# 444                                                 []
# 445  [1ekMcZuh9gTNEUw6q6M8WO, 2YWu923Xc47UsMvUKK5Fg...
# 446                                                 []
# 447  [2rQpzaWZ5jaOEBfXfYqKZ9, 35dJmO7Fn6SDDbO39YA8S...
# 448                                                 []
#
#                                          related_names  \
# 0                                                   []
# 1    [Almighty Suspect, Conradfrmdaaves, Peso Da Go...
# 2                                      [Tyburn Saints]
# 3                                                   []
# 4    [Mattic, Lex (de Kalhex), Pete Flux, Alcynoos,...
# ..                                                 ...
# 444                                                 []
# 445  [Cuarteto Mayari, Felipe Rodriguez, Las Tres G...
# 446                                                 []
# 447  [Seaflea, Fivehead, Pretty Please, The Addicti...
# 448                                                 []
#
#                                         related_genres
# 0                                                   []
# 1    [cali rap, west coast trap, pop rap, detroit t...
# 2                                                   []
# 3                                                   []
# 4    [jazz boom bap, chillhop, lo-fi jazzhop, focus...
# ..                                                 ...
# 444                                                 []
# 445  [puerto rican folk, musica jibara, bolero, cla...
# 446                                                 []
# 447  [austindie, rochester ny indie, atlanta punk, ...
# 448                                                 []
#
# [449 rows x 4 columns]

# %% [markdown]
# *   Por fim, com esta relação 'limpa', vamos agregá-la no dataset de Artistas Relacionados, salvando-a e integrando-a sempre que finalizar uma etapa da coleta

# %%
related_artists = related_artists_dataset.append(new_related_artists)

# %% [markdown]
# > Veja agora como ficou nosso conjunto de dados de Artistas Relacionados

# %%
related_artists
# Out:
#                             id  \
# 0       2d0hyoQ5ynDBnkvAbJKORj
# 1       77tT1kLj6mCWtFNqiOmP9H
# 2       2U6gqwyl9F33YxawnFrZG7
# 3       4sh4MHP7lhrSUakxwZzwqz
# 4       1KsASRNugxU85T0u6zSg32
# ...                        ...
# 140444  4CSqFTFO3P0UEBSJ5Iti5H
# 140445  5TphiK6LsT4X5NOZxq3NJB
# 140446  1oj9F8x44ah5gxYecEj8ch
# 140447  0UnmV3m91hxEzspbZtoz5b
# 140448  6fUcX0Rh7Z17l8jAFQlY50
#
#                                               related_ids  \
# 0       [2ziB7fzrXBoh1HUPS6sVFn, 6GbCJZrI318Ybm8mY36Of...
# 1       [3Y3xIwWyq5wnNHPp5gPjOW, 7A9yZMTrFZcgEWAX2kBfK...
# 2       [1XgFuvRd7r5g0h844A5ZUQ, 17UkABEasVRlCcIFZ3wHb...
# 3       [4PM86aECDhcdwuJNZNrR22, 5R6GD31ZP8YPGIlt73Mad...
# 4       [3X0tJzVYoWlfjLYI0Ridsw, 76oeXwztPqAxVg9oqozK3...
# ...                                                   ...
# 140444                                                 []
# 140445  [1ekMcZuh9gTNEUw6q6M8WO, 2YWu923Xc47UsMvUKK5Fg...
# 140446                                                 []
# 140447  [2rQpzaWZ5jaOEBfXfYqKZ9, 35dJmO7Fn6SDDbO39YA8S...
# 140448                                                 []
#
#                                             related_names  \
# 0       [Audioslave, Faith No More, Prophets Of Rage, ...
# 1       [Kenny Loggins, Huey Lewis & The News, Christo...
# 2       [Take That, Steps, Gary Barlow, Daniel Bedingf...
# 3       [Chris Smither, Robbie Robertson, Greg Brown, ...
# 4       [Suzanne Vega, Heather Nova, Aimee Mann, Natal...
# ...                                                   ...
# 140444                                                 []
# 140445  [Cuarteto Mayari, Felipe Rodriguez, Las Tres G...
# 140446                                                 []
# 140447  [Seaflea, Fivehead, Pretty Please, The Addicti...
# 140448                                                 []
#
#                                            related_genres
# 0       [alternative metal, alternative rock, nu metal...
# 1       [album rock, classic rock, mellow gold, new wa...
# 2       [boy band, dance pop, europop, bubblegum dance...
# 3       [acoustic blues, alternative country, country ...
# 4       [lilith, new wave pop, permanent wave, pop roc...
# ...                                                   ...
# 140444                                                 []
# 140445  [puerto rican folk, musica jibara, bolero, cla...
# 140446                                                 []
# 140447  [austindie, rochester ny indie, atlanta punk, ...
# 140448                                                 []
#
# [140449 rows x 4 columns]

# %%
related_artists.duplicated(subset=['id']).sum()
# Out:
# 0

# %%
related_artists.to_csv('new_related_artists_dataset.csv', index=False)

# %% [markdown]
# #### **IMPORTANTE**: o arquivo salvo aqui como '*new related artists dataset*' será reutilizado neste mesmo notebook como '*related artists dataset*' posteriormente (já que ele tem salvo todos os artistas relacionados pesquisados até o momento), a fim de continuar a coleta, até que ela seja finalizada

# %% [markdown]
# ## Dados de *Tracks* (faixas)

# %% [markdown]
# *   Veja abaixo uma pequena amostra das Faixas que temos em nosso dataset
# *   Perçeba que existem vários dados, chamados de **audio features**, que representam as músicas... vamos usar estes dados p/ calcular a semelhança entre elas (danceability, acousticness, energy, ...)

# %%
df_tracks.sample(n=5)
# Out:
#                              id                name  \
# 128816   1SkuilXmIIHTSHXCUHzGUf             Freedom
# 511393   7K2kssj1VQjrshWPdNrqQt    Intaglio Waltzes
# 336053   5EPcaxU4jQsjPAQ1AS0yG1  Intergalactic Talk
# 827330   6W3DPXpKDEVSRJWYqLsQov       In The Garden
# 1114764  34oRLdKVxdLKu0wniTmHmI       Gonna Find Me
#
#                                                      album  \
# 128816                                   The Sails of Self
# 511393   John PhilipSousa.: Music For Wind Band, Vol. 7...
# 336053                             The Next Mission, Pt. 2
# 827330                                   After The Sunrise
# 1114764                                Flies Like The Wind
#
#                        album_id  \
# 128816   0aoaTPqX1fdh7YaJQgcvyD
# 511393   7sbRE2beqTVr2cEdF1lQxw
# 336053   3gMRi9b9HeWryG5m9ghFKt
# 827330   22lywHrCVm37xy5MsTOOjX
# 1114764  0o0G0dxXnlwbWv5wtFqH5l
#
#                                                artists  \
# 128816                           ['Rising Appalachia']
# 511393   ['Royal Artillery Band', 'John Philip Sousa']
# 336053                               ['Tor.Ma In DuB']
# 827330                                ['Bill Harrell']
# 1114764                                 ['Dom Bianco']
#
#                                                 artist_ids  track_number  \
# 128816                          ['3I6e2ZqqoxQhXc9z7Tp5ci']             2
# 511393   ['3IzZdcF86S2YxqKkdbVvQG', '6jNyNAMv2gNLnfaP0b...             6
# 336053                          ['6hJVyOMMo1A3XN8yz8neiy']             2
# 827330                          ['5pJsZK3VaSayBIVHuyAQHQ']            10
# 1114764                         ['4YPs5J2NVL5zhyfTEjEGpN']             6
#
#          disc_number  explicit  danceability  ...  speechiness  acousticness  \
# 128816             1     False         0.595  ...       0.0637        0.9330
# 511393             1     False         0.149  ...       0.0359        0.9630
# 336053             1     False         0.502  ...       0.0401        0.0051
# 827330             1     False         0.451  ...       0.0409        0.9290
# 1114764            1     False         0.613  ...       0.0265        0.2660
#
#          instrumentalness  liveness  valence    tempo  duration_ms  \
# 128816              0.000    0.3170    0.446   93.857       139760
# 511393              0.430    0.0563    0.185   75.634       524107
# 336053              0.847    0.2230    0.410  157.978       419491
# 827330              0.000    0.0928    0.280  125.620       150760
# 1114764             0.907    0.0668    0.646  100.094       198973
#
#          time_signature  year  release_date
# 128816              4.0  2010    2010-04-23
# 511393              3.0  2008    2008-12-16
# 336053              3.0  2012    2012-08-20
# 827330              4.0  2011    2011-10-30
# 1114764             4.0  2005    2005-06-14
#
# [5 rows x 24 columns]

# %% [markdown]
# *   Além destes dados, que nós já temos em nosso dataset, o Spotify disponibiliza também, a chamada **audio analysis** que, assim como os *audio features*, 'traduzem' a estrutura das músicas em números
# *   Da mesma forma que acontece com os artistas relacionados, a API disponibiliza a consulta de *audio analysis* de cada faixa individualmente
# *   Veja abaixo o exemplo de *audio analysis* de uma única faixa

# %%
header = { "Authorization" : "Bearer " + get_token() }

id = '6JZLVLOYVHEOwqZK0ezTdf'
url = f"https://api.spotify.com/v1/audio-analysis/{id}"

response = requests.get(url, headers=header)

# Retorna com os dados do artista se o request obtiver sucesso
if response.status_code == 200:
  for endpoint, result in response.json().items() : print (result)
# Out:
# {'analyzer_version': '4.0.0', 'platform': 'Linux', 'detailed_status': 'OK', 'status_code': 0, 'timestamp': 1584953651, 'analysis_time': 11.09301, 'input_process': 'libvorbisfile L+R 44100->22050'}
# {'num_samples': 7299300, 'duration': 331.034, 'sample_md5': '', 'offset_seconds': 0, 'window_seconds': 0, 'analysis_sample_rate': 22050, 'analysis_channels': 1, 'end_of_fade_in': 0.0, 'start_of_fade_out': 318.87964, 'loudness': -10.641, 'tempo': 87.012, 'tempo_confidence': 0.667, 'time_signature': 4, 'time_signature_confidence': 0.658, 'key': 7, 'key_confidence': 0.899, 'mode': 0, 'mode_confidence': 0.797, 'codestring': 'eJxVnAmW5aquRKeSQwDRz39iFTuEj13vr3V_meMGhBQKNeRafRb93_krfzHWHGus-tei_O3ovUUb_a_Wrf-suiLOWX91nvnXS-woe4eemoVfW60x118rS2PtRI8Z_a-dNv_WGvpZD__13rcu_c0Rf0Ojf6F_xV767NA3mUUtdbT9N-fef22d3cbY629FC132VfXJ8bfL1KxK36fX0zTfWTbXZ5bSxtK1JjLKGbs3zfB05jVWO3txebQmTaSW0kfTc3xL_50zauN6a6J1xxiz7flXIzS12fR7O-X8Vb1SL5GItPKjO9se80_zbFF70-9d0tB1l0Tnrn91dL1_aS5aFPfP7dnr_-tTDfGuYAJ1lSmhNL7dtajSEIWWW4_Wpus4XUvUF86s8y_OkgyZcUgS5W_NuY5-0XUtiH_WPvaRbKNupNlLOXVWXfOArmuV9LTdWqAEdJaEM47WEjHCW6UprM39S3fxPn1Cb5IurPl7n64b2yMp1rP4JVrP77cdUa0Smr_esaKjGNGr3q-57lGLnozOLPqoW7OTHuku7aeuW-wzND9NROvT27Uh2pEYRbMcqI6E-sdsi3VCSrk0nTH0OT0-pXtMdyDfIdGt0rWa4f3X0pd2QLOZVXPW7Aq6pdnMyX4uvaQvlFwLK3q8j-X9jsVuaHVaxpGyxULHUhpNeh5LM_tKYy2k9Upjs-Y6u35uXd-XpvF72dZuXQ_0x--T_HWtD-Tu9MP89tFy9L45-27oQUdbVmg5nd08U-8fUY7EKDnGYfeR5pldetMK-pnSlUx03fQW9FG7IYvSAGYdVbpQpFS63pUbtOvSNpl55bV66ynS3PGHzmrCsbS_m_srCn-mtGmd0nSthcksxuq-jHrib8t86pLEdN20HxIH61p6fWgjLS8BRtHrteBH27rk2zSf_ZFvayDJK9_WZHa6v0uQmzc1jF6_lz7vTtXnfYIx_eun_Zavnpz9I9_WJeCrvUd62CS5-dHeNoR4H-3V5_tXe5tngfpJ_5hoOShFGXtKXLpG-Qf7P8dmolI1HgdGfL_2VfBY2Keh5S-Mm-3SalD_tkLr4fsbRNQ1IC2o231Jusu2Pwvmc_R6qXzP1UuMuluTK19p7qHVoPxFVqsnD6C-K3DWkOuJlM4oU-qh68H0j748JspwVr6lg204AQnK0u1HIpTzMFYJafWezjW7LWUT-g7NpBe0W9fApJBfUkDnfS1voWutj9WWs7av0XZ0RxM87Q-bBPuXtl9C_uvGMpm45B3CVm22fl9zCfyk8H-92Zql2lJ-aUdv7GabQjBJXu83VqE92h3tphzj7nkdi_nbrQ20taBngome6DC2FOCvJ3bJUQnF-P6I7vd1eY3BSnBOiQZ6Vtegk4QmLUevu9HJ2iXvoO_NfOrRrj73T9u6XGFf6SvkC8aUMUsHEmtPG1qgrkEnqdNGEfU-o5EQ88hMdbvBqOuya4YSz2Y5EucZ2gj9YjCqYKPgj_sPHhVvehYTMRhJFvpebVqOwahKqZocrKZnMBJyS2sBq2EwWvJrR9p2dN0SXDvozEayfaleYgK6tgMRNK2DWx41IU4DQpWlaztbgB93-IfaWL2W5nz4ck1s07j4gK7ZzhNSH9mSaEgYbHGbHXEPg03V-gUtK-20WD5aELSlnVSHik-auInZH2dQMXvUzeATGM4weBis5VkR_Ex1kPF0O7XdH2cCao5EB3ExLYCdmDgHmWuTM-J-o4HMqYh6jKFrwCDBCfMT5q4vOA2DQ4J9ZQOH8UGy1R0NnAEeql4idBe1kM6bMU15xaKZj40vGEKKyoj-BTzoWjsqBdO_4r5_DrkVCfhY33Dd0iyuF_AmK457DUuc0qAi-jP-ZmFb9W12XnglUO7ghxBIe1Z1DbeTALbWvLkf7yBep-9P3mS80Hw1QyRlKUhfBCtx9Hg1eZOWSRCS14RrCe7k7sUSz980NQrI3gBOpuECc1wyRwGJ1FOT0prkwLru1_ZYn2S2pejzpj4XvpI2dmutZi1HpWvgUddS4CL4EvhZXliA8ErX-9GvgKqx3aZ2R5YlbjPNbRKu8CaAEgzoiCgWwdU0XNjHNL1F1-JWV99W4_cRX32bJjevvk2TGd4nd3O4Zvvk_HS76IMED_W2fgkx9D7jxZB3O3DfaXgY4p2i8bgVwDypVvc2E068VEurkvXuAjgLcXR9qYu0bBMFHFY3JfkGQv4to8Uwj8aOl9GC38W1CRPKBUdNaOO0zVxkUyFfJOqha61WXltGo6fglKYyonlriwrruidT1t5LUXVt6iKwbFZ_lqL_SjMZseHhLXbFFQvdVzzeQXLh-YDJJnyFtnMZXl74WnCtFO_AOy5zl14kwQ68LHMXSVffYf6dwGBKkSR7yWcZbdA-aQiS7lirCIQ-doi2pDLmEkMkVsYjhN6ELqg6nHkllTHaSV1ZmEOTB-3WAD1ftNNk5hft1nypKmgnyIbO_7RnGY3ktvEPjv5AH7RT6nuGrk882lcg4SYjL9oto8-LdstoA8HVTkvbl9FG2ijlwtqWyUg6y8V6DDYftFtmIz-02wabF-22weVFO3lJMPuHdhtKRmApgSo43uYikrbkJKq1TUWGeN4xSmxji6Guou3b2CK_oqXg60QHClCnNfA_XWObmojMAd-0jT1SpS0iq0B1O-yC8Ehawo5t7JlFzAJ3r-sbdum-EHbJw7PH4vsCheD-Y2vZwnz-tY09RFGat9R-O-wSFirIAkW2sUibpTiaQHg77JIJa0Ti1nVNKiHs1HbqGsIimUrLl6wR6pC-V-SA-YwkpkeRrtdj7JIkQ7rciNr5KsYhMVfNN7HJWDYgocYiVB_00fMb16BZyLyZmejssfbJsuEe2-iSz-teXbM_CgcOxs3vzmZIhRWBg_KFwEBfJk8QXF_rknpArQgX0EaBiZS96hoEDUMpiQFxiBsn6c7QBI-tXRsi5RW86nr_yAHmdmzdUm15O1jxeSKTLgUjhLK5iznGZL7nBibF7Fya00E7g4vsWq_vUMEXXA4T13xETuVu5FzOE5kcoYnM70ADc8H6tH432Uj4kMXquu_r3ARkWvAEzjumOWHtx-YtZ7alfqwPuGKDha-Y67mJDaxct-j6xBdOjtVMwD5w4jw5cgPhCoMQ8wAv-kmKhgBs7lJQoZQXbHOHLGKCuKW9Eq1FmwqGjLUTWUn-ZKq0wWH2Ocg4LAacKRIbFf8O7nDqBDDQllQPwNcVgzk85hEzCt6sfagegFKEogH5IH_FIYjELKMgwaBXYviCbUUsmIQGCDmFQlLghYTCuCfFlHHbQwVbK0ash2o-kSkYyRbQzmhcsq8yb-EG72jGclkn2sUdmZUZOJbjiTbEp-2VYiBODQAYOZBBpRFDnxW8pi4nXZEocIBcAxwJcdtf1cT9BLvoV1xCI7kFSMNIw2ylKwtaxUCmd1pTtLHZsL4MhNpX8RO_FeSRkSoI2_nW3D9BWEUTpdTVvNpbe7iDgDP3fhA3MuCsH7mz5PBOAxHpkg7jjuRKRyyiybEz4LwX-jWSxhqBMAatsDNTR1eS5hLB3SZu2FgKeTYm5ngrbebkwPgFsNN ...
# [{'start': 0.48377, 'duration': 2.77646, 'confidence': 0.608}, {'start': 3.26022, 'duration': 2.7636, 'confidence': 0.607}, {'start': 6.02382, 'duration': 2.75714, 'confidence': 0.65}, {'start': 8.78096, 'duration': 2.75622, 'confidence': 0.573}, {'start': 11.53719, 'duration': 2.74804, 'confidence': 0.485}, {'start': 14.28523, 'duration': 2.75954, 'confidence': 0.329}, {'start': 17.04477, 'duration': 2.76785, 'confidence': 0.653}, {'start': 19.81261, 'duration': 2.06311, 'confidence': 0.637}, {'start': 21.87573, 'duration': 2.75219, 'confidence': 0.587}, {'start': 24.62792, 'duration': 2.75949, 'confidence': 0.284}, {'start': 27.38741, 'duration': 2.75888, 'confidence': 0.772}, {'start': 30.1463, 'duration': 2.75961, 'confidence': 0.59}, {'start': 32.90591, 'duration': 2.75784, 'confidence': 0.861}, {'start': 35.66375, 'duration': 2.75788, 'confidence': 0.544}, {'start': 38.42163, 'duration': 2.76766, 'confidence': 0.388}, {'start': 41.18929, 'duration': 2.75645, 'confidence': 0.587}, {'start': 43.94575, 'duration': 2.74836, 'confidence': 0.553}, {'start': 46.6941, 'duration': 2.75932, 'confidence': 0.116}, {'start': 49.45342, 'duration': 2.77711, 'confidence': 0.503}, {'start': 52.23053, 'duration': 2.75567, 'confidence': 0.659}, {'start': 54.9862, 'duration': 2.74293, 'confidence': 0.574}, {'start': 57.72913, 'duration': 2.75727, 'confidence': 0.709}, {'start': 60.4864, 'duration': 2.75357, 'confidence': 0.869}, {'start': 63.23996, 'duration': 2.75834, 'confidence': 0.387}, {'start': 65.9983, 'duration': 2.76368, 'confidence': 0.496}, {'start': 68.76198, 'duration': 2.75913, 'confidence': 0.087}, {'start': 71.52111, 'duration': 2.77684, 'confidence': 0.619}, {'start': 74.29795, 'duration': 2.75598, 'confidence': 0.753}, {'start': 77.05393, 'duration': 2.74501, 'confidence': 0.281}, {'start': 79.79894, 'duration': 2.75683, 'confidence': 0.423}, {'start': 82.55578, 'duration': 2.7538, 'confidence': 0.846}, {'start': 85.30958, 'duration': 2.77155, 'confidence': 0.639}, {'start': 88.08113, 'duration': 2.75543, 'confidence': 0.488}, {'start': 90.83657, 'duration': 2.74422, 'confidence': 0.046}, {'start': 93.58078, 'duration': 2.76141, 'confidence': 0.857}, {'start': 96.34219, 'duration': 2.75604, 'confidence': 0.855}, {'start': 99.09823, 'duration': 2.7711, 'confidence': 0.21}, {'start': 101.86933, 'duration': 2.75917, 'confidence': 0.502}, {'start': 104.6285, 'duration': 2.75524, 'confidence': 0.673}, {'start': 107.38374, 'duration': 2.7592, 'confidence': 0.378}, {'start': 110.14293, 'duration': 2.75917, 'confidence': 0.333}, {'start': 112.9021, 'duration': 2.75772, 'confidence': 0.701}, {'start': 115.65983, 'duration': 2.75073, 'confidence': 0.568}, {'start': 118.41055, 'duration': 2.7557, 'confidence': 0.897}, {'start': 121.16625, 'duration': 2.77003, 'confidence': 0.279}, {'start': 123.93628, 'duration': 2.76469, 'confidence': 0.486}, {'start': 126.70097, 'duration': 2.75086, 'confidence': 0.666}, {'start': 129.45183, 'duration': 2.76775, 'confidence': 0.683}, {'start': 132.21957, 'duration': 2.76416, 'confidence': 0.366}, {'start': 134.98373, 'duration': 2.74029, 'confidence': 0.176}, {'start': 137.72401, 'duration': 2.80877, 'confidence': 0.81}, {'start': 140.53279, 'duration': 2.75482, 'confidence': 0.72}, {'start': 143.28761, 'duration': 2.7215, 'confidence': 0.28}, {'start': 146.00911, 'duration': 2.75841, 'confidence': 0.716}, {'start': 148.76752, 'duration': 2.75973, 'confidence': 0.832}, {'start': 151.52725, 'duration': 2.7615, 'confidence': 0.681}, {'start': 154.28876, 'duration': 2.75596, 'confidence': 0.547}, {'start': 157.04471, 'duration': 2.75551, 'confidence': 0.187}, {'start': 159.80022, 'duration': 2.7621, 'confidence': 0.663}, {'start': 162.56232, 'duration': 2.75797, 'confidence': 0.343}, {'start': 165.3203, 'duration': 2.75533, 'confidence': 0.434}, {'start': 168.07562, 'duration': 2.76032, 'confidence': 0.861}, {'start': 170.83595, 'duration': 2.76008, 'confidence': 0.635}, {'start': 173.59602, 'duration ...
# [{'start': 0.48377, 'duration': 0.69853, 'confidence': 0.578}, {'start': 1.1823, 'duration': 0.69175, 'confidence': 0.392}, {'start': 1.87405, 'duration': 0.6895, 'confidence': 0.213}, {'start': 2.56355, 'duration': 0.69667, 'confidence': 0.302}, {'start': 3.26022, 'duration': 0.68678, 'confidence': 0.222}, {'start': 3.947, 'duration': 0.69534, 'confidence': 0.322}, {'start': 4.64234, 'duration': 0.68673, 'confidence': 0.258}, {'start': 5.32907, 'duration': 0.69476, 'confidence': 0.308}, {'start': 6.02382, 'duration': 0.68616, 'confidence': 0.214}, {'start': 6.70998, 'duration': 0.69235, 'confidence': 0.281}, {'start': 7.40234, 'duration': 0.68314, 'confidence': 0.234}, {'start': 8.08548, 'duration': 0.69548, 'confidence': 0.299}, {'start': 8.78096, 'duration': 0.68444, 'confidence': 0.26}, {'start': 9.4654, 'duration': 0.69369, 'confidence': 0.332}, {'start': 10.15909, 'duration': 0.68198, 'confidence': 0.244}, {'start': 10.84106, 'duration': 0.69613, 'confidence': 0.284}, {'start': 11.53719, 'duration': 0.68688, 'confidence': 0.192}, {'start': 12.22406, 'duration': 0.69179, 'confidence': 0.296}, {'start': 12.91585, 'duration': 0.67761, 'confidence': 0.232}, {'start': 13.59346, 'duration': 0.69176, 'confidence': 0.298}, {'start': 14.28523, 'duration': 0.68621, 'confidence': 0.232}, {'start': 14.97144, 'duration': 0.6942, 'confidence': 0.257}, {'start': 15.66564, 'duration': 0.68557, 'confidence': 0.187}, {'start': 16.35121, 'duration': 0.69355, 'confidence': 0.309}, {'start': 17.04477, 'duration': 0.68491, 'confidence': 0.259}, {'start': 17.72968, 'duration': 0.70152, 'confidence': 0.351}, {'start': 18.43119, 'duration': 0.68672, 'confidence': 0.241}, {'start': 19.11791, 'duration': 0.6947, 'confidence': 0.29}, {'start': 19.81261, 'duration': 0.68791, 'confidence': 0.163}, {'start': 20.50053, 'duration': 0.68852, 'confidence': 0.281}, {'start': 21.18905, 'duration': 0.68667, 'confidence': 0.212}, {'start': 21.87573, 'duration': 0.69283, 'confidence': 0.267}, {'start': 22.56855, 'duration': 0.6842, 'confidence': 0.747}, {'start': 23.25275, 'duration': 0.69035, 'confidence': 0.871}, {'start': 23.94311, 'duration': 0.68481, 'confidence': 0.844}, {'start': 24.62792, 'duration': 0.68973, 'confidence': 0.857}, {'start': 25.31765, 'duration': 0.69034, 'confidence': 0.853}, {'start': 26.00799, 'duration': 0.69033, 'confidence': 0.86}, {'start': 26.69832, 'duration': 0.6891, 'confidence': 0.846}, {'start': 27.38741, 'duration': 0.68972, 'confidence': 0.862}, {'start': 28.07713, 'duration': 0.68972, 'confidence': 0.834}, {'start': 28.76685, 'duration': 0.68972, 'confidence': 0.854}, {'start': 29.45657, 'duration': 0.68973, 'confidence': 0.852}, {'start': 30.1463, 'duration': 0.68974, 'confidence': 0.863}, {'start': 30.83603, 'duration': 0.68913, 'confidence': 0.851}, {'start': 31.52516, 'duration': 0.69037, 'confidence': 0.87}, {'start': 32.21553, 'duration': 0.69037, 'confidence': 0.851}, {'start': 32.90591, 'duration': 0.69038, 'confidence': 0.849}, {'start': 33.59629, 'duration': 0.68915, 'confidence': 0.836}, {'start': 34.28544, 'duration': 0.68915, 'confidence': 0.859}, {'start': 34.9746, 'duration': 0.68916, 'confidence': 0.839}, {'start': 35.66375, 'duration': 0.68978, 'confidence': 0.856}, {'start': 36.35353, 'duration': 0.68978, 'confidence': 0.841}, {'start': 37.04331, 'duration': 0.68916, 'confidence': 0.83}, {'start': 37.73247, 'duration': 0.68916, 'confidence': 0.796}, {'start': 38.42163, 'duration': 0.69039, 'confidence': 0.788}, {'start': 39.11202, 'duration': 0.69038, 'confidence': 0.756}, {'start': 39.8024, 'duration': 0.69407, 'confidence': 0.773}, {'start': 40.49646, 'duration': 0.69283, 'confidence': 0.737}, {'start': 41.18929, 'duration': 0.68974, 'confidence': 0.733}, {'start': 41.87903, 'duration': 0.68973, 'confidence': 0.469}, {'start': 42.56876, 'duration': 0.68849, 'confidence': 0.216}, {'start': 43.25726, 'duration': 0.68849, 'confidence': 0.074}, {'start': 43.94575, 'duration': 0.6891, 'confidence': 0.122}, ...
# [{'start': 0.0, 'duration': 23.25275, 'confidence': 1.0, 'loudness': -31.747, 'tempo': 86.502, 'tempo_confidence': 0.29, 'key': 3, 'key_confidence': 0.429, 'mode': 1, 'mode_confidence': 0.501, 'time_signature': 4, 'time_signature_confidence': 1.0}, {'start': 23.25275, 'duration': 22.06749, 'confidence': 0.985, 'loudness': -11.077, 'tempo': 86.971, 'tempo_confidence': 0.745, 'key': 2, 'key_confidence': 0.018, 'mode': 1, 'mode_confidence': 0.342, 'time_signature': 4, 'time_signature_confidence': 1.0}, {'start': 45.32024, 'duration': 41.36805, 'confidence': 0.31, 'loudness': -8.556, 'tempo': 87.046, 'tempo_confidence': 0.48, 'key': 7, 'key_confidence': 0.061, 'mode': 1, 'mode_confidence': 0.54, 'time_signature': 4, 'time_signature_confidence': 1.0}, {'start': 86.6883, 'duration': 16.56119, 'confidence': 0.177, 'loudness': -8.771, 'tempo': 86.802, 'tempo_confidence': 0.295, 'key': 7, 'key_confidence': 0.075, 'mode': 0, 'mode_confidence': 0.536, 'time_signature': 4, 'time_signature_confidence': 1.0}, {'start': 103.24948, 'duration': 32.41824, 'confidence': 0.021, 'loudness': -8.704, 'tempo': 87.091, 'tempo_confidence': 0.385, 'key': 7, 'key_confidence': 0.087, 'mode': 0, 'mode_confidence': 0.514, 'time_signature': 4, 'time_signature_confidence': 1.0}, {'start': 135.66772, 'duration': 41.96646, 'confidence': 0.594, 'loudness': -10.707, 'tempo': 87.046, 'tempo_confidence': 0.601, 'key': 7, 'key_confidence': 0.144, 'mode': 0, 'mode_confidence': 0.544, 'time_signature': 4, 'time_signature_confidence': 0.755}, {'start': 177.63419, 'duration': 12.04375, 'confidence': 0.187, 'loudness': -13.527, 'tempo': 89.913, 'tempo_confidence': 0.226, 'key': 3, 'key_confidence': 0.0, 'mode': 1, 'mode_confidence': 0.0, 'time_signature': 4, 'time_signature_confidence': 0.615}, {'start': 189.67793, 'duration': 24.13724, 'confidence': 0.366, 'loudness': -10.007, 'tempo': 87.053, 'tempo_confidence': 0.704, 'key': 7, 'key_confidence': 0.052, 'mode': 0, 'mode_confidence': 0.426, 'time_signature': 3, 'time_signature_confidence': 0.409}, {'start': 213.81517, 'duration': 8.27607, 'confidence': 0.339, 'loudness': -10.028, 'tempo': 87.023, 'tempo_confidence': 0.707, 'key': 0, 'key_confidence': 0.28, 'mode': 0, 'mode_confidence': 0.222, 'time_signature': 3, 'time_signature_confidence': 1.0}, {'start': 222.09125, 'duration': 14.4831, 'confidence': 0.298, 'loudness': -10.479, 'tempo': 87.007, 'tempo_confidence': 0.808, 'key': 3, 'key_confidence': 0.0, 'mode': 1, 'mode_confidence': 0.0, 'time_signature': 3, 'time_signature_confidence': 0.95}, {'start': 236.57434, 'duration': 6.89611, 'confidence': 0.268, 'loudness': -10.753, 'tempo': 87.031, 'tempo_confidence': 0.845, 'key': 7, 'key_confidence': 0.211, 'mode': 1, 'mode_confidence': 0.446, 'time_signature': 3, 'time_signature_confidence': 1.0}, {'start': 243.47044, 'duration': 15.87873, 'confidence': 0.142, 'loudness': -10.228, 'tempo': 87.023, 'tempo_confidence': 0.755, 'key': 3, 'key_confidence': 0.0, 'mode': 1, 'mode_confidence': 0.0, 'time_signature': 3, 'time_signature_confidence': 1.0}, {'start': 259.34918, 'duration': 39.98229, 'confidence': 0.375, 'loudness': -8.6, 'tempo': 87.069, 'tempo_confidence': 0.477, 'key': 7, 'key_confidence': 0.131, 'mode': 0, 'mode_confidence': 0.492, 'time_signature': 4, 'time_signature_confidence': 0.55}, {'start': 299.33148, 'duration': 22.76296, 'confidence': 0.022, 'loudness': -11.051, 'tempo': 87.059, 'tempo_confidence': 0.529, 'key': 7, 'key_confidence': 0.107, 'mode': 1, 'mode_confidence': 0.0, 'time_signature': 4, 'time_signature_confidence': 1.0}, {'start': 322.09442, 'duration': 8.93958, 'confidence': 1.0, 'loudness': -39.335, 'tempo': 86.996, 'tempo_confidence': 0.433, 'key': 7, 'key_confidence': 0.0, 'mode': 0, 'mode_confidence': 0.013, 'time_signature': 4, 'time_signature_confidence': 1.0}]
# [{'start': 0.0, 'duration': 0.09261, 'confidence': 0.0, 'loudness_start': -37.988, 'loudness_max_time': 0.02131, 'loudness_max': -29.228, 'loudness_end': 0.0, 'pitches': [0.172, 1.0, 0.42, 0.234, 0.09, 0.211, 0.292, 0.359, 0.049, 0.145, 0.047, 0.183], 'timbre': [27.333, -235.634, -14.825, 10.706, 86.016, -51.355, -13.449, 25.976, -7.57, -1.01, 12.338, -16.355]}, {'start': 0.09261, 'duration': 0.25619, 'confidence': 0.335, 'loudness_start': -35.751, 'loudness_max_time': 0.04052, 'loudness_max': -30.483, 'loudness_end': 0.0, 'pitches': [0.042, 0.323, 0.534, 0.131, 0.245, 0.136, 0.233, 1.0, 0.108, 0.068, 0.24, 0.03], 'timbre': [27.337, -245.446, -17.623, -12.755, 78.239, -46.34, 7.576, 15.837, -9.605, -3.834, 2.933, -21.271]}, {'start': 0.3488, 'duration': 0.09274, 'confidence': 0.61, 'loudness_start': -35.044, 'loudness_max_time': 0.00704, 'loudness_max': -27.448, 'loudness_end': 0.0, 'pitches': [0.083, 1.0, 0.748, 0.075, 0.106, 0.33, 0.75, 0.29, 0.08, 0.146, 0.042, 0.1], 'timbre': [29.096, -258.575, -26.209, -0.133, 71.331, -82.326, -0.03, 11.558, 0.213, -15.42, -3.095, -9.845]}, {'start': 0.44154, 'duration': 0.12213, 'confidence': 0.378, 'loudness_start': -34.125, 'loudness_max_time': 0.02925, 'loudness_max': -28.196, 'loudness_end': 0.0, 'pitches': [0.033, 0.37, 0.376, 0.052, 0.042, 0.071, 0.388, 1.0, 0.17, 0.075, 0.193, 0.032], 'timbre': [28.732, -254.786, -37.75, 0.428, 66.267, -39.884, 7.928, 27.045, -0.093, -3.103, -1.685, -17.696]}, {'start': 0.56367, 'duration': 0.48649, 'confidence': 0.407, 'loudness_start': -34.989, 'loudness_max_time': 0.13541, 'loudness_max': -28.568, 'loudness_end': 0.0, 'pitches': [0.043, 0.327, 0.166, 0.072, 0.088, 0.132, 0.144, 1.0, 0.054, 0.059, 0.313, 0.037], 'timbre': [27.094, -251.557, -31.341, -50.744, 66.642, -53.571, 18.069, 10.189, -11.558, -5.532, -14.354, -19.007]}, {'start': 1.05016, 'duration': 0.11079, 'confidence': 0.307, 'loudness_start': -37.241, 'loudness_max_time': 0.04374, 'loudness_max': -32.6, 'loudness_end': 0.0, 'pitches': [0.062, 0.808, 1.0, 0.155, 0.077, 0.129, 0.466, 0.818, 0.241, 0.118, 0.489, 0.085], 'timbre': [25.886, -235.269, -23.473, -17.551, 83.959, -46.949, 6.974, 20.985, -12.691, -2.855, -7.185, -18.849]}, {'start': 1.16095, 'duration': 0.13995, 'confidence': 0.67, 'loudness_start': -36.9, 'loudness_max_time': 0.05461, 'loudness_max': -28.181, 'loudness_end': 0.0, 'pitches': [0.064, 1.0, 0.59, 0.064, 0.041, 0.122, 0.407, 0.675, 0.104, 0.079, 0.131, 0.053], 'timbre': [28.821, -251.799, 9.259, -39.446, 83.534, -21.96, 8.863, 7.827, -10.26, -1.77, -25.362, -17.127]}, {'start': 1.30091, 'duration': 0.17488, 'confidence': 0.257, 'loudness_start': -33.726, 'loudness_max_time': 0.02897, 'loudness_max': -28.268, 'loudness_end': 0.0, 'pitches': [0.114, 0.747, 0.793, 0.114, 0.051, 0.101, 0.173, 1.0, 0.083, 0.104, 0.555, 0.064], 'timbre': [29.667, -257.419, -11.075, -20.629, 69.069, -31.74, 6.655, 17.148, -3.012, -0.322, -3.483, -16.947]}, {'start': 1.47578, 'duration': 0.24853, 'confidence': 0.279, 'loudness_start': -35.237, 'loudness_max_time': 0.0347, 'loudness_max': -29.83, 'loudness_end': 0.0, 'pitches': [0.06, 0.498, 0.6, 0.197, 0.34, 0.207, 0.458, 0.64, 0.269, 0.136, 1.0, 0.062], 'timbre': [27.609, -249.792, -26.232, -8.791, 72.599, -50.35, 7.324, 23.691, -7.389, -8.816, 4.219, -21.868]}, {'start': 1.72431, 'duration': 0.09347, 'confidence': 0.572, 'loudness_start': -35.703, 'loudness_max_time': 0.01021, 'loudness_max': -28.794, 'loudness_end': 0.0, 'pitches': [0.09, 1.0, 0.349, 0.088, 0.052, 0.331, 0.593, 0.347, 0.092, 0.202, 0.266, 0.058], 'timbre': [27.711, -232.028, 1.987, 20.25, 93.86, -68.874, -30.129, 18.396, -6.333, -16.983, 0.681, -12.506]}, {'start': 1.81778, 'duration': 0.12163, 'confidence': 0.321, 'loudness_start': -36.578, 'loudness_max_time': 0.02911, 'loudness_max': -29.675, 'loudness_end': 0.0, 'pitches': [0.091, 1.0, 0.393, 0.067, 0.115, 0.172, 0.2, 0.134, 0.052, 0.143, 0.22, 0.059], 'timbre': [27.374, -225.719, 25.918, 16.378, 107.414, -36.175,  ...
# [{'start': 0.48377, 'duration': 0.46569, 'confidence': 0.578}, {'start': 0.94945, 'duration': 0.23284, 'confidence': 0.578}, {'start': 1.1823, 'duration': 0.46117, 'confidence': 0.392}, {'start': 1.64347, 'duration': 0.23058, 'confidence': 0.392}, {'start': 1.87405, 'duration': 0.45967, 'confidence': 0.213}, {'start': 2.33372, 'duration': 0.22983, 'confidence': 0.213}, {'start': 2.56355, 'duration': 0.46445, 'confidence': 0.302}, {'start': 3.028, 'duration': 0.23222, 'confidence': 0.302}, {'start': 3.26022, 'duration': 0.45785, 'confidence': 0.222}, {'start': 3.71807, 'duration': 0.22893, 'confidence': 0.222}, {'start': 3.947, 'duration': 0.46356, 'confidence': 0.322}, {'start': 4.41056, 'duration': 0.23178, 'confidence': 0.322}, {'start': 4.64234, 'duration': 0.45782, 'confidence': 0.258}, {'start': 5.10016, 'duration': 0.22891, 'confidence': 0.258}, {'start': 5.32907, 'duration': 0.46317, 'confidence': 0.308}, {'start': 5.79224, 'duration': 0.23159, 'confidence': 0.308}, {'start': 6.02382, 'duration': 0.45744, 'confidence': 0.214}, {'start': 6.48126, 'duration': 0.22872, 'confidence': 0.214}, {'start': 6.70998, 'duration': 0.46157, 'confidence': 0.281}, {'start': 7.17155, 'duration': 0.23078, 'confidence': 0.281}, {'start': 7.40234, 'duration': 0.45543, 'confidence': 0.234}, {'start': 7.85777, 'duration': 0.22771, 'confidence': 0.234}, {'start': 8.08548, 'duration': 0.46366, 'confidence': 0.299}, {'start': 8.54914, 'duration': 0.23183, 'confidence': 0.299}, {'start': 8.78096, 'duration': 0.45629, 'confidence': 0.26}, {'start': 9.23725, 'duration': 0.22815, 'confidence': 0.26}, {'start': 9.4654, 'duration': 0.46246, 'confidence': 0.332}, {'start': 9.92786, 'duration': 0.23123, 'confidence': 0.332}, {'start': 10.15909, 'duration': 0.45465, 'confidence': 0.244}, {'start': 10.61374, 'duration': 0.22733, 'confidence': 0.244}, {'start': 10.84106, 'duration': 0.46408, 'confidence': 0.284}, {'start': 11.30515, 'duration': 0.23204, 'confidence': 0.284}, {'start': 11.53719, 'duration': 0.45792, 'confidence': 0.192}, {'start': 11.9951, 'duration': 0.22896, 'confidence': 0.192}, {'start': 12.22406, 'duration': 0.46119, 'confidence': 0.296}, {'start': 12.68526, 'duration': 0.2306, 'confidence': 0.296}, {'start': 12.91585, 'duration': 0.45174, 'confidence': 0.232}, {'start': 13.36759, 'duration': 0.22587, 'confidence': 0.232}, {'start': 13.59346, 'duration': 0.46118, 'confidence': 0.298}, {'start': 14.05464, 'duration': 0.23059, 'confidence': 0.298}, {'start': 14.28523, 'duration': 0.45747, 'confidence': 0.232}, {'start': 14.7427, 'duration': 0.22874, 'confidence': 0.232}, {'start': 14.97144, 'duration': 0.4628, 'confidence': 0.257}, {'start': 15.43424, 'duration': 0.2314, 'confidence': 0.257}, {'start': 15.66564, 'duration': 0.45705, 'confidence': 0.187}, {'start': 16.12269, 'duration': 0.22852, 'confidence': 0.187}, {'start': 16.35121, 'duration': 0.46237, 'confidence': 0.309}, {'start': 16.81358, 'duration': 0.23118, 'confidence': 0.309}, {'start': 17.04477, 'duration': 0.45661, 'confidence': 0.259}, {'start': 17.50137, 'duration': 0.2283, 'confidence': 0.259}, {'start': 17.72968, 'duration': 0.46768, 'confidence': 0.351}, {'start': 18.19736, 'duration': 0.23384, 'confidence': 0.351}, {'start': 18.43119, 'duration': 0.45781, 'confidence': 0.241}, {'start': 18.88901, 'duration': 0.22891, 'confidence': 0.241}, {'start': 19.11791, 'duration': 0.46314, 'confidence': 0.29}, {'start': 19.58105, 'duration': 0.23157, 'confidence': 0.29}, {'start': 19.81261, 'duration': 0.45861, 'confidence': 0.163}, {'start': 20.27122, 'duration': 0.2293, 'confidence': 0.163}, {'start': 20.50053, 'duration': 0.45901, 'confidence': 0.281}, {'start': 20.95954, 'duration': 0.22951, 'confidence': 0.281}, {'start': 21.18905, 'duration': 0.45778, 'confidence': 0.212}, {'start': 21.64683, 'duration': 0.22889, 'confidence': 0.212}, {'start': 21.87573, 'duration': 0.46188, 'confidence': 0.267}, {'start': 22.33761, 'duration': 0.23094, 'confidence': 0.267}, {'start': 22 ...

# %% [markdown]
# *   Como podemos ver, uma única música gera um resultado relativamente grande quando buscamos seus dados de *audio analysis*
# *   Isso porque estes dados são, na verdade, a decodificação de cada pedacinho da música, incluindo seu ritmo, timbre e tom ([para saber mais, clique aqui](https://developer.spotify.com/documentation/web-api/reference/#/operations/get-audio-analysis))
# *   Considerando que vamos trabalhar com + 1 milhão de faixas, de gêneros muito variados entre si, estariamos lidando com uma quantidade absurda de dados, que acarretaria em um custo alto de processamento e de consultas à API, e talvez teríamos um ganho apenas marginal em nossa aplicação
# *   Portanto, para a criação desse nosso modelo preditivo, vamos nos limitar aos dados de *audio features* (que já temos disponibilizados no dataset do Kaggle), apesar da API disponibilizar também estes dados de *audio analysis*

# %% [markdown]
# # Salvando todos dados no Banco de Dados SQLite3

# %% [markdown]
# 1.   **Criando o banco e gerando uma conexão com ele**

# %%
conn = sqlite3.connect('recsys.db')

# %% [markdown]
# 2.   **Salvando as tabelas de Faixas, Artistas e Artistas Relacionados**

# %% [markdown]
# Tabela de FAIXAS

# %%
df_tracks.to_sql(name='tracks', con=conn)

# %% [markdown]
# Tabela de ARTISTAS

# %%
spotify_artists.to_sql(name='artists', con=conn)

# %% [markdown]
# Tabela de ARTISTAS RELACIONADOS

# %% [markdown]
# > Para salvar a relação de Artistas Relacionados no nosso Banco de Dados, é necessário transformar em String os dados que estão no formato Lista no .csv

# %%
related_artists_copy = related_artists_dataset.copy()

# %%
for column in ['related_ids', 'related_names', 'related_genres'] : related_artists_copy[column] = related_artists_copy[column].apply(lambda x: ', '.join([str(i) for i in x]))

# %%
related_artists_copy.to_sql(name='related_artists', con=conn)

# %% [markdown]
# 3.   **Consultas gerais ao banco criado**

# %%
df = pd.read_sql('SELECT * FROM tracks', con=conn, index_col='index')

# %%
df
# Out:
#                              id                   name  \
# index
# 0        7lmeHLHBe4nmXzuXc0HDjk                Testify
# 1        1wsRitfRRtWyEapl0q22o8        Guerrilla Radio
# 2        1hR0fIFK2qRG3f3RF70pb7       Calm Like a Bomb
# 3        2lbASgTSoDO7MTuLAXlTW0              Mic Check
# 4        1MQTmpYOZ6fcMQc56Hdo7T  Sleep Now In the Fire
# ...                         ...                    ...
# 1204020  0EsMifwUmMfJZxzoMPXJKZ         Gospel of Juke
# 1204021  2WSc2TB1CSJgGE0PEzVeiu          Prism Visions
# 1204022  6iProIgUe3ETpO6UT0v5Hg              Tokyo 360
# 1204023  37B4SXC8uoBsUyKCWnhPfX                 Yummy!
# 1204024  3GgQmOxxLyRoAb4j86zOBX   That's The Way It Is
#
#                              album                album_id  \
# index
# 0        The Battle Of Los Angeles  2eia0myWFgoHuttJytCxgX
# 1        The Battle Of Los Angeles  2eia0myWFgoHuttJytCxgX
# 2        The Battle Of Los Angeles  2eia0myWFgoHuttJytCxgX
# 3        The Battle Of Los Angeles  2eia0myWFgoHuttJytCxgX
# 4        The Battle Of Los Angeles  2eia0myWFgoHuttJytCxgX
# ...                            ...                     ...
# 1204020                 Notch - EP  38O5Ys0W9PFS5K7dMb7yKb
# 1204021                 Notch - EP  38O5Ys0W9PFS5K7dMb7yKb
# 1204022                 Notch - EP  38O5Ys0W9PFS5K7dMb7yKb
# 1204023                 Notch - EP  38O5Ys0W9PFS5K7dMb7yKb
# 1204024                 Notch - EP  38O5Ys0W9PFS5K7dMb7yKb
#
#                               artists                  artist_ids  \
# index
# 0        ['Rage Against The Machine']  ['2d0hyoQ5ynDBnkvAbJKORj']
# 1        ['Rage Against The Machine']  ['2d0hyoQ5ynDBnkvAbJKORj']
# 2        ['Rage Against The Machine']  ['2d0hyoQ5ynDBnkvAbJKORj']
# 3        ['Rage Against The Machine']  ['2d0hyoQ5ynDBnkvAbJKORj']
# 4        ['Rage Against The Machine']  ['2d0hyoQ5ynDBnkvAbJKORj']
# ...                               ...                         ...
# 1204020                   ['FVLCRVM']  ['7AjItKsRnEYRSiBt2OxK1y']
# 1204021                   ['FVLCRVM']  ['7AjItKsRnEYRSiBt2OxK1y']
# 1204022                   ['FVLCRVM']  ['7AjItKsRnEYRSiBt2OxK1y']
# 1204023                   ['FVLCRVM']  ['7AjItKsRnEYRSiBt2OxK1y']
# 1204024                   ['FVLCRVM']  ['7AjItKsRnEYRSiBt2OxK1y']
#
#          track_number  disc_number  explicit  danceability  ...  speechiness  \
# index                                                       ...
# 0                   1            1         0         0.470  ...       0.0727
# 1                   2            1         1         0.599  ...       0.1880
# 2                   3            1         0         0.315  ...       0.4830
# 3                   4            1         1         0.440  ...       0.2370
# 4                   5            1         0         0.426  ...       0.0701
# ...               ...          ...       ...           ...  ...          ...
# 1204020             2            1         0         0.264  ...       0.0672
# 1204021             3            1         0         0.796  ...       0.0883
# 1204022             4            1         0         0.785  ...       0.0564
# 1204023             5            1         0         0.665  ...       0.0409
# 1204024             6            1         0         0.736  ...       0.0539
#
#          acousticness  instrumentalness  liveness  valence    tempo  \
# index
# 0             0.02610          0.000011    0.3560    0.503  117.906
# 1             0.01290          0.000071    0.1550    0.489  103.680
# 2             0.02340          0.000002    0.1220    0.370  149.749
# 3             0.16300          0.000004    0.1210    0.574   96.752
# 4             0.00162          0.105000    0.0789    0.539  127.059
# ...               ...               ...       ...      ...      ...
# 1204020       0.00935          0.002240    0.3370    0.415  159.586
# 1204021       0.10400          0.644000    0.0749    0.781  121.980
# 1204022       0.03040          0.918000    0.0664    0.467  121.996
# 1204023       0.00007          0.776000    0.1170    0.227  124.986
# 1204024       0.01680          0.296000    0.2790    0.204  117.991
#
#          duration_ms  time_signature  year  release_date
# index
# 0             210133             4.0  1999    1999-11-02
# 1             206200             4.0  1999    1999-11-02
# 2             298893             4.0  1999    1999-11-02
# 3             213640             4.0  1999    1999-11-02
# 4             205600             4.0  1999    1999-11-02
# ...              ...             ...   ...           ...
# 1204020       276213             4.0  2014    2014-01-09
# 1204021       363179             4.0  2014    2014-01-09
# 1204022       385335             4.0  2014    2014-01-09
# 1204023       324455             4.0  2014    2014-01-09
# 1204024       304982             4.0  2014    2014-01-09
#
# [1204025 rows x 24 columns]
