# %%
# Manipulação dos Dados
import numpy as np
import pandas as pd
import json

from sklearn import preprocessing
 
# Visualização dos Dados
import matplotlib.pyplot as plt
import seaborn as sns
 
# Machine Learning

# %%
df_artists = pd.read_csv('artists.csv')

# %%
df_tracks = pd.read_csv('tracks.csv')

# %%
with open('dict_artists.json', 'r') as f:
  data = json.load(f)

related_artists = pd.DataFrame().from_dict(data, orient='index').reset_index()
related_artists.rename(columns={'index' : 'id_artist'}, inplace=True)

# %% [markdown]
# # DataFrame **Artists**

# %%
df_artists
# Out:
#                              id  followers                 genres  \
# 0        0DheY5irMjBUeLybbCUEZ2        0.0                     []
# 1        0DlhY15l3wsrnlfGio2bjU        5.0                     []
# 2        0DmRESX2JknGPQyO15yxg7        0.0                     []
# 3        0DmhnbHjm1qw6NCYPeZNgJ        0.0                     []
# 4        0Dn11fWM7vHQ3rinvWEl4E        2.0                     []
# ...                         ...        ...                    ...
# 1104344  6rJIG42vcWAf1UBdRFlQxB     3345.0                     []
# 1104345  1ljurfXKPlGncNdW3J8zJ8     2123.0  ['deep acoustic pop']
# 1104346  2vnT9YhKIvjVo9LnVjWmr2       26.0                     []
# 1104347  3ID0E5XCvnJIYZEq043ZoB      406.0                     []
# 1104348  5m0Y4WSYyai2BU752lCASy      146.0                     []
#
#                                                    name  popularity
# 0        Armid & Amir Zare Pashai feat. Sara Rouzbehani           0
# 1                                           ปูนา ภาวิณี           0
# 2                                                 Sadaa           0
# 3                                             Tra'gruda           0
# 4                                Ioannis Panoutsopoulos           0
# ...                                                 ...         ...
# 1104344                                      Cody Longo           8
# 1104345                                 Right the Stars          18
# 1104346                                  Jesse Giddings           0
# 1104347                            The Boy Band Project           0
# 1104348                                      10 Reasons           1
#
# [1104349 rows x 5 columns]

# %%
df_artists.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1104349 entries, 0 to 1104348
# Data columns (total 5 columns):
#  #   Column      Non-Null Count    Dtype
# ---  ------      --------------    -----
#  0   id          1104349 non-null  object
#  1   followers   1104336 non-null  float64
#  2   genres      1104349 non-null  object
#  3   name        1104349 non-null  object
#  4   popularity  1104349 non-null  int64
# dtypes: float64(1), int64(1), object(3)
# memory usage: 42.1+ MB

# %% [markdown]
# 'FOLLOWERS' É A ÚNICA COLUNA COM VALORES NaN

# %%
df_artists.describe()
# Out:
#           followers    popularity
# count  1.104336e+06  1.104349e+06
# mean   1.074304e+04  9.083884e+00
# std    2.609554e+05  1.376310e+01
# min    0.000000e+00  0.000000e+00
# 25%    1.000000e+01  0.000000e+00
# 50%    5.900000e+01  2.000000e+00
# 75%    4.510000e+02  1.400000e+01
# max    7.890023e+07  1.000000e+02

# %%
df_artists[df_artists.duplicated()]
# Out:
# Empty DataFrame
# Columns: [id, followers, genres, name, popularity]
# Index: []

# %% [markdown]
# MATRIZ DE CORRELAÇÃO DENTRE AS VARIÁVEIS DO *df_artists*

# %%
matrix_artists = df_artists.corr()
plt.figure(figsize=(10,8))
sns.heatmap(matrix_artists, annot=True, linewidths=0.5, fmt=".2f")

# %% [markdown]
# # - artist id : *hash* que identifica o artista

# %%
df_artists['id'].nunique()
# Out:
# 1104349

# %%
type(df_artists['id'][0])
# Out:
# str

# %%
# O Dtype da coluna foi convertido para String, para ser usado nas próximas etapas

df_artists['id'] = df_artists['id'].astype('string')

# %% [markdown]
# **Conclusões**
#
# 1.   Cada artista possui um id único

# %% [markdown]
# # - artist followers : quantidade de seguidores que o artista tem

# %% [markdown]
# TRATANDO VALORES FALTANTES

# %%
df_artists.loc[df_artists['followers'].isnull()]
# Out:
#                             id  followers                  genres  \
# 444199  7F71W80jaXFARK7hBjsDI2        NaN           ['czech pop']
# 444200  3MLHJz04KmEVzCTPclzkEm        NaN           ['czech pop']
# 444797  0cqZsULDZdJTGA4Zqh8Ckv        NaN                      []
# 444798  0BuknWzKujyc9HfZ1V50Uk        NaN                      []
# 446635  6ltU5gIDLmWNYaVNHnll5G        NaN  ['mexican electronic']
# 446636  7C9nWRMbRqpPUuKh2OEw9n        NaN                      []
# 446637  41c30F8zy5UCTSevbn0WfD        NaN  ['mexican electronic']
# 468525  1DK979aOesiZ4Vkus8txqu        NaN                      []
# 468526  6jkpqSWWsXSuqtsoeAiMDU        NaN        ['uk americana']
# 468527  7aMdHPv79qOuqqBD6TnaCp        NaN                      []
# 468528  2lr0R5vHGfI0C489h0r6qV        NaN            ['dc indie']
# 468529  0xkSOIeyeTILNIOZKyFgaP        NaN                      []
# 468530  4EqqnE0XMAcreVF84QGYJ0        NaN                      []
#
#                                                      name  popularity
# 444199                                            Marcell          36
# 444200                                               Niko          21
# 444797                                           Savzilla           0
# 444798                                          Duck Doja           0
# 446635                                               Zofa           0
# 446636                                                MHV           3
# 446637                                     Broadband Star           0
# 468525              AmorArtis Orchestra & Johannes Somary           2
# 468526                                   Police Dog Hogan          14
# 468527                Miles Davis & Charlie "Bird" Parker           0
# 468528                                    Black Dog Prowl          16
# 468529  Band of the Fifteenth Field Artillery Regiment...           3
# 468530                             Robert Steven Williams           0

# %% [markdown]
# Como temos poucos artistas com valores faltantes no item de Seguidores, será pesquisado os valores reais manualmente na plataforma, e os incluiremos a seguir:

# %%
spotify_followers = {'Marcell' : 344839, 'Niko' : 467, 'Savzilla' : 16, 'Duck Doja' : 10, 
                     'Zofa' : 7, 'MHV' : 117, 'Broadband Star' : 9, 'AmorArtis Orchestra & Johannes Somary' : 15, 
                     'Police Dog Hogan' : 1081, 'Miles Davis & Charlie "Bird" Parker' : 12461, 'Black Dog Prowl' : 198, 
                     'Band of the Fifteenth Field Artillery Regiment, RCA': 27, 'Robert Steven Williams' : 7}

# %%
df_artists['followers'] = df_artists['followers'].fillna(df_artists['name'].map(spotify_followers))

# %%
df_artists['followers'].isnull().any()
# Out:
# False

# %% [markdown]
# Os dados serão convertidos para int, visto que não existem Seguidores decimais

# %%
df_artists['followers'] = df_artists['followers'].astype('int')

# %% [markdown]
# IDENTIFICANDO OS OUTLIERS

# %%
df_artists.boxplot(column=['followers'])

# %%
df_artists['followers'].describe()
# Out:
# count    1.104349e+06
# mean     1.074324e+04
# std      2.609541e+05
# min      0.000000e+00
# 25%      1.000000e+01
# 50%      5.900000e+01
# 75%      4.510000e+02
# max      7.890023e+07
# Name: followers, dtype: float64

# %%
q1 = df_artists['followers'].quantile(0.25)
q3 = df_artists['followers'].quantile(0.75)

IQR = q3 - q1

# %%
followers_outliers = q3 + 1.5 * IQR

# %%
len( df_artists[df_artists['followers'] >= followers_outliers] )
# Out:
# 187927

# %% [markdown]
# ANÁLISE DA QUANTIDADE DE SEGUIDORES

# %%
# Os 15 artistas com maior número de Seguidores

df_artists[['followers', 'name']].sort_values('followers', ascending=False).head(15)
# Out:
#         followers             name
# 144138   78900234       Ed Sheeran
# 144485   61301006    Ariana Grande
# 313676   54416812            Drake
# 144481   44606973    Justin Bieber
# 144488   43747833           Eminem
# 313508   42244011          Rihanna
# 126658   41792604    Billie Eilish
# 126338   38869193     Taylor Swift
# 126339   33665795  Imagine Dragons
# 144496   33483326            Queen
# 107321   32419313     Shawn Mendes
# 115489   32244734        Bad Bunny
# 145802   32167665      Post Malone
# 144484   31623813              BTS
# 144483   31308207       The Weeknd

# %%
# Os 15 maiores conjuntos de artistas, com base na quantidade de Seguidores

df_artists['followers'].value_counts().sort_values(ascending=False).head(15)
# Out:
# 0     67875
# 1     35979
# 2     27956
# 3     24906
# 4     22155
# 5     20162
# 6     18299
# 7     17019
# 8     15909
# 9     14668
# 10    13579
# 11    12925
# 12    11785
# 13    11583
# 14    10641
# Name: followers, dtype: int64

# %% [markdown]
# *   Ao agruparmos os artistas com base na quantidade de seus seguidores, percebe-se uma tendência de que, quanto MAIS seguidores, MENOS artistas agrupados (sendo que o maior conjunto de artistas é aquele com zero seguidores)
# *   Analisaremos isso graficamente

# %%
df_artists['followers'].plot(xlabel='Artista (nº index)', ylabel='Quantidade de Seguidores')

# %% [markdown]
# *   O dataset contém artistas com quantidade de seguidores muito diversos entre si (de 0 a 70MM+).
# *   Assim, para um melhor entendimento do todo, a visualização da quantidade de seguidores será fracionada

# %%
fig, axs = plt.subplots(2, 3, figsize=(15, 6))
ax = axs.ravel()

fig.suptitle('Segmentação de Artistas com base na quantidade de Seguidores', fontsize=16)
fig.text(0.5, 0.04, 'Número de Seguidores', ha='center', fontsize=12)
fig.text(0.04, 0.5, 'Quantidade de Artistas', va='center', rotation='vertical', fontsize=12)

ranges = [range(0, 110, 10), range(100, 1100, 100), 
          range(1000, 110000, 1000), range(100000, 1100000, 10000), 
          range(1000000, 11000000, 1000000), range(10000000, 110000000, 10000000)]

for i in range(6):
  df_artists['followers'].hist(bins=ranges[i], ax=ax[i])

plt.show()

# %% [markdown]
# **Conclusões**
#
# 1.   Considerando os quartis no método *describe*, identificamos que 25% de todo o dataset possui até 10 seguidores
# 2.   75% dos artistas possuem até 451 seguidores
# 3.   Os demais artistas (25%) constam com uma quantidade "desproporcional" aos demais, chegando a terem mais de 78 milhões, como é o caso de Ed Sheeran
# 4.   Identificamos, então, que 187.927 são outliers considerando a quantidade de seus Seguidores, o que mostra que, de forma macro, os artistas têm padrões de quantidade de seguidores muito diferentes entre si
# 5.   É possível perceber que, quanto maior o número de Seguidores, menor a quantidade de Artistas com tal atributo

# %% [markdown]
# # - artist genres : gêneros musicais do artista

# %% [markdown]
# TRANSFORMANDO A COLUNA DE GÊNEROS EM LISTA

# %%
df_artists['genres'] = list(df_artists['genres'].replace('[]', 'not specified'))

# %%
for char in ["[", "]", "'", "\""]:
  df_artists['genres'] = df_artists['genres'].str.replace(char, "")
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.

# %%
df_artists['genres'] = df_artists['genres'].str.split(", ")

# %% [markdown]
# CRIAÇÃO DE UM DATAFRAME ESPECÍFICO DE GÊNEROS MUSICAIS

# %%
genres = df_artists.explode('genres')['genres']

# %%
df_genres = pd.DataFrame(np.sort(genres.unique()), columns=['genre_name'])

# %%
pd.set_option('display.max_rows', None)
print(df_genres)
pd.reset_option('display.max_rows')
# Out:
#                                    genre_name
# 0                      21st century classical
# 1                                       432hz
# 2                                         48g
# 3                                       8-bit
# 4                                          8d
# 5                                  a cappella
# 6                                          a3
# 7                                aarhus indie
# 8                              aberdeen indie
# 9                                    abstract
# 10                             abstract beats
# 11                           abstract hip hop
# 12                               abstract idm
# 13                                 abstractro
# 14                                  accordeon
# 15                                  accordion
# 16                                 acid house
# 17                                   acid idm
# 18                                  acid jazz
# 19                                  acid rock
# 20                                acid techno
# 21                                acid trance
# 22                                   acidcore
# 23                                 acousmatic
# 24                             acoustic blues
# 25                             acoustic chill
# 26                      acoustic guitar cover
# 27                               acoustic opm
# 28                               acoustic pop
# 29                              acoustic punk
# 30                              acoustic rock
# 31                                action rock
# 32                                     actors
# 33                             adelaide indie
# 34                                   adoracao
# 35                                  adoracion
# 36                            adult standards
# 37                                 adventista
# 38                                 afghan pop
# 39                         afghan traditional
# 40                         african electronic
# 41                       african experimental
# 42                             african gospel
# 43                              african metal
# 44                         african percussion
# 45                             african reggae
# 46                               african rock
# 47                 african-american classical
# 48                                  afrikaans
# 49                             afrikaans folk
# 50                           afrikaans gospel
# 51                             afro dancehall
# 52                                 afro house
# 53                                 afro psych
# 54                                   afro r&b
# 55                                  afro soul
# 56                     afro-cuban traditional
# 57                                  afro-funk
# 58                                   afrobeat
# 59                        afrobeat brasileiro
# 60                            afrobeat fusion
# 61                               afrofuturism
# 62                   afrofuturismo brasileiro
# 63                                    afropop
# 64                                  afroswing
# 65                              aggro chileno
# 66                                  aggrotech
# 67                           aghani lil-atfal
# 68                                         ai
# 69                                    aikatsu
# 70                                  ainu folk
# 71                              alabama indie
# 72                              alabama metal
# 73                                alabama rap
# 74                               alaska indie
# 75                              albanian folk
# 76                           albanian hip hop
# 77                     albanian iso polyphony
# 78                               albanian pop
# 79                            albany ny indie
# 80                            alberta country
# 81                            alberta hip hop
# 82                                 album rock
# 83                          albuquerque indie
# 84                              algerian folk
# 85                                    alphorn
# 86                            alpine yodeling
# 87                                      alt z
# 88                                   alt-idol
# 89                                       alte
# 90                      alternative americana
# 91                            alternative ccm
# 92                        alternative country
# 93                          alternative dance
# 94                            alternative emo
# 95                       alternative hardcore
# 96                        alternative hip hop
# 97                          alternative metal
# 98                      alternative metalcore
# 99                            alternative pop
# 100                      alternative pop rock
# 101                           alternative r&b
# 102                          alternative rock
# 103                    alternative roots rock
# 104                                  amapiano
# 105                                    ambeat
# 106                                   ambient
# 107                       ambient black metal
# 108                        ambient dub techno
# 109                              ambient folk
# 110                            ambient fusion
# 111                             ambient house
# 112                               ambient idm
# 113                        ambient industrial
# 114                               ambient pop
# 115                          ambient psychill
# 116                            ambient techno
# 117                            ambient trance
# 118                           ambient worship
# 119           american 21st century classical
# 120                            american choir
# 121                  american classical piano
# 122           american contemporary classical
# 123                      american early music
# 124                     american folk revival
# 125                        american grindcore
# 126                        american metalcore
# 127                 american modern classical
# 128                               american oi
# 129                        american orchestra
# 130                        american post-rock
# 131                        american primitive
# 132                      american romanticism
# 133                         american shoegaze
# 134                               amharic pop
# 135                              anadolu rock
# 136                              anarcho-punk
# 137                     ancient mediterranean
# 138                      andalusian classical
# 139                              andean flute
# 140                          anglican liturgy
# 141                            animal singing
# 142                                     anime
# 143                                  anime cv
# 144                                anime game
# 145                              anime latino
# 146                                anime rock
# 147                               anime score
# 148                           ann arbor indie
# 149                                    anthem
# 150                                anthem emo
# 151                            anthem worship
# 152                                 anti-folk
# 153                              antideutsche
# 154                     antilliaanse folklore
# 155                          antilliaanse rap
# 156                             antiviral pop
# 157                         apostolic worship
# 158                          appalachian folk
# 159                          appenzeller folk
# 160                          arab alternative
# 161                           arab electronic
# 162                         arab experimental
# 163                                 arab folk
# 164                               arab groove
# 165                                arab metal
# 166                                  arab pop
# 167                                 arab trap
# 168                                   arabesk
# 169                            arabic hip hop
# 170                               arabic jazz
# 171                argentine alternative rock
# 172                         argentine ambient
# 173                        argentine hardcore
# 174                     argentine heavy metal
# 175                         argentine hip hop
# 176                           argentine indie
# 177                      argentine indie rock
# 178                            argentine jazz
# 179                           argentine metal
# 180                            argentine punk
# 181                          argentine reggae
# 182                            argentine rock
# 183                         argentine telepop
# 184                              arizona punk
# 185                          arkansas country
# 186                          arkansas hip hop
# 187                            arkansas indie
# 188                            arkansas metal
# 189                             armenian folk
# 190                          armenian hip hop
# 191                              armenian pop
# 192                               arpa grande
# 193                            arpa paraguaya
# 194                             ars subtilior
# 195                                   art pop
# 196                                  art punk
# 197                                  art rock
# 198                                  art song
# 199                                    asakaa
# 200                         asbury park indie
# 201                           asheville indie
# 202                    asian american hip hop
# 203                                      asmr
# 204                              assamese pop
# 205                              assyrian pop
# 206                              athens indie
# 207                               atl hip hop
# 208                                  atl trap
# 209                             atlanta indie
# 210                             atlanta metal
# 211                              atlanta punk
# 212                                atmosphere
# 213                   atmospheric black metal
# 214                           atmospheric dnb
# 215                          atmospheric doom
# 216                    atmospheric post-metal
# 217                     atmospheric post-rock
# 218                        atmospheric sludge
# 219                            auckland indie
# 220                          audiophile vocal
# 221                              aussie drill
# 222                                aussie emo
# 223                             aussietronica
# 224                          austin americana
# 225                            austin hip hop
# 226                               austin rock
# 227                  austin singer-songwriter
# 228                                 austindie
# 229                australian alternative pop
# 230               australian alternative rock
# 231                        australian ambient
# 232                      australian americana
# 233                    australian black metal
# 234                          australian blues
# 235                australian childrens music
# 236                          australian choir
# 237                      australian classical
# 238                australian classical piano
# 239                         australian comedy
# 240                        australian country
# 241                          australian dance
# 242                    australian death metal
# 243                     australian electropop
# 244                   australian experimental
# 245                    australian garage punk
# 246                       australian hardcore
# 247                        australian hip hop
# 248                          australian house
# 249                          australian indie
# 250                     australian indie folk
# 251                     australian indie rock
# 252                     australian indigenous
# 253                           australian jazz
# 254                          australian metal
# 255                      australian metalcore
# 256                            australian pop
# 257                  australian post-hardcore
# 258                      australian post-punk
# 259                      australian post-rock
# 260                          australian psych
# 261                            australian r&b
# 262                  australian reggae fusion
# 263                           australian rock
# 264                     australian rockabilly
# 265                       australian shoegaze
# 266              australian singer-songwriter
# 267                            australian ska
# 268                    australian talent show
# 269                         australian techno
# 270                   australian thrash metal
# 271                           australian trap
# 272            australian underground hip hop
# 273                      austrian black metal
# 274                            austrian choir
# 275                  austrian classical piano
# 276           austrian contemporary classical
# 277                              austrian dnb
# 278                          austrian hip hop
# 279                            austrian indie
# 280                             austrian jazz
# 281                            austrian metal
# 282                        austrian orchestra
# 283                              austrian pop
# 284                             austrian punk
# 285                      austrian stoner rock
# 286                           austrian techno
# 287                   austro-german modernism
# 288                                 austropop
# 289   auteur-compositeur-interprete quebecois
# 290                                  autoharp
# 291                    autonomous black metal
# 292                               avant-garde
# 293                   avant-garde black metal
# 294                          avant-garde jazz
# 295                         avant-garde metal
# 296                                avant-rock
# 297                                       axe
# 298                                 azeri pop
# 299                                 azeri rap
# 300                         azeri traditional
# 301                                    azonto
# 302                               azontobeats
# 303                                   bachata
# 304                        bachata dominicana
# 305                           background jazz
# 306                          background music
# 307                          background piano
# 308                             backing track
# 309                                   baglama
# 310                                   bagpipe
# 311                     bagpipe marching band
# 312                                     bahai
# 313                             bahamian folk
# 314                              bahamian pop
# 315                                     baiao
# 316                              baithak gana
# 317                                baja indie
# 318                                     bajki
# 319                         bakersfield sound
# 320                               bal-musette
# 321                                   balafon
# 322                                 balalaika
# 323                                  balearic
# 324                                   balfolk
# 325                      balinese traditional
# 326                              balkan brass
# 327                    balkan classical piano
# 328                         balkan folk metal
# 329                            balkan hip hop
# 330                               balkan trap
# 331                              ballet class
# 332                                  ballroom
# 333                        baltic black metal
# 334                              baltic choir
# 335                          baltic classical
# 336                    baltic classical piano
# 337                               baltic folk
# 338                         baltimore hip hop
# 339                           baltimore indie
# 340                              baluchi folk
# 341                                band organ
# 342                                     banda
# 343                            banda caliente
# 344                         banda carnavalera
# 345                                 bandinhas
# 346                                  bandolim
# 347                                 bandoneon
# 348                           bangalore indie
# 349                                    bangla
# 350                       bangladeshi hip hop
# 351                         bangladeshi indie
# 352                          bangladeshi rock
# 353                                     banjo
# 354                                   bansuri
# 355                                      baps
# 356                            baptist gospel
# 357                             barbadian pop
# 358                                barbershop
# 359                                      bard
# 360                                  bardcore
# 361                                  barnalog
# 362                                barnasogur
# 363                               barnemusikk
# 364                                 barnmusik
# 365                                 barnsagor
# 366                         barockinterpreten
# 367                                   baroque
# 368                             baroque brass
# 369                             baroque cello
# 370                          baroque ensemble
# 371                               baroque pop
# 372                           baroque singing
# 373                            baroque violin
# 374                          baroque woodwind
# 375                         barrelhouse piano
# 376                               basel indie
# 377                               basque folk
# 378                                bass house
# 379                                bass music
# 380                                 bass trap
# 381                                 bass trip
# 382                                  basshall
# 383                                  bassline
# 384                                     batak
# 385                                bath indie
# 386                                    batida
# 387                         batidao romantico
# 388                         baton rouge indie
# 389                           baton rouge rap
# 390                                battle rap
# 391                          bay area hip hop
# 392                            bay area indie
# 393                           bayerischer rap
# 394                                      bboy
# 395                    bc underground hip hop
# 396                               beach house
# 397                               beach music
# 398                             beat italiano
# 399                               beat poetry
# 400                                beatboxing
# 401                                  beatdown
# 402                                beatlesque
# 403                                     beats
# 404                                     bebop
# 405                               bedroom pop
# 406                              bedroom soul
# 407                     belarusian electronic
# 408                        belarusian hip hop
# 409                          belarusian indie
# 410                          belarusian metal
# 411                            belarusian pop
# 412                           belarusian punk
# 413                           belarusian rock
# 414                             belfast indie
# 415                             belfast metal
# 416                       belgian black metal
# 417                             belgian blues
# 418                   belgian classical piano
# 419            belgian contemporary classical
# 420                             belgian dance
# 421                       belgian death metal
# 422                               belgian dnb
# 423                               belgian edm
# 424                      belgian experimental
# 425                          belgian hardcore
# 426                           belgian hip hop
# 427                             belgian indie
# 428                        belgian indie rock
# 429                              belgian jazz
# 430                             belgian metal
# 431                       belgian modern jazz
# 432                          belgian new wave
# 433                               belgian pop
# 434                         belgian post-rock
# 435                              belgian punk
# 436                              belgian rock
# 437                 belgian singer-songwriter
# 438                       belgian stoner rock
# 439                            belgian techno
# 440                                     bells
# 441                               belly dance
# 442                      belo horizonte indie
# 443                                    bemani
# 444                                     benga
# 445                              bengali folk
# 446                              beninese pop
# 447                             bergamo indie
# 448                              bergen indie
# 449                     berlin minimal techno
# 450                             berlin school
# 451                                bern indie
# 452                            bernu dziesmas
# 453                                    bhajan
# 454                                   bhangra
# 455                              bhojpuri pop
# 456                             bhutanese pop
# 457                                     bible
# 458                                  big band
# 459                                  big beat
# 460                                  big room
# 461                                   bikutsi
# 462                                  binaural
# 463                                  birdsong
# 464                          birmingham grime
# 465                        birmingham hip hop
# 466                          birmingham indie
# 467                          birmingham metal
# 468                                  birthday
# 469                              bisaya indie
# 470                                bisaya rap
# 471                                   bisrock
# 472                                    bitpop
# 473                              black comedy
# 474                               black death
# 475                               black metal
# 476                     black metal argentino
# 477                              black n roll
# 478                               black noise
# 479                                black punk
# 480                              black sludge
# 481                         black speed metal
# 482                              black thrash
# 483                           blackened crust
# 484                       blackened deathcore
# 485                        blackened hardcore
# 486                                 blackgaze
# 487                               blaskapelle
# 488                                 blasmusik
# 489                              bleep techno
# 490                                     bloco
# 491                                 bluegrass
# 492                          bluegrass fiddle
# 493                          bluegrass gospel
# 494                                     blues
# 495                                blues band
# 496                     blues latinoamericano
# 497                            blues mexicano
# 498                                blues rock
# 499                         blues-rock guitar
# 500                                     bmore
# 501                                  bodo pop
# 502                               boeremusiek
# 503                               bogor indie
# 504                          bohemian baroque
# 505                               bohol indie
# 506                                    bolero
# 507                             bolero cubano
# 508                           bolero mexicano
# 509                            bolivian metal
# 510                             bolivian rock
# 511                             bomba y plena
# 512                               bongo flava
# 513                                  boogaloo
# 514                                    boogie
# 515                             boogie-woogie
# 516                                  boom bap
# 517                       boom bap brasileiro
# 518                            bornehistorier
# 519                                bornesange
# 520                        bosnian electronic
# 521                             bosnian indie
# 522                                bossa nova
# 523                          bossa nova cover
# 524                           bossa nova jazz
# 525                         boston electronic
# 526                               boston folk
# 527                           boston hardcore
# 528                            boston hip hop
# 529                              boston indie
# 530                              boston metal
# 531                               boston punk
# 532                               boston rock
# 533                              bothy ballad
# 534                              botswana pop
# 535                             botswanan pop
# 536                                    bounce
# 537                              bouncy house
# 538                                  bouzouki
# 539                                   bow pop
# 540                                  boy band
# 541                                   boy pop
# 542                               boy soprano
# 543                                    bozlak
# 544                               brain waves
# 545                                braindance
# 546                            brasilia indie
# 547                                brass band
# 548                     brass band brasileiro
# 549                            brass ensemble
# 550                             brass quintet
# 551                            brazilian bass
# 552                     brazilian black metal
# 553                           brazilian blues
# 554                          brazilian boogie
# 555                             brazilian ccm
# 556                       brazilian classical
# 557                 brazilian classical piano
# 558          brazilian contemporary classical
# 559                     brazilian death metal
# 560                             brazilian dnb
# 561                      brazilian doom metal
# 562                             brazilian edm
# 563                             brazilian emo
# 564                    brazilian experimental
# 565                          brazilian gospel
# 566                       brazilian grindcore
# 567                    brazilian groove metal
# 568                        brazilian hardcore
# 569                     brazilian heavy metal
# 570                         brazilian hip hop
# 571                           brazilian house
# 572                           brazilian indie
# 573                      brazilian indie rock
# 574                            brazilian jazz
# 575                      brazilian lo-fi rock
# 576                           brazilian metal
# 577                       brazilian metalcore
# 578                     brazilian modern jazz
# 579                      brazilian percussion
# 580                   brazilian post-hardcore
# 581                       brazilian post-rock
# 582                     brazilian power metal
# 583               brazilian progressive metal
# 584                            brazilian punk
# 585                       brazilian punk rock
# 586                          brazilian reggae
# 587                            brazilian rock
# 588                      brazilian rockabilly
# 589                             brazilian ska
# 590                            brazilian soul
# 591                     brazilian stoner rock
# 592                       brazilian surf rock
# 593                      brazilian tech house
# 594                          brazilian techno
# 595                    brazilian thrash metal
# 596                                 breakbeat
# 597                                 breakcore
# 598                                    breaks
# 599                                     brega
# 600                                brega funk
# 601                           brega romantico
# 602                               breton folk
# 603                            brighton indie
# 604                        brill building pop
# 605                            brisbane indie
# 606                        bristol electronic
# 607                             bristol indie
# 608                                 brit funk
# 609                  british alternative rock
# 610                       british black metal
# 611                             british blues
# 612                        british brass band
# 613                   british childrens music
# 614                             british choir
# 615                   british classical piano
# 616                            british comedy
# 617            british contemporary classical
# 618                           british country
# 619                        british dance band
# 620                       british death metal
# 621                   british electroacoustic
# 622                      british experimental
# 623                              british folk
# 624                         british grindcore
# 625                        british indie rock
# 626                        british industrial
# 627                          british invasion
# 628                              british jazz
# 629                         british math rock
# 630                  british modern classical
# 631                         british orchestra
# 632                         british post-rock
# 633                       british power metal
# 634                 british singer-songwriter
# 635                              british soul
# 636                        british soundtrack
# 637                                   britpop
# 638                                  broadway
# 639                          brockton hip hop
# 640                               broken beat
# 641                             bronx hip hop
# 642                            brooklyn drill
# 643                            brooklyn indie
# 644                                   brostep
# 645                              bruneian pop
# 646                        brutal death metal
# 647                          brutal deathcore
# 648                             bubble trance
# 649                              bubblegrunge
# 650                           bubblegum dance
# 651                             bubblegum pop
# 652                           buffalo hip hop
# 653                          buffalo ny indie
# 654                          buffalo ny metal
# 655                      bulgarian electronic
# 656                    bulgarian experimental
# 657                            bulgarian folk
# 658                         bulgarian hip hop
# 659                           bulgarian indie
# 660                           bulgarian metal
# 661                             bulgarian pop
# 662                            bulgarian rock
# 663                             burkinabe pop
# 664                     burkinabe traditional
# 665                               burmese pop
# 666                       burmese traditional
# 667                             burundian pop
# 668                     burundian traditional
# 669                     bury st edmunds indie
# 670                               bush ballad
# 671                                 byzantine
# 672                                     c-pop
# 673                                       c64
# 674                                       c86
# 675                                   cabaret
# 676                                     cajun
# 677                             calgary indie
# 678                                  cali rap
# 679                       california hardcore
# 680                      calming instrumental
# 681                                   calypso
# 682                             cambodian pop
# 683                            cambodian rock
# 684                     cambodian traditional
# 685                           cambridge choir
# 686                      cambridgeshire indie
# 687                       cameroonian hip hop
# 688                           cameroonian pop
# 689                                campursari
# 690                        canadian americana
# 691                      canadian black metal
# 692                            canadian blues
# 693                              canadian ccm
# 694                           canadian celtic
# 695                  canadian childrens music
# 696                            canadian choir
# 697                        canadian classical
# 698                  canadian classical piano
# 699                           canadian comedy
# 700             canadian contemporary country
# 701                 canadian contemporary r&b
# 702                          canadian country
# 703                      canadian death metal
# 704                       canadian electronic
# 705                       canadian electropop
# 706                     canadian experimental
# 707                             canadian folk
# 708                      canadian garage rock
# 709                         canadian hardcore
# 710                          canadian hip hop
# 711                            canadian house
# 712                            canadian indie
# 713                       canadian indie folk
# 714                       canadian indigenous
# 715               canadian indigenous hip hop
# 716                            canadian latin
# 717                            canadian metal
# 718                        canadian metalcore
# 719                      canadian modern jazz
# 720               canadian old school hip hop
# 721                              canadian pop
# 722                         canadian pop punk
# 723                    canadian post-hardcore
# 724                        canadian post-punk
# 725                        canadian post-rock
# 726                      canadian psychedelic
# 727                 canadian psychedelic rock
# 728                             canadian punk
# 729                             canadian rock
# 730                       canadian rockabilly
# 731                         canadian shoegaze
# 732                canadian singer-songwriter
# 733                       canadian soundtrack
# 734                      canadian stoner rock
# 735                            canberra indie
# 736                 cancion infantil mexicana
# 737                          cancion melodica
# 738                          cancoes infantis
# 739                                  candombe
# 740                                 candomble
# 741                                 candy pop
# 742                                cantaditas
# 743                                 cantautor
# 744                          cantautor catala
# 745                          cante alentejano
# 746                            cante flamenco
# 747                          canterbury scene
# 748                              canti alpini
# 749                            canto a tenore
# 750                    canto popular uruguayo
# 751                           cantonese opera
# 752                     cantonese traditional
# 753                         cantonese worship
# 754                                  cantopop
# 755                           canzone dautore
# 756                          canzone genovese
# 757                        canzone napoletana
# 758                          cape breton folk
# 759                         cape breton indie
# 760                           cape town indie
# 761                         cape verdean folk
# 762                                  capoeira
# 763                             caracas indie
# 764                             cardiff indie
# 765                           caribbean metal
# 766                                   carimbo
# 767                                  carnatic
# 768                     carnatic instrumental
# 769                            carnatic vocal
# 770                                  carnaval
# 771                            carnaval cadiz
# 772                          carnaval limburg
# 773                                   cartoon
# 774                     cascadian black metal
# 775                              catalan folk
# 776                           cathedral choir
# 777                       caucasian classical
# 778                 caucasian classical piano
# 779                            caucasian folk
# 780                     cavernous death metal
# 781                                       ccm
# 782                                cdmx indie
# 783                                      cedm
# 784                                   ceilidh
# 785                                     cello
# 786                                    celtic
# 787                               celtic harp
# 788                              celtic metal
# 789                               celtic punk
# 790                               celtic rock
# 791                    central american metal
# 792                        central asian folk
# 793                          cerkes muzikleri
# 794                               cha-cha-cha
# 795                           chaabi algerien
# 796                           chaabi marocain
# 797                                    chakra
# 798                                    chalga
# 799                                   chamame
# 800                         chamame brasilero
# 801                             chamber choir
# 802                          chamber ensemble
# 803                              chamber folk
# 804                         chamber orchestra
# 805                               chamber pop
# 806                             chamber psych
# 807                                  champeta
# 808                     channel islands indie
# 809                               channel pop
# 810                                   chanson
# 811                         chanson paillarde
# 812                         chanson quebecois
# 813                            chanson virale
# 814                              chant basque
# 815                           chant religieux
# 816                       chaotic black metal
# 817                          chaotic hardcore
# 818                                  charanga
# 819                                  charango
# 820                        charlotte nc indie
# 821                     charlottesville indie
# 822                             charred death
# 823                         chattanooga indie
# 824                               chechen pop
# 825                             chennai indie
# 826                         chhattisgarhi pop
# 827                             chicago blues
# 828                             chicago drill
# 829                          chicago hardcore
# 830                             chicago house
# 831                             chicago indie
# 832                          chicago pop punk
# 833                              chicago punk
# 834                               chicago rap
# 835                              chicago soul
# 836                              chicano punk
# 837                               chicano rap
# 838                                    chicha
# 839                           chihuahua indie
# 840                           childrens choir
# 841                            childrens folk
# 842                           childrens music
# 843                           childrens story
# 844                       chilean black metal
# 845                          chilean hardcore
# 846                             chilean indie
# 847                             chilean metal
# 848                              chilean rock
# 849                                   chilena
# 850                               chill baile
# 851                               chill beats
# 852                              chill groove
# 853                              chill guitar
# 854                              chill lounge
# 855                                 chill out
# 856                                 chill pop
# 857                                 chill r&b
# 858                          chill-out trance
# 859                                  chillhop
# 860                                 chillstep
# 861                                 chillwave
# 862                             chinderlieder
# 863                        chinese audiophile
# 864                         chinese classical
# 865             chinese classical performance
# 866                   chinese classical piano
# 867                         chinese drama ost
# 868                        chinese electronic
# 869                        chinese electropop
# 870                      chinese experimental
# 871                              chinese folk
# 872                           chinese hip hop
# 873                          chinese idol pop
# 874                             chinese indie
# 875                         chinese indie pop
# 876                        chinese indie rock
# 877                      chinese instrumental
# 878                              chinese jazz
# 879                            chinese manyao
# 880                             chinese metal
# 881                            chinese minyao
# 882                          chinese new year
# 883                             chinese opera
# 884                         chinese post-punk
# 885                         chinese post-rock
# 886                              chinese punk
# 887                               chinese r&b
# 888                 chinese singer-songwriter
# 889                        chinese soundtrack
# 890                       chinese traditional
# 891                         chinese viral pop
# 892                              chinese wind
# 893                           chinese worship
# 894                                  chip hop
# 895                                  chiptune
# 896                       chopped and screwed
# 897                                    choral
# 898                                     choro
# 899                       choro contemporaneo
# 900                        christchurch indie
# 901                               christelijk
# 902                      christian a cappella
# 903                        christian afrobeat
# 904                christian alternative rock
# 905                           christian dance
# 906                       christian deathcore
# 907                       christian hard rock
# 908                        christian hardcore
# 909                         christian hip hop
# 910                           christian indie
# 911                           christian metal
# 912                       christian metalcore
# 913                           christian music
# 914                             christian pop
# 915                     christian power metal
# 916                            christian punk
# 917                      christian relaxative
# 918                            christian rock
# 919                 christian symphonic metal
# 920                    christian thrash metal
# 921                            christian trap
# 922                          christian uplift
# 923                          christlicher rap
# 924                    christmas instrumental
# 925                         christmas product
# 926                                 chunchaca
# 927                                   chutney
# 928                                   cifteli
# 929                                  cimbalom
# 930                          cimbalova muzika
# 931                          cincinnati indie
# 932                            cincinnati rap
# 933                         cinematic dubstep
# 934                       cinematic post-rock
# 935                           circassian folk
# 936                                   circuit
# 937                                    circus
# 938                                  city pop
# 939                          classic afrobeat
# 940                             classic anime
# 941                          classic arab pop
# 942                classic australian country
# 943                         classic azeri pop
# 944                       classic belgian pop
# 945                           classic bhangra
# 946                         classic bollywood
# 947                     classic bulgarian pop
# 948                     classic canadian rock
# 949                          classic cantopop
# 950                          classic city pop
# 951                     classic colombian pop
# 952                       classic country pop
# 953                         classic czech pop
# 954                        classic danish pop
# 955                       classic danish rock
# 956                           classic dubstep
# 957                         classic dutch pop
# 958                        classic eurovision
# 959                       classic finnish pop
# 960                      classic finnish rock
# 961                        classic french pop
# 962                       classic garage rock
# 963                        classic girl group
# 964                         classic greek pop
# 965                        classic greek rock
# 966                         classic hardstyle
# 967                             classic house
# 968                     classic hungarian pop
# 969                    classic hungarian rock
# 970                     classic icelandic pop
# 971                          classic indo pop
# 972                   classic indonesian rock
# 973                           classic iskelma
# 974                       classic israeli pop
# 975                  classic italian folk pop
# 976                       classic italian pop
# 977                             classic j-pop
# 978                            classic j-rock
# 979                     classic japanese jazz
# 980                             classic k-pop
# 981                         classic kollywood
# 982                       classic konkani pop
# 983                        classic korean pop
# 984                       classic latvian pop
# 985                         classic luk thung
# 986                     classic malaysian pop
# 987                          classic mandopop
# 988                      classic moroccan pop
# 989                        classic nepali pop
# 990                     classic norwegian pop
# 991                        classic nz country
# 992                            classic nz pop
# 993                               classic opm
# 994                     classic pakistani pop
# 995                       classic persian pop
# 996                      classic peruvian pop
# 997                        classic polish pop
# 998                    classic portuguese pop
# 999                            classic praise
# 1000                classic progressive house
# 1001                 classic psychedelic rock
# 1002                      classic punjabi pop
# 1003                             classic rock
# 1004                      classic russian pop
# 1005                     classic russian rock
# 1006                         classic schlager
# 1007                      classic sinhala pop
# 1008                             classic soul
# 1009                       classic soundtrack
# 1010                      classic swedish pop
# 1011                         classic thai pop
# 1012                        classic tollywood
# 1013                     classic tunisian pop
# 1014                      classic turkish pop
# 1015                           classic uk pop
# 1016                   classic venezuelan pop
# 1017                                classical
# 1018                      classical accordion
# 1019                       classical baritone
# 1020                           classical bass
# 1021                        classical bassoon
# 1022                          classical cello
# 1023                       classical clarinet
# 1024                      classical contralto
# 1025                   classical countertenor
# 1026                            classical era
# 1027                          classical flute
# 1028                         classical guitar
# 1029                     classical guitar duo
# 1030                 classical guitar quartet
# 1031                           classical harp
# 1032                           classical horn
# 1033                    classical jazz fusion
# 1034                       classical mandolin
# 1035                  classical mezzo-soprano
# 1036                           classical oboe
# 1037                          classical organ
# 1038                     classical percussion
# 1039                    classical performance
# 1040                          classical piano
# 1041                      classical piano duo
# ...
# 5019                              trio cubano
# 5020                            trio huasteco
# 5021                                 trip hop
# 5022                                   trival
# 5023                      trombone brasileiro
# 5024                         trondersk musikk
# 5025                          trondheim indie
# 5026                                 tropical
# 5027                           tropical house
# 5028                               tropicalia
# 5029                                     trot
# 5030                               troubadour
# 5031                                 trouvere
# 5032                                    trova
# 5033                           trova mexicana
# 5034                    truck-driving country
# 5035                                 tsukiuta
# 5036                            tuareg guitar
# 5037                             tucson indie
# 5038                              tulsa indie
# 5039                                    tulum
# 5040                                     tuna
# 5041                         tuna estudiantil
# 5042                             tunisian pop
# 5043                               turbo folk
# 5044                              turin indie
# 5045                             turkce drill
# 5046                             turkce remix
# 5047                        turkce trap metal
# 5048                          turkish alt pop
# 5049                      turkish alternative
# 5050                 turkish alternative rock
# 5051                      turkish black metal
# 5052                        turkish classical
# 5053            turkish classical performance
# 5054                              turkish edm
# 5055                       turkish electronic
# 5056                     turkish experimental
# 5057                             turkish folk
# 5058                          turkish hip hop
# 5059                     turkish instrumental
# 5060                             turkish jazz
# 5061                            turkish metal
# 5062                      turkish modern jazz
# 5063                              turkish pop
# 5064                        turkish post-punk
# 5065                            turkish psych
# 5066                             turkish punk
# 5067                           turkish reggae
# 5068                             turkish rock
# 5069                turkish singer-songwriter
# 5070                       turkish soundtrack
# 5071                             turkish trap
# 5072                         turkish trap pop
# 5073                              turntablism
# 5074                               tuvan folk
# 5075                           twee indie pop
# 5076                                 twee pop
# 5077                        twin cities indie
# 5078                                twoubadou
# 5079                                   tzadik
# 5080                                uae indie
# 5081                              ugandan pop
# 5082                      ugandan traditional
# 5083                           uilleann pipes
# 5084                   uk alternative hip hop
# 5085                       uk alternative pop
# 5086                             uk americana
# 5087                              uk beatdown
# 5088                         uk christian rap
# 5089                     uk contemporary jazz
# 5090                      uk contemporary r&b
# 5091                                 uk dance
# 5092                             uk dancehall
# 5093                              uk diy punk
# 5094                                   uk dnb
# 5095                            uk doom metal
# 5096                                 uk drill
# 5097                                   uk dub
# 5098               uk experimental electronic
# 5099                                 uk funky
# 5100                                uk garage
# 5101                               uk hip hop
# 5102                                 uk house
# 5103                             uk metalcore
# 5104                            uk noise rock
# 5105                                   uk pop
# 5106                              uk pop punk
# 5107                         uk post-hardcore
# 5108                            uk post-metal
# 5109                             uk post-punk
# 5110                     uk post-punk revival
# 5111                                uk reggae
# 5112                            uk rockabilly
# 5113                           uk stoner rock
# 5114                            uk tech house
# 5115                               uk worship
# 5116                                     uk82
# 5117                              ukg revival
# 5118                                     ukhc
# 5119                    ukrainian black metal
# 5120                          ukrainian choir
# 5121                      ukrainian classical
# 5122                ukrainian classical piano
# 5123                     ukrainian electronic
# 5124                   ukrainian experimental
# 5125                           ukrainian folk
# 5126                        ukrainian hip hop
# 5127                          ukrainian indie
# 5128                          ukrainian metal
# 5129                            ukrainian pop
# 5130                           ukrainian rock
# 5131                                  ukulele
# 5132                          ulkucu sarkilar
# 5133                                  umbanda
# 5134                            umea hardcore
# 5135                               umea indie
# 5136                            unblack metal
# 5137                      underground hip hop
# 5138                    underground power pop
# 5139                          underground rap
# 5140                         university choir
# 5141                         uplifting trance
# 5142                            uppsala indie
# 5143                         uptempo hardcore
# 5144                       urban contemporary
# 5145                           urbano espanol
# 5146                          uruguayan indie
# 5147                           us power metal
# 5148                                     usbm
# 5149                               utah indie
# 5150                               utah metal
# 5151                                   utapri
# 5152                              uwielbienie
# 5153                              uyghur folk
# 5154                                uzbek pop
# 5155                        uzbek traditional
# 5156                                    v-pop
# 5157                         vaikiskos dainos
# 5158                                vallenato
# 5159                        vallenato moderno
# 5160                          vancouver indie
# 5161                          vancouver metal
# 5162                           vancouver punk
# 5163                            vanuatu music
# 5164                              vapor house
# 5165                                vapor pop
# 5166                               vapor soul
# 5167                               vapor trap
# 5168                             vapor twitch
# 5169                                vaporwave
# 5170                                 vaqueiro
# 5171                        variete francaise
# 5172                            varmland rock
# 5173                               vaudeville
# 5174                                      vbs
# 5175                                    veena
# 5176                      vegan straight edge
# 5177                              vegas indie
# 5178                             velha guarda
# 5179                       venezuelan hip hop
# 5180                         venezuelan indie
# 5181                         venezuelan metal
# 5182                          venezuelan rock
# 5183                           veracruz indie
# 5184                            vermont indie
# 5185                         vgm instrumental
# 5186                                vgm remix
# 5187                                      via
# 5188                        victoria bc indie
# 5189                        victorian britain
# 5190                         video game music
# 5191                             vienna indie
# 5192                                 viet edm
# 5193                        viet instrumental
# 5194                               viet lo-fi
# 5195                        vietnamese bolero
# 5196                       vietnamese hip hop
# 5197                           vietnamese pop
# 5198             vietnamese singer-songwriter
# 5199                   vietnamese traditional
# 5200                       viking black metal
# 5201                              viking folk
# 5202                             viking metal
# 5203                              villancicos
# 5204                                vinahouse
# 5205                    vintage cantonese pop
# 5206                          vintage chanson
# 5207                      vintage chinese pop
# 5208                vintage classical singing
# 5209                     vintage country folk
# 5210                        vintage dutch pop
# 5211                     vintage finnish jazz
# 5212                vintage french electronic
# 5213                           vintage gospel
# 5214                         vintage hawaiian
# 5215                        vintage hollywood
# 5216                      vintage italian pop
# 5217               vintage italian soundtrack
# 5218                             vintage jazz
# 5219                    vintage norwegian pop
# 5220                         vintage old-time
# 5221                       vintage radio show
# 5222                           vintage reggae
# 5223                       vintage rockabilly
# 5224                         vintage schlager
# 5225                      vintage spanish pop
# 5226                      vintage swedish pop
# 5227                            vintage swing
# 5228                            vintage swoon
# 5229                       vintage taiwan pop
# 5230                            vintage tango
# 5231                          vintage western
# 5232                                    viola
# 5233                            viola caipira
# 5234                           viola da gamba
# 5235                                   violao
# 5236                          violao classico
# 5237                                   violin
# 5238                                viral pop
# 5239                     viral pop brasileiro
# 5240                                viral rap
# 5241                               viral trap
# 5242                    virgin islands reggae
# 5243                         virginia hip hop
# 5244                           virginia indie
# 5245                           virginia metal
# 5246                            virginia punk
# 5247                                    visor
# 5248                                   vispop
# 5249                               visual kei
# 5250                          vlaamse cabaret
# 5251                     vlaamse kinderliedje
# 5252                              vlaamse rap
# 5253                           vocal ensemble
# 5254                      vocal harmony group
# 5255                              vocal house
# 5256                               vocal jazz
# 5257                             vocal trance
# 5258                                 vocaloid
# 5259                                    vogue
# 5260                                 voidgaze
# 5261                                voidgrind
# 5262                               volksmusik
# 5263                                 volkspop
# 5264                      volkstumliche musik
# 5265                             waiata maori
# 5266                       waiata mo tamariki
# 5267                             wandelweiser
# 5268                                war metal
# 5269                               warm drone
# 5270                         warrington indie
# 5271                                washboard
# 5272                         washington indie
# 5273                                wassoulou
# 5274                                    water
# 5275                                     wave
# 5276                               weightless
# 5277                         wellington indie
# 5278                              welsh choir
# 5279                               welsh folk
# 5280                            welsh hip hop
# 5281                              welsh indie
# 5282                              welsh metal
# 5283                               welsh rock
# 5284                        west african jazz
# 5285                  west australian hip hop
# 5286                           west coast rap
# 5287                        west coast reggae
# 5288                          west coast trap
# 5289                                 west end
# 5290                      west virginia indie
# 5291                      west virginia metal
# 5292                     west yorkshire indie
# 5293                     west-vlaamse hip hop
# 5294                        western americana
# 5295                       western mass indie
# 5296                         western ny metal
# 5297                     western saharan folk
# 5298                            western swing
# 5299                               whale song
# 5300                              white noise
# 5301                            wind ensemble
# 5302                             wind quintet
# 5303                            wind symphony
# 5304                         windsor on indie
# 5305                         winnipeg hip hop
# 5306                          wisconsin indie
# 5307                          wisconsin metal
# 5308                              witch house
# 5309                             womens choir
# 5310                             womens music
# 5311                                    wonky
# 5312                       worcester ma indie
# 5313                          workout product
# 5314                                    world
# 5315                              world chill
# 5316                         world devotional
# 5317                             world fusion
# 5318                         world meditation
# 5319                            world worship
# 5320                                  worship
# 5321                                wrestling
# 5322                                    wrock
# 5323                                   wu fam
# 5324                              wuhan indie
# 5325                            wyoming indie
# 5326                            wyoming roots
# 5327                                    xhosa
# 5328                                   xinyao
# 5329                                 xtra raw
# 5330                               yacht rock
# 5331                                     yaoi
# 5332                                    ye ye
# 5333                               yemeni pop
# 5334                       yemeni traditional
# 5335                             yiddish folk
# 5336                                 yodeling
# 5337                                     yoga
# 5338                                     yoik
# 5339                               york indie
# 5340                           yorkshire folk
# 5341                          youth orchestra
# 5342                        yugoslav new wave
# 5343                            yugoslav rock
# 5344                       yunnan traditional
# 5345                                     yuri
# 5346                          zambian hip hop
# 5347                              zambian pop
# 5348                                 zampogna
# 5349                                      zen
# 5350                         zespol dzieciecy
# 5351                                    zeuhl
# 5352                            zhongguo feng
# 5353                                    zikir
# 5354                                zillertal
# 5355                               zim gospel
# 5356                              zim hip hop
# 5357                         zim urban groove
# 5358                             zimdancehall
# 5359                                   zither
# 5360                                     zolo
# 5361                                  zouglou
# 5362                                     zouk
# 5363                              zouk riddim
# 5364                             zurich indie
# 5365                                   zydeco

# %%
df_genres.to_csv('genres.csv', index=False)

# %% [markdown]
# **Conclusões:**
#
# 1.   Temos 5365 gêneros musicais do dataset (exceto 'não especificado')
# 2.   Muitos gêneros existentes são, na verdade, subdivisões de outros gêneros com base em regionalidades. Ex.: (ukrainian folk, ukrainian hip hop, ukrainian indie,  ukrainian metal, ukrainian pop)
# 3.   Existem 68 subgêneros apenas de musicas italianas, 59 suecas, 25 turcas, entre outros
# 4.   Talvez seja válido criar uma relação entre gêneros, assim como já existe entre os artistas, para criar recomendações

# %% [markdown]
# # - artist name : nome do artista

# %% [markdown]
# IDENTIFICANDO ARTISTAS DUPLICADOS

# %%
duplicated_artists = df_artists[df_artists.duplicated(subset=['name'])]
duplicated_artists
# Out:
#                              id  followers  \
# 556      2EIDNRLlK40vvt5EyhiwFE      12722
# 2363     6D40RuzdpIC5ip4yL2UUvD      12946
# 3029     7vOAn1z0BOIyxKV59lSUMp        303
# 3059     3F7y6OKpRQVTYknMF3weXr        931
# 3123     4ubUEsQ5s7FJpJthJjvop0       4929
# ...                         ...        ...
# 1104277  4wf6GGNBqaU79839E6yjfn       1182
# 1104279  0Iv7bsODzqbmMkC6pylYYN       8667
# 1104280  65kdSVYKtaef3P8EOCGWHl       6899
# 1104281  0iG7bYgNYz3PUqjAIrgiFu       2375
# 1104319  02rbtsxmzmlWKtEZ4DLZr8      10099
#
#                                                genres           name  \
# 556                                   [not specified]      Los Bonys
# 2363                                    [belgian pop]         Suarez
# 3029                                  [not specified]            BNR
# 3059                                 [bulgarian rock]         Signal
# 3123                              [bulgarian hip hop]          Spens
# ...                                               ...            ...
# 1104277                               [not specified]          Speed
# 1104279                 [mathcore, metallic hardcore]        Chamber
# 1104280  [australian post-hardcore, melodic hardcore]          Bloom
# 1104281                        [australian metalcore]         Graves
# 1104319     [australian indie, australian indie folk]  Patrick James
#
#          popularity
# 556              31
# 2363             37
# 3029             17
# 3059             19
# 3123             18
# ...             ...
# 1104277          15
# 1104279          28
# 1104280          34
# 1104281          15
# 1104319          36
#
# [25689 rows x 5 columns]

# %% [markdown]
# **Conclusões:**
#
# 1.   Existem diversos artistas com mesmo nome no catálogo do Spotify que se tratam, de fato, do mesmo artista com mais de um registro
# 2.   É importante que os artistas de nome duplicado não sejam excluídos do
# dataset, isso porque podem haver perdas ao gerar recomendações (exclusão de faixas do catálogo)

# %% [markdown]
# # - artist popularity : nível de popularidade do artista

# %%
df_artists['popularity'].describe()
# Out:
# count    1.104349e+06
# mean     9.083884e+00
# std      1.376310e+01
# min      0.000000e+00
# 25%      0.000000e+00
# 50%      2.000000e+00
# 75%      1.400000e+01
# max      1.000000e+02
# Name: popularity, dtype: float64

# %%
df_artists['popularity'].hist()

# %%
# Os 15 artistas com maior Popularidade

df_artists[['popularity', 'name']].sort_values('popularity', ascending=False).head(15)

        # Os 15 artistas com maior Popularidade
# Out:
#         popularity           name
# 144481         100  Justin Bieber
# 115489          98      Bad Bunny
# 126338          98   Taylor Swift
# 313676          98          Drake
# 144484          96            BTS
# 115490          96     Juice WRLD
# 144483          96     The Weeknd
# 144485          95  Ariana Grande
# 144486          95       J Balvin
# 115491          95    Myke Towers
# 144487          95       Dua Lipa
# 144488          94         Eminem
# 313813          94   Travis Scott
# 126409          93          Ozuna
# 313701          93       Lil Baby

# %%
# Os 15 maiores conjuntos de artistas, com base na Popularidade

df_artists['popularity'].value_counts().sort_values(ascending=False).head(15)
# Out:
# 0     467416
# 1      74593
# 2      47594
# 3      36371
# 4      29567
# 5      26680
# 6      23735
# 7      21119
# 8      19592
# 9      17615
# 10     16761
# 11     15795
# 12     15047
# 13     14393
# 14     13586
# Name: popularity, dtype: int64

# %%
df_artists.boxplot(column=['popularity'])

# %%
q1 = df_artists['popularity'].quantile(0.25)
q3 = df_artists['popularity'].quantile(0.75)

IQR = q3 - q1

# %%
popularity_outliers = q3 + 1.5 * IQR

# %%
len( df_artists[df_artists['popularity'] >= popularity_outliers] )
# Out:
# 82156

# %%
plt.figure(figsize=(10,6))
plt.scatter(df_artists['followers'], df_artists['popularity'])

plt.title('Correlação entre Popularidade e Quantidade de Seguidores')
plt.xlabel('Número de Seguidores')
plt.ylabel('Popularidade');

# %% [markdown]
# **Conclusões**
#
# 1.   Observa-se que a Popularidade é um item que varia de 0 a 100 no dataset
# 2.   Como é de se esperar, quanto maior o número de Seguidores, maior a Popularidade do Artista
# 3.   O artista com maior Popularidade (Justin Bieber), porém, não é o artista com maior nº de Seguidores (mas ocupa o 3º quartil, com 44 milhões de seguidores)
# 4.   75% de todos os artistas do dataset possuem Popularidade até 14, o que indica que o dataset é composto por artistas que, em sua maioria, possuem baixa Popularidade
# 5.   82.156 artistas são outliers, considerando a Popularidade

# %% [markdown]
# # DataFrame **Tracks**

# %%
df_tracks
# Out:
#                             id                                 name  \
# 0       35iwgR4jXetI318WEWsa1Q                                Carve
# 1       021ht4sdgPcrDgSk7JTbKY  Capítulo 2.16 - Banquero Anarquista
# 2       07A5yehtSnoedViJAZkNnc   Vivo para Quererte - Remasterizado
# 3       08FmqUhxtyLTn6pAh6bk45        El Prisionero - Remasterizado
# 4       08y9GfoqCWfOGsKdwojr5e                  Lady of the Evening
# ...                        ...                                  ...
# 586667  5rgu12WBIHQtvej2MdHSH0                                  云与海
# 586668  0NuWgxEp51CutD2pJoF4OM                                blind
# 586669  27Y1N4Q4U3EfDU5Ubw8ws2            What They'll Say About Us
# 586670  45XJsGpFTyzbzeWK8VzR8S                      A Day At A Time
# 586671  5Ocn6dZ3BJFPWh4ylwFXtn                     Mar de Emociones
#
#         popularity  duration_ms  explicit                          artists  \
# 0                6       126903         0                          ['Uli']
# 1                0        98200         0              ['Fernando Pessoa']
# 2                0       181640         0              ['Ignacio Corsini']
# 3                0       176907         0              ['Ignacio Corsini']
# 4                0       163080         0                  ['Dick Haymes']
# ...            ...          ...       ...                              ...
# 586667          50       258267         0                      ['阿YueYue']
# 586668          72       153293         0                   ['ROLE MODEL']
# 586669          70       187601         0                      ['FINNEAS']
# 586670          58       142003         0  ['Gentle Bones', 'Clara Benin']
# 586671          38       214360         0                    ['Afrosound']
#
#                                                id_artists release_date  \
# 0                              ['45tIt06XoI0Iio4LBEVpls']   1922-02-22
# 1                              ['14jtPCOoNZwquk5wd9DxrY']   1922-06-01
# 2                              ['5LiOoJbxVSAMkBS2fUm3X2']   1922-03-21
# 3                              ['5LiOoJbxVSAMkBS2fUm3X2']   1922-03-21
# 4                              ['3BiJGZsyX9sJchTqcSA7Su']         1922
# ...                                                   ...          ...
# 586667                         ['1QLBXKM5GCpyQQSVMNZqrZ']   2020-09-26
# 586668                         ['1dy5WNgIKQU6ezkpZs4y8z']   2020-10-21
# 586669                         ['37M5pPGs6V1fchFJSgCguX']   2020-09-02
# 586670  ['4jGPdu95icCKVF31CcFKbS', '5ebPSE9YI5aLeZ1Z2g...   2021-03-05
# 586671                         ['0i4Qda0k4nf7jnNHmSNpYv']   2015-07-01
#
#         danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0              0.645  0.4450    0   -13.338     1       0.4510         0.674
# 1              0.695  0.2630    0   -22.136     1       0.9570         0.797
# 2              0.434  0.1770    1   -21.180     1       0.0512         0.994
# 3              0.321  0.0946    7   -27.961     1       0.0504         0.995
# 4              0.402  0.1580    3   -16.900     0       0.0390         0.989
# ...              ...     ...  ...       ...   ...          ...           ...
# 586667         0.560  0.5180    0    -7.471     0       0.0292         0.785
# 586668         0.765  0.6630    0    -5.223     1       0.0652         0.141
# 586669         0.535  0.3140    7   -12.823     0       0.0408         0.895
# 586670         0.696  0.6150   10    -6.212     1       0.0345         0.206
# 586671         0.686  0.7230    6    -7.067     1       0.0363         0.105
#
#         instrumentalness  liveness  valence    tempo  time_signature
# 0               0.744000    0.1510   0.1270  104.851               3
# 1               0.000000    0.1480   0.6550  102.009               1
# 2               0.021800    0.2120   0.4570  130.418               5
# 3               0.918000    0.1040   0.3970  169.980               3
# 4               0.130000    0.3110   0.1960  103.220               4
# ...                  ...       ...      ...      ...             ...
# 586667          0.000000    0.0648   0.2110  131.896               4
# 586668          0.000297    0.0924   0.6860  150.091               4
# 586669          0.000150    0.0874   0.0663  145.095               4
# 586670          0.000003    0.3050   0.4380   90.029               4
# 586671          0.000000    0.2640   0.9750  112.204               4
#
# [586672 rows x 20 columns]

# %%
df_tracks.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 586672 entries, 0 to 586671
# Data columns (total 20 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   id                586672 non-null  object
#  1   name              586601 non-null  object
#  2   popularity        586672 non-null  int64
#  3   duration_ms       586672 non-null  int64
#  4   explicit          586672 non-null  int64
#  5   artists           586672 non-null  object
#  6   id_artists        586672 non-null  object
#  7   release_date      586672 non-null  object
#  8   danceability      586672 non-null  float64
#  9   energy            586672 non-null  float64
#  10  key               586672 non-null  int64
#  11  loudness          586672 non-null  float64
#  12  mode              586672 non-null  int64
#  13  speechiness       586672 non-null  float64
#  14  acousticness      586672 non-null  float64
#  15  instrumentalness  586672 non-null  float64
#  16  liveness          586672 non-null  float64
#  17  valence           586672 non-null  float64
#  18  tempo             586672 non-null  float64
#  19  time_signature    586672 non-null  int64
# dtypes: float64(9), int64(6), object(5)
# memory usage: 89.5+ MB

# %% [markdown]
# 'NAME' É A ÚNICA COLUNA COM VALORES NaN

# %%
df_tracks.describe()
# Out:
#           popularity   duration_ms       explicit   danceability  \
# count  586672.000000  5.866720e+05  586672.000000  586672.000000
# mean       27.570053  2.300512e+05       0.044086       0.563594
# std        18.370642  1.265261e+05       0.205286       0.166103
# min         0.000000  3.344000e+03       0.000000       0.000000
# 25%        13.000000  1.750930e+05       0.000000       0.453000
# 50%        27.000000  2.148930e+05       0.000000       0.577000
# 75%        41.000000  2.638670e+05       0.000000       0.686000
# max       100.000000  5.621218e+06       1.000000       0.991000
#
#               energy            key       loudness           mode  \
# count  586672.000000  586672.000000  586672.000000  586672.000000
# mean        0.542036       5.221603     -10.206067       0.658797
# std         0.251923       3.519423       5.089328       0.474114
# min         0.000000       0.000000     -60.000000       0.000000
# 25%         0.343000       2.000000     -12.891000       0.000000
# 50%         0.549000       5.000000      -9.243000       1.000000
# 75%         0.748000       8.000000      -6.482000       1.000000
# max         1.000000      11.000000       5.376000       1.000000
#
#          speechiness   acousticness  instrumentalness       liveness  \
# count  586672.000000  586672.000000     586672.000000  586672.000000
# mean        0.104864       0.449863          0.113451       0.213935
# std         0.179893       0.348837          0.266868       0.184326
# min         0.000000       0.000000          0.000000       0.000000
# 25%         0.034000       0.096900          0.000000       0.098300
# 50%         0.044300       0.422000          0.000024       0.139000
# 75%         0.076300       0.785000          0.009550       0.278000
# max         0.971000       0.996000          1.000000       1.000000
#
#              valence          tempo  time_signature
# count  586672.000000  586672.000000   586672.000000
# mean        0.552292     118.464857        3.873382
# std         0.257671      29.764108        0.473162
# min         0.000000       0.000000        0.000000
# 25%         0.346000      95.600000        4.000000
# 50%         0.564000     117.384000        4.000000
# 75%         0.769000     136.321000        4.000000
# max         1.000000     246.381000        5.000000

# %%
df_tracks[df_tracks.duplicated()]
# Out:
# Empty DataFrame
# Columns: [id, name, popularity, duration_ms, explicit, artists, id_artists, release_date, danceability, energy, key, loudness, mode, speechiness, acousticness, instrumentalness, liveness, valence, tempo, time_signature]
# Index: []

# %%
df_tracks
# Out:
#                             id                                 name  \
# 0       35iwgR4jXetI318WEWsa1Q                                Carve
# 1       021ht4sdgPcrDgSk7JTbKY  Capítulo 2.16 - Banquero Anarquista
# 2       07A5yehtSnoedViJAZkNnc   Vivo para Quererte - Remasterizado
# 3       08FmqUhxtyLTn6pAh6bk45        El Prisionero - Remasterizado
# 4       08y9GfoqCWfOGsKdwojr5e                  Lady of the Evening
# ...                        ...                                  ...
# 586667  5rgu12WBIHQtvej2MdHSH0                                  云与海
# 586668  0NuWgxEp51CutD2pJoF4OM                                blind
# 586669  27Y1N4Q4U3EfDU5Ubw8ws2            What They'll Say About Us
# 586670  45XJsGpFTyzbzeWK8VzR8S                      A Day At A Time
# 586671  5Ocn6dZ3BJFPWh4ylwFXtn                     Mar de Emociones
#
#         popularity  duration_ms  explicit                          artists  \
# 0                6       126903         0                          ['Uli']
# 1                0        98200         0              ['Fernando Pessoa']
# 2                0       181640         0              ['Ignacio Corsini']
# 3                0       176907         0              ['Ignacio Corsini']
# 4                0       163080         0                  ['Dick Haymes']
# ...            ...          ...       ...                              ...
# 586667          50       258267         0                      ['阿YueYue']
# 586668          72       153293         0                   ['ROLE MODEL']
# 586669          70       187601         0                      ['FINNEAS']
# 586670          58       142003         0  ['Gentle Bones', 'Clara Benin']
# 586671          38       214360         0                    ['Afrosound']
#
#                                                id_artists release_date  \
# 0                              ['45tIt06XoI0Iio4LBEVpls']   1922-02-22
# 1                              ['14jtPCOoNZwquk5wd9DxrY']   1922-06-01
# 2                              ['5LiOoJbxVSAMkBS2fUm3X2']   1922-03-21
# 3                              ['5LiOoJbxVSAMkBS2fUm3X2']   1922-03-21
# 4                              ['3BiJGZsyX9sJchTqcSA7Su']         1922
# ...                                                   ...          ...
# 586667                         ['1QLBXKM5GCpyQQSVMNZqrZ']   2020-09-26
# 586668                         ['1dy5WNgIKQU6ezkpZs4y8z']   2020-10-21
# 586669                         ['37M5pPGs6V1fchFJSgCguX']   2020-09-02
# 586670  ['4jGPdu95icCKVF31CcFKbS', '5ebPSE9YI5aLeZ1Z2g...   2021-03-05
# 586671                         ['0i4Qda0k4nf7jnNHmSNpYv']   2015-07-01
#
#         danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0              0.645  0.4450    0   -13.338     1       0.4510         0.674
# 1              0.695  0.2630    0   -22.136     1       0.9570         0.797
# 2              0.434  0.1770    1   -21.180     1       0.0512         0.994
# 3              0.321  0.0946    7   -27.961     1       0.0504         0.995
# 4              0.402  0.1580    3   -16.900     0       0.0390         0.989
# ...              ...     ...  ...       ...   ...          ...           ...
# 586667         0.560  0.5180    0    -7.471     0       0.0292         0.785
# 586668         0.765  0.6630    0    -5.223     1       0.0652         0.141
# 586669         0.535  0.3140    7   -12.823     0       0.0408         0.895
# 586670         0.696  0.6150   10    -6.212     1       0.0345         0.206
# 586671         0.686  0.7230    6    -7.067     1       0.0363         0.105
#
#         instrumentalness  liveness  valence    tempo  time_signature
# 0               0.744000    0.1510   0.1270  104.851               3
# 1               0.000000    0.1480   0.6550  102.009               1
# 2               0.021800    0.2120   0.4570  130.418               5
# 3               0.918000    0.1040   0.3970  169.980               3
# 4               0.130000    0.3110   0.1960  103.220               4
# ...                  ...       ...      ...      ...             ...
# 586667          0.000000    0.0648   0.2110  131.896               4
# 586668          0.000297    0.0924   0.6860  150.091               4
# 586669          0.000150    0.0874   0.0663  145.095               4
# 586670          0.000003    0.3050   0.4380   90.029               4
# 586671          0.000000    0.2640   0.9750  112.204               4
#
# [586672 rows x 20 columns]

# %% [markdown]
# MATRIZ DE CORRELAÇÃO DENTRE AS VARIÁVEIS DO *df_tracks*

# %%
matrix_tracks = df_tracks.corr()
plt.figure(figsize=(15,12))
sns.heatmap(matrix_tracks, annot=True, linewidths=0.5, fmt=".2f")

# %% [markdown]
# **Interpretando a correlação de Pearson**
#
# *   0.9 [+ ou -] indica correlação muito forte
# *   0.7 a 0.9 [+ ou -] indica correlação forte
# *   0.5 a 0.7 [+ ou -] indica correlação moderada
# *   0.3 a 0.5 [+ ou -] indica correlação fraca
# *   0 a 0.3 [+ ou -] indica correlação desprezível

# %%
rel = matrix_tracks.unstack().sort_values().drop_duplicates()
negative_rel = rel.loc[rel < -0.5]
positive_rel = rel.loc[(rel > 0.5) & (rel != 1)]

# %%
negative_rel
# Out:
# energy        acousticness   -0.715412
# acousticness  loudness       -0.519423
# dtype: float64

# %%
positive_rel
# Out:
# valence  danceability    0.528150
# energy   loudness        0.764735
# dtype: float64

# %% [markdown]
# *   OBS.: Vamos perceber, ao longo da análise deste DataFrame, que existem muitos outliers, em praticamente todos os atributos numéricos

# %% [markdown]
# **Conclusões:**
#
# 1.   *Acousticness* tem uma correlação negativa com *loudness* (moderada) e *energy* (forte)
# 2.   Existe uma correlação positiva entre *valence* e *danceability* (moderada) e entre *energy* e *loudness* (forte)

# %% [markdown]
# # - track id : *hash* que identifica a faixa

# %%
df_tracks['id'].nunique()
# Out:
# 586672

# %%
type(df_tracks['id'][0])
# Out:
# str

# %%
# O Dtype da coluna será convertido para String, para ser usado nas próximas etapas

df_tracks['id'] = df_tracks['id'].astype('string')

# %% [markdown]
# **Conclusões:**
#
# 1.   Cada faixa possui um id único

# %% [markdown]
# # - track name : nome da faixa/música

# %% [markdown]
# TRATANDO VALORES FALTANTES

# %%
df_tracks.loc[df_tracks['name'].isnull()]
# Out:
#                             id name  popularity  duration_ms  explicit  \
# 226336  4iH7negBYMfj2z0wDNmgdx  NaN          28       264973         0
# 510975  04d5kbLvSAIBt3pGcljdhC  NaN           0       184293         0
# 510976  05tRkgyxVdwMePGqOXMDYU  NaN           0       191587         0
# 510978  0YAMRgAQH6tkTh4sWNXr8L  NaN           0       191573         0
# 510979  1K6MQQxmFpPb66ZnaiIpHX  NaN           0       167602         0
# ...                        ...  ...         ...          ...       ...
# 517206  6OH9mz9aFbGlbf74cBwYWD  NaN           2       209760         0
# 517215  15RqFDA86slfzujSQMEX4i  NaN           2       257280         0
# 520127  0hKA9A2JPtFdg0fiMhyjQD  NaN           6       194081         0
# 525238  1kR4gIb7nGxHPI3D2ifs59  NaN          26       289440         0
# 525265  4xyBq8t4nkUKH8s28j6ZoD  NaN          24       254000         0
#
#        artists                  id_artists release_date  danceability  energy  \
# 226336    ['']  ['0LyfQWJT6nXafLPZqxe9Of']   1994-01-01         0.512   0.578
# 510975    ['']  ['0LyfQWJT6nXafLPZqxe9Of']   1922-04-01         0.426   0.285
# 510976    ['']  ['0LyfQWJT6nXafLPZqxe9Of']   1922-04-01         0.344   0.186
# 510978    ['']  ['0LyfQWJT6nXafLPZqxe9Of']   1922-04-01         0.316   0.257
# 510979    ['']  ['0LyfQWJT6nXafLPZqxe9Of']   1922-04-01         0.558   0.283
# ...        ...                         ...          ...           ...     ...
# 517206    ['']  ['0LyfQWJT6nXafLPZqxe9Of']   1962-02-01         0.506   0.598
# 517215    ['']  ['0LyfQWJT6nXafLPZqxe9Of']   1962-02-01         0.612   0.615
# 520127    ['']  ['0LyfQWJT6nXafLPZqxe9Of']   1974-12-31         0.471   0.369
# 525238    ['']  ['0LyfQWJT6nXafLPZqxe9Of']   1998-01-05         0.501   0.583
# 525265    ['']  ['0LyfQWJT6nXafLPZqxe9Of']   1998-01-05         0.390   0.452
#
#         key  loudness  mode  speechiness  acousticness  instrumentalness  \
# 226336    0   -12.280     0       0.0299        0.0433          0.000064
# 510975   11   -11.970     1       0.0466        0.9950          0.264000
# 510976    0   -13.495     1       0.0745        0.9950          0.000000
# 510978    3   -13.611     0       0.0549        0.9950          0.769000
# 510979    1   -12.847     1       0.0646        0.9960          0.000000
# ...     ...       ...   ...          ...           ...               ...
# 517206    7    -4.672     0       0.0635        0.7710          0.000001
# 517215    5    -5.609     1       0.0551        0.8540          0.000023
# 520127    4   -12.927     0       0.1460        0.9680          0.001100
# 525238    7    -9.460     0       0.0605        0.6900          0.003960
# 525265    7    -9.900     1       0.0361        0.7370          0.000000
#
#         liveness  valence    tempo  time_signature
# 226336    0.5160    0.692  156.465               1
# 510975    0.2930    0.583  135.661               4
# 510976    0.1150    0.290   79.591               1
# 510978    0.5190    0.529   68.682               3
# 510979    0.4530    0.608   70.379               4
# ...          ...      ...      ...             ...
# 517206    0.6910    0.800   91.172               4
# 517215    0.0541    0.809   90.536               4
# 520127    0.1410    0.766   94.063               4
# 525238    0.0747    0.734  138.391               4
# 525265    0.1110    0.662   94.630               4
#
# [71 rows x 20 columns]

# %%
df_tracks.loc[df_tracks['name'].isnull(), 'id_artists'].unique()
# Out:
# array(["['0LyfQWJT6nXafLPZqxe9Of']"], dtype=object)

# %%
df_artists.loc[df_artists['id'] == "0LyfQWJT6nXafLPZqxe9Of"]
# Out:
# Empty DataFrame
# Columns: [id, followers, genres, name, popularity]
# Index: []

# %%
df_tracks.dropna(subset=['name'], inplace=True)

# %% [markdown]
# *   Foram identificadas 71 canções de um único artista com valores faltantes no dataset
# *   Este artista, porém, não existe no *df_artists*, e, portanto, estas canções foram excluídas do dataset

# %%
df_tracks['name'] = df_tracks['name'].str.split(' -').str[0]

# %%
for word in ['Radio Edit', 'Single Version', 'Remastered', 'Remasterizado', 'Remaster']:
  df_tracks['name'] = df_tracks['name'].str.replace(word, "")

# %% [markdown]
# RETIRANDO MÚSICAS COM MESMOS NOME E ARTISTA DO DATASET

# %%
df_tracks[df_tracks.duplicated(subset=['name', 'id_artists'])]
# Out:
#                             id                                 name  \
# 121     5cUFFY2Atw4QeFitueQCt2                          El Huerfano
# 230     5eXOIVUkW17FqnEoLR2wTX                             Stardust
# 254     0JTkhdnSpIupvyzRctzhPZ                         Chapter 5.19
# 255     0Jz6ef3RtrtJVsDF0gx3Xl                         Chapter 5.15
# 278     0exN2h6nGOlAGbuMKszNnn                         Chapter 3.12
# ...                        ...                                  ...
# 586604  11DUHbs4Vu8M7ppePmszse                                    誰
# 586637  1HpzOCZbNWzxvvXfSGtSrX  Find U Again (feat. Camila Cabello)
# 586646  0F2muCxmWhi7NfY9poM0KZ                               至少我還記得
# 586647  0mDsJ6a7qY3DWbCAHancPj                                 King
# 586655  2nt8dbNspSCB9p7YgLIblV                                 执迷不悟
#
#         popularity  duration_ms  explicit                            artists  \
# 121              0       159800         0                ['Ignacio Corsini']
# 230              5       213667         0                ['Louis Armstrong']
# 254              0       141100         0                 ['Janusz Korczak']
# 255              0       130200         0                 ['Janusz Korczak']
# 278              0       153800         0                 ['Janusz Korczak']
# ...            ...          ...       ...                                ...
# 586604          45       251077         0                         ['Yo Lee']
# 586637          64       176417         0  ['Mark Ronson', 'Camila Cabello']
# 586646          44       304800         0                      ['Eric Chou']
# 586647           2       243987         0                  ['Years & Years']
# 586655          50       245625         0                            ['小乐哥']
#
#                                                id_artists release_date  \
# 121                            ['5LiOoJbxVSAMkBS2fUm3X2']   1922-03-29
# 230                            ['19eLuQmk9aCobbVDHc6eek']         1923
# 254                            ['4hLtcEEpjCmBtTnDdzRV4J']   1923-12-27
# 255                            ['4hLtcEEpjCmBtTnDdzRV4J']   1923-12-27
# 278                            ['4hLtcEEpjCmBtTnDdzRV4J']   1923-12-27
# ...                                                   ...          ...
# 586604                         ['1D2LuIU6rgg0MGa0l8wYJh']   2018-08-31
# 586637  ['3hv9jJF3adDNsBSIQDqcjp', '4nDoRrQiYLoBzwC5Bh...   2019-05-30
# 586646                         ['5fEQLwq1BWWQNR8GzhOIvi']   2019-01-10
# 586647                         ['5vBSrE1xujD2FXYRarbAXc']   2020-06-26
# 586655                         ['7LadOFiUVrFL5Ancq9RLtP']   2020-09-22
#
#         danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 121            0.366  0.0749    7   -26.340     1       0.0806       0.99600
# 230            0.614  0.2980    3   -11.004     0       0.0541       0.97000
# 254            0.667  0.2440    5   -18.571     1       0.9540       0.45100
# 255            0.705  0.2680    2   -19.633     1       0.9450       0.72900
# 278            0.696  0.2830    1   -18.499     1       0.9510       0.86200
# ...              ...     ...  ...       ...   ...          ...           ...
# 586604         0.468  0.2600    1    -9.757     1       0.0386       0.69400
# 586637         0.605  0.6640    8    -7.162     1       0.0316       0.00548
# 586646         0.269  0.3680   10   -10.436     1       0.0339       0.72400
# 586647         0.451  0.1950    2    -8.335     1       0.0440       0.95800
# 586655         0.792  0.8030    0    -5.044     1       0.0443       0.33300
#
#         instrumentalness  liveness  valence    tempo  time_signature
# 121             0.924000    0.1170    0.515   90.969               3
# 230             0.646000    0.0514    0.772  122.319               4
# 254             0.000000    0.1350    0.527   79.279               4
# 255             0.000000    0.1390    0.826   81.718               4
# 278             0.000000    0.1810    0.695  137.399               4
# ...                  ...       ...      ...      ...             ...
# 586604          0.000000    0.1090    0.214  128.579               4
# 586637          0.000003    0.2040    0.164  103.997               4
# 586646          0.000003    0.1110    0.337  168.803               4
# 586647          0.000003    0.1040    0.286   93.706               4
# 586655          0.000121    0.2140    0.931  128.003               4
#
# [90426 rows x 20 columns]

# %%
df_tracks.drop_duplicates(subset=['name', 'id_artists'], inplace=True)

# %%
len(df_tracks)
# Out:
# 496175

# %% [markdown]
# **Conclusões:**
#
# 1.   Excluímos 71 canções sem nome, de um artista que não existe no *df_artists*
# 2.   Retiramos, dos títulos das faixas, palavras que podem manter registros duplicados, mas que significam um mesmo item, por exemplo: 'Radio Edit', 'Single Version', 'Remastered', 'Remasterizado', 'Remaster'
# 3.   Ainda excluimos mais de 60.000 faixas que estavam repetidas, caso consideremos nome da faixa e id do artista

# %% [markdown]
# # - tracks popularity : popularidade das faixas

# %%
df_tracks['popularity'].describe()
# Out:
# count    496175.000000
# mean         27.426424
# std          18.555937
# min           0.000000
# 25%          12.000000
# 50%          26.000000
# 75%          41.000000
# max         100.000000
# Name: popularity, dtype: float64

# %%
df_tracks['popularity'].hist()

# %%
df_tracks.boxplot(column=['popularity'])

# %%
# As 15 faixas de maior Popularidade

df_tracks[['name', 'artists', 'popularity']].sort_values('popularity', ascending=False).head(15)
# Out:
#                                          name  \
# 93802  Peaches (feat. Daniel Caesar & Giveon)
# 93803                         drivers license
# 93804                  Astronaut In The Ocean
# 92810                         Save Your Tears
# 92811                               telepatía
# 92813                         Blinding Lights
# 93805                     Leave The Door Open
# 92814                            The Business
# 93806                                    Fiel
# 93807         Friday (feat. Mufasa & Hypeman)
# 92819                                 Bandido
# 92817                             WITHOUT YOU
# 92816                  Heartbreak Anniversary
# 91866                                 Streets
# 92821                      LA NOCHE DE ANOCHE
#
#                                                  artists  popularity
# 93802       ['Justin Bieber', 'Daniel Caesar', 'Giveon']         100
# 93803                                 ['Olivia Rodrigo']          99
# 93804                                    ['Masked Wolf']          98
# 92810                                     ['The Weeknd']          97
# 92811                                     ['Kali Uchis']          97
# 92813                                     ['The Weeknd']          96
# 93805     ['Bruno Mars', 'Anderson .Paak', 'Silk Sonic']          96
# 92814                                         ['Tiësto']          95
# 93806        ['Los Legendarios', 'Wisin', 'Jhay Cortez']          94
# 93807  ['Riton', 'Nightcrawlers', 'Mufasa & Hypeman',...          94
# 92819                            ['Myke Towers', 'Juhn']          94
# 92817                                  ['The Kid LAROI']          94
# 92816                                         ['Giveon']          94
# 91866                                       ['Doja Cat']          94
# 92821                           ['Bad Bunny', 'ROSALÍA']          93

# %%
# Os 15 maiores conjuntos de faixas, com base na Popularidade

df_tracks['popularity'].value_counts().sort_values(ascending=False).head(15)
# Out:
# 0     38468
# 23    10519
# 1     10346
# 22     9731
# 24     9638
# 25     9233
# 21     9159
# 35     9046
# 26     9038
# 33     8987
# 34     8983
# 19     8929
# 36     8927
# 27     8783
# 28     8767
# Name: popularity, dtype: int64

# %% [markdown]
# *   Vamos comparar a popularidade das faixas, com a popularidade dos seus respectivos cantores
# *   Para isso, vamos unir os dois DataFrames, através do comando *merge()*

# %% [markdown]
# PREPARANDO OS DATASETS PARA O MERGE

# %% [markdown]
# *   Antes de unir os DataFrames, vamos transformar as colunas *artists* e *id_artists* em lista, da mesma forma que fizemos com a coluna de *genres*, no *df_artists*
# *   Também vamos excluir os eventuais duplicados que forem gerados deste processo
# *   OBS.: Este DataFrame resultante será utilizado em outras partes da análise

# %% [markdown]
# CONVERTENDO OS ATRIBUTOS DE ARTISTAS DAS FAIXAS EM LISTAS

# %%
for char in ["[", "]", "'", "\""]:
  df_tracks['artists'] = df_tracks['artists'].str.replace(char, "")
df_tracks['artists'] = df_tracks['artists'].str.split(", ")
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.

# %%
for char in ["[", "]", "'", "\""]:
  df_tracks['id_artists'] = df_tracks['id_artists'].str.replace(char, "")
df_tracks['id_artists'] = df_tracks['id_artists'].str.split(", ")
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.

# %%
df_tracks_exploded = df_tracks.explode('id_artists')
df_tracks_exploded.rename(columns={'id' : 'id_track', 'id_artists' : 'id_artist', 'name' : 'track'}, inplace = True)

# %%
df_artists_exploded = df_artists.explode('genres')
df_artists_exploded.rename(columns={'id' : 'id_artist', 'name' : 'artist', 'genres' : 'genre'}, inplace = True)

# %% [markdown]
# EXCLUSÃO DE EVENTUAIS ITENS DUPLICADOS

# %%
df_tracks_exploded.drop_duplicates(subset=['id_track', 'id_artist'], inplace=True)

# %%
df_artists_exploded.drop_duplicates(subset=['id_artist', 'genre'], inplace=True)

# %% [markdown]
# UNIÃO DOS DATAFRAMES

# %%
df_merged = df_tracks_exploded.merge(df_artists_exploded, how='left', on="id_artist", suffixes=('_track', '_artist'), indicator=True)

# %%
df_merged_sample = df_merged.sample(frac=0.01)

# %%
df_merged.loc[df_merged['artist'].isnull()]
# Out:
#                        id_track                           track  \
# 24486    0VHoDqq7N5VH1UX93Mdyfj                             Air
# 24562    0cSyeb33PyBMtLeUzCgDgO                concerto piccolo
# 24849    1GYoPjJvGyYufhbxZmAKmF                   drume negrita
# 25698    2nUaz5sLG0HccdACC1IG35  i know that my redeemer liveth
# 25704    2oYfdKTcUpk3xJZm0CkHJm                      summertime
# ...                         ...                             ...
# 1925424  44tvGaqisGSy4Qy45vd0CF     Thousand Pieces (FYHYM2019)
# 1925457  65hdygJXXOBGKS76EKvxth                           醒不来的梦
# 1925460  7JWoMpoxEl3pZ2CLZxM6ms                            天空之外
# 1925469  4ow9HehIdFii1cggylW2k0                            四季予你
# 1925475  1ZwZsVZUiyFwIHMNpI3ERt                      Skyscraper
#
#          popularity_track  duration_ms  explicit  \
# 24486                   0       268400         0
# 24562                   0       279600         0
# 24849                   0       182400         0
# 25698                   0       236733         0
# 25704                   0       246667         0
# ...                   ...          ...       ...
# 1925424                 1        83477         0
# 1925457                50       232297         0
# 1925460                49       367192         0
# 1925469                47       156393         0
# 1925475                 4       106002         0
#
#                                                 artists  \
# 24486           [n/a, Johann Sebastian Bach, In Motion]
# 24562                [n/a, Nitsch, Johannes, In Motion]
# 24849                 [n/a, Grenet, Ernesto, In Motion]
# 25698    [n/a, Händel, Georg Friedrich (DP), In Motion]
# 25704                 [n/a, George Gershwin, In Motion]
# ...                                                 ...
# 1925424              [A & Z, Claudiu Adam, Clara Yates]
# 1925457                                           [回小仙]
# 1925460                                           [解语花]
# 1925469                                        [程響, 阿卓]
# 1925475                                   [Emilie Chin]
#
#                       id_artist release_date  danceability  energy  ...  \
# 24486    2pKBejGoRlzAc5VHQ0R26E         1935         0.317   0.317  ...
# 24562    2pKBejGoRlzAc5VHQ0R26E         1935         0.535   0.435  ...
# 24849    2pKBejGoRlzAc5VHQ0R26E         1935         0.628   0.661  ...
# 25698    2pKBejGoRlzAc5VHQ0R26E         1935         0.492   0.286  ...
# 25704    2pKBejGoRlzAc5VHQ0R26E         1935         0.341   0.424  ...
# ...                         ...          ...           ...     ...  ...
# 1925424  5Ny5rgjblitALAHGH2ICG0   2020-01-05         0.393   0.997  ...
# 1925457  27kWsk6mk6DeqQhdOHsyej   2020-09-29         0.744   0.605  ...
# 1925460  5SWFVqjJ5POFRF6cudSL3X   2020-01-19         0.617   0.220  ...
# 1925469  7g8hOWXtGS16J30CMU1SR7   2020-12-29         0.677   0.970  ...
# 1925475  4USdOnfLczwUglA3TrdHs2   2020-02-08         0.626   0.530  ...
#
#          instrumentalness  liveness  valence    tempo  time_signature  \
# 24486             0.95600    0.0868   0.1290   66.296               4
# 24562             0.25300    0.1190   0.2050  106.124               4
# 24849             0.23600    0.0572   0.8050   96.198               4
# 25698             0.89200    0.1430   0.2730   87.973               3
# 25704             0.81200    0.1600   0.2640  151.676               4
# ...                   ...       ...      ...      ...             ...
# 1925424           0.00268    0.7560   0.0639  137.938               4
# 1925457           0.00000    0.3940   0.4710  108.012               4
# 1925460           0.00483    0.4200   0.2430  124.990               4
# 1925469           0.00234    0.3020   0.9080  140.026               4
# 1925475           0.85600    0.1040   0.2150  120.113               4
#
#          followers  genre  artist  popularity_artist     _merge
# 24486          NaN    NaN     NaN                NaN  left_only
# 24562          NaN    NaN     NaN                NaN  left_only
# 24849          NaN    NaN     NaN                NaN  left_only
# 25698          NaN    NaN     NaN                NaN  left_only
# 25704          NaN    NaN     NaN                NaN  left_only
# ...            ...    ...     ...                ...        ...
# 1925424        NaN    NaN     NaN                NaN  left_only
# 1925457        NaN    NaN     NaN                NaN  left_only
# 1925460        NaN    NaN     NaN                NaN  left_only
# 1925469        NaN    NaN     NaN                NaN  left_only
# 1925475        NaN    NaN     NaN                NaN  left_only
#
# [25925 rows x 25 columns]

# %%
df_merged.drop_duplicates(subset=['track', 'id_artist', 'genre'], inplace=True)

# %% [markdown]
# *   OBS.: Este DataFrame *df_merged* será usado para a criação do modelo
# *   IMPORTANTE: Durante a criação do modelo, provavelmente excluiremos, também, as duplicidades geradas para as tracks (para restar apenas um registro para cada faixa, com um único artista e gênero)

# %% [markdown]
# **Conclusões:**
#
# 1.   As faixas do dataset possuem, em média, 27 de Popularidade
# 2.   75% das faixas têm Popularidade igual ou abaixo de 40
# 3.   Com o *merge 'left'*, existirão músicas sem artista (e, consequentemente, sem Gênero)
# 4.   No próprio *df_artists*, existem, também, artistas sem Gênero (not specified)
# 5.   Isso deve ser levado em consideração, caso tais itens sejam mantidos no DataFrame

# %%
plt.figure(figsize=(20,12))
plt.scatter(df_merged_sample['popularity_artist'], df_merged_sample['popularity_track'])

plt.title('Correlação entre Popularidades', fontsize=24)
plt.xlabel('Popularidade do Artista', fontsize=20)
plt.ylabel('Popularidade da Faixa', fontsize=20);

# %%
# Artistas e Canções de Alta Popularidade

df_merged.loc[(df_merged['popularity_artist'] >= 90) & (df_merged['popularity_track'] >= 90),
              ['track', 'popularity_track', 'artist', 'popularity_artist']].groupby("track").first().head()
# Out:
#                                                 popularity_track  \
# track
# 34+35                                                         91
# Anyone                                                        90
# Baila Conmigo (with Rauw Alejandro)                           90
# Bandido                                                       94
# Beautiful Mistakes (feat. Megan Thee Stallion)                90
#
#                                                         artist  \
# track
# 34+35                                            Ariana Grande
# Anyone                                           Justin Bieber
# Baila Conmigo (with Rauw Alejandro)             Rauw Alejandro
# Bandido                                            Myke Towers
# Beautiful Mistakes (feat. Megan Thee Stallion)        Maroon 5
#
#                                                 popularity_artist
# track
# 34+35                                                        95.0
# Anyone                                                      100.0
# Baila Conmigo (with Rauw Alejandro)                          93.0
# Bandido                                                      95.0
# Beautiful Mistakes (feat. Megan Thee Stallion)               91.0

# %%
# Artistas de Alta Popularidade com Canções de Baixa Popularidade

df_merged.loc[(df_merged['popularity_artist'] >= 90) & (df_merged['popularity_track'] == 0),
              ['track', 'popularity_track', 'artist', 'popularity_artist']].groupby("track").first().head()
# Out:
#                    popularity_track          artist  popularity_artist
# track
# 4x                                0          DaBaby               93.0
# Baila Conmigo                     0  Rauw Alejandro               93.0
# Be Alright                        0   Justin Bieber              100.0
# Beautiful Goodbye                 0        Maroon 5               91.0
# Catching Feelings                 0   Justin Bieber              100.0

# %%
# Artistas e Canções de Baixa Popularidade

df_merged.loc[(df_merged['popularity_artist'] == 0) & (df_merged['popularity_track'] == 0), 
              ['track', 'popularity_track', 'artist', 'popularity_artist']].groupby("track").first().head()
# Out:
#                                         popularity_track            artist  \
# track
# "Anne-Marie Stretter, Lol V. Stein..."                 0  Jean Marc Turine
# "Je suis née en Indochine"                             0  Jean Marc Turine
# "L'Immoraliste"                                        0        André Gide
# "Les Faux-monnayeurs": Composition...                  0        André Gide
# "Les nourritures terrestres"                           0        André Gide
#
#                                         popularity_artist
# track
# "Anne-Marie Stretter, Lol V. Stein..."                0.0
# "Je suis née en Indochine"                            0.0
# "L'Immoraliste"                                       0.0
# "Les Faux-monnayeurs": Composition...                 0.0
# "Les nourritures terrestres"                          0.0

# %%
# Artistas de Baixa Popularidade com Canções de Alta Popularidade

df_merged.loc[(df_merged['popularity_artist'] == 0) & (df_merged['popularity_track'] >= 70), 
              ['track', 'popularity_track', 'artist', 'popularity_artist']].groupby("track").first().head()
# Out:
# Empty DataFrame
# Columns: [popularity_track, artist, popularity_artist]
# Index: []

# %% [markdown]
# **Conclusões II:**
#
# 4.   Existem artistas de alta popularidade com canções de baixa - e alta! - popularidades
# 5.   O contrário, porém, não é verdadeiro, pois, artistas de baixa popularidade só possuem canções de baixa popularidade

# %% [markdown]
# IMPORTANTE!
#
# *   Devem ser levados em consideração, os artistas sem Gênero (not specified), assim como as faixas sem artistas (em ambos os casos não teremos o Gênero especificado)
# *   A partir deste ponto, temos os DataFrames originais, bem como o *df_merged*, usado p/ fazer correlações
# *   O *df_merged* será usado para construção do modelo
# *   Para análise das features individualmente, continuaremos usando os DataFrame originais

# %% [markdown]
# # - track duration_ms : duração da música em milissegundos

# %% [markdown]
# IDENTIFICANDO OS OUTLIERS

# %%
duration_timestamp = pd.to_datetime(df_tracks['duration_ms'], unit='ms')

# %%
duration_timestamp.describe(datetime_is_numeric=True)
# Out:
# count                           496175
# mean     1970-01-01 00:03:52.370966322
# min                1970-01-01 00:00:04
# 25%         1970-01-01 00:02:56.933000
# 50%         1970-01-01 00:03:35.640000
# 75%         1970-01-01 00:04:24.200000
# max         1970-01-01 01:33:41.218000
# Name: duration_ms, dtype: object

# %%
duration_timestamp.astype(int).plot.box()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: FutureWarning: casting datetime64[ns] values to int64 with .astype(...) is deprecated and will raise in a future version. Use .view(...) instead.
#   """Entry point for launching an IPython kernel.

# %%
df_tracks.loc[df_tracks['duration_ms'] == df_tracks['duration_ms'].min()]
# Out:
#                           id         name  popularity  duration_ms  explicit  \
# 1291  1JUFU8XJRWgG9Ir8KlLvpW  Pause Track           0         4000         0
#
#                 artists                id_artists release_date  danceability  \
# 1291  [Louis Armstrong]  [19eLuQmk9aCobbVDHc6eek]         1925           0.0
#
#       energy  key  loudness  mode  speechiness  acousticness  \
# 1291     0.0    0     -60.0     0          0.0           0.0
#
#       instrumentalness  liveness  valence  tempo  time_signature
# 1291               0.0       0.0      0.0    0.0               0

# %%
df_tracks.loc[df_tracks['duration_ms'] == df_tracks['duration_ms'].max()]
# Out:
#                             id                               name  popularity  \
# 326329  3EEv9UCeZdn4MVFv8tsO1E  โครงสร้างแห่งสิ่งที่เรียกว่าชีวิต           3
#
#         duration_ms  explicit        artists                id_artists  \
# 326329      5621218         0  [ท่านพุทธทาส]  [2ySk9zib3PuomvMGmCqdTA]
#
#        release_date  danceability  energy  key  loudness  mode  speechiness  \
# 326329   1979-07-28         0.638   0.537    8   -13.365     1        0.775
#
#         acousticness  instrumentalness  liveness  valence    tempo  \
# 326329         0.825               0.0     0.345    0.401  131.446
#
#         time_signature
# 326329               3

# %%
# Faixas com menos de 1 minuto de duração

df_tracks.loc[df_tracks['duration_ms'] < 60000].head()
# Out:
#                           id                                      name  \
# 106   4vV7uBcF2AnjNTOejBS5oL                                   L'enfer
# 1291  1JUFU8XJRWgG9Ir8KlLvpW                               Pause Track
# 2777  6Gb9wRpZp6p0VYuMBxuFHH            Past Ice and Ice and Even More
# 4170  1IW9ryxKdvWxINpv4SwhEr  Kinderszenen, Op. 15: IV. Bittendes Kind
# 4191  1UOb4CrTEjQZAqD74HCFMJ  Preludes: Op. 11, No. 14 in E-Flat Minor
#
#       popularity  duration_ms  explicit  \
# 106            0        40000         0
# 1291           0         4000         0
# 2777           0        51149         0
# 4170           0        56507         0
# 4191           0        57333         0
#
#                                       artists  \
# 106                                     [Uli]
# 1291                        [Louis Armstrong]
# 2777                          [Future Rapper]
# 4170     [Robert Schumann, Vladimir Horowitz]
# 4191  [Alexander Scriabin, Vladimir Horowitz]
#
#                                             id_artists release_date  \
# 106                           [45tIt06XoI0Iio4LBEVpls]   1922-02-22
# 1291                          [19eLuQmk9aCobbVDHc6eek]         1925
# 2777                          [2la3t6tT3UzEJaENsqudLP]   1926-10-03
# 4170  [2UqjDAXnDxejEyE0CzfUrZ, 4Ws5hSoABAwvGJ4LhHwHgq]         1928
# 4191  [6nZiWg5ZB511S24WmB7TCV, 4Ws5hSoABAwvGJ4LhHwHgq]         1928
#
#       danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 106          0.657  0.3250   10   -14.319     0       0.2540        0.1990
# 1291         0.000  0.0000    0   -60.000     0       0.0000        0.0000
# 2777         0.151  0.2790    1    -7.713     1       0.0340        0.0068
# 4170         0.386  0.0076    2   -30.032     1       0.0422        0.9960
# 4191         0.316  0.3880    8   -14.338     0       0.0380        0.9930
#
#       instrumentalness  liveness  valence   tempo  time_signature
# 106           0.856000    0.0931    0.105  81.944               5
# 1291          0.000000    0.0000    0.000   0.000               0
# 2777          0.000066    0.1880    0.461  81.184               4
# 4170          0.883000    0.1400    0.609  76.125               1
# 4191          0.912000    0.1230    0.456  79.385               4

# %%
len(df_tracks.loc[df_tracks['duration_ms'] < 60000])
# Out:
# 5247

# %%
# Faixas acima de 20 minutos de duração

df_tracks.loc[df_tracks['duration_ms'] > 1200000].head()
# Out:
#                           id                             name  popularity  \
# 1127  2Pu2Hv2NnitI7yxc3rHQzf        Death and Transfiguration           0
# 5408  6pRh92RIJ9I4o1IZo9JCqo        Tod und Verklärung Op. 24           0
# 5525  6Zy82cYdN3x9ktUpQxHydk  Piano Sonata in B Minor, S. 178          15
# 6596  0bIuxZqqFor0FWIexwWjqh           N'ecoutez Pas Mesdames           0
# 8025  7M2tLKFG4LJEx0rd0NqFAu                           Anslag           0
#
#       duration_ms  explicit  \
# 1127      1335000         0
# 5408      1450347         0
# 5525      1803280         0
# 6596      1856960         0
# 8025      3093226         0
#
#                                                 artists  \
# 1127  [Richard Strauss, Karl Böhm, Staatskapelle Dre...
# 5408   [Richard Strauss, London Philharmonic Orchestra]
# 5525                   [Franz Liszt, Vladimir Horowitz]
# 6596                                     [Sacha Guitry]
# 8025                                     [Portugallien]
#
#                                              id_artists release_date  \
# 1127  [6pAwHPeExeUbMd5w7Iny6D, 3fyr5uksidSlLzsUjRIz5...   1924-12-31
# 5408   [6pAwHPeExeUbMd5w7Iny6D, 3PfJE6ebCbCHeuqO4BfNeA]         1929
# 5525   [1385hLNbrnbCJGokfH2ac2, 4Ws5hSoABAwvGJ4LhHwHgq]         1930
# 6596                           [5WxFNZUj28Pvf9fsOivG5F]         1931
# 8025                           [18LbUxlDiDSNFm1HREKWqL]         1932
#
#       danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 1127        0.1080   0.183    7   -16.348     1       0.0348         0.972
# 5408        0.0965   0.129    7   -16.723     1       0.0375         0.959
# 5525        0.3100   0.220    6   -16.664     1       0.0428         0.979
# 6596        0.5220   0.240    8   -25.380     1       0.8610         0.766
# 8025        0.0644   0.132    3   -37.943     1       0.0583         0.993
#
#       instrumentalness  liveness  valence   tempo  time_signature
# 1127             0.901    0.1070   0.0369  91.171               3
# 5408             0.933    0.0897   0.0338  76.544               3
# 5525             0.868    0.1620   0.0634  79.903               4
# 6596             0.000    0.1060   0.3560  77.297               4
# 8025             0.962    0.1440   0.0357  72.482               4

# %%
len(df_tracks.loc[df_tracks['duration_ms'] > 1200000])
# Out:
# 985

# %% [markdown]
# **Conclusões:**
#
# 1.   A média de duração das músicas do dataset é de 03min50s.
# 2.   75% das canções possuem até 04min23s.
# 3.   A faixa de maior duração do dataset possui 01h33min41s, chama-se โครงสร้างแห่งสิ่งที่เรียกว่าชีวิต, que em Português significa "A estrutura daquilo que se chama de Vida", e, na verdade, trata-se de uma palestra
# 4.   Levando isso em consideração, identificamos que no DataFrame Tracks, também estão relacionadas itens diferentes de música, em formato de faixas (palestras, álbuns inteiros, concertos etc)
# 5.   Vamos excluir do DataFrame todos os itens que não consideramos músicas, pois levarão a resultados indesejados no futuro modelo
# 6.   Considerando o atributo de duração individualmente, vamos entender
# como música todos os itens que possuem entre 01 e 20 minutos
# 7.   Existem 6573 com menos de 1 minuto, e 1024 registros com duração superior a 20 minutos.

# %% [markdown]
# EXCLUINDO AS FAIXAS FORA DOS LIMITES ESTABELECIDOS

# %%
df_tracks.drop(df_tracks[df_tracks['duration_ms'] < 60000].index, inplace = True)
df_tracks.drop(df_tracks[df_tracks['duration_ms'] > 1200000].index, inplace = True)

# %% [markdown]
# CONVERTENDO A COLUNA DE MILISSEGUNDOS P/ MINUTOS

# %%
df_tracks['duration_ms'] = duration_timestamp.apply(lambda x : x.strftime('%H:%M:%S'))

# %%
df_tracks.rename(columns={'duration_ms' : 'duration'}, inplace = True)

# %% [markdown]
# REPLICANDO AS ALTERAÇÕES NO *DF_TRACKS_EXPLODED* E *DF_MERGED*

# %%
df_merged.drop(df_merged[df_merged['duration_ms'] < 60000].index, inplace = True)
df_merged.drop(df_merged[df_merged['duration_ms'] > 1200000].index, inplace = True)

df_tracks_exploded.drop(df_tracks_exploded[df_tracks_exploded['duration_ms'] < 60000].index, inplace = True)
df_tracks_exploded.drop(df_tracks_exploded[df_tracks_exploded['duration_ms'] > 1200000].index, inplace = True)

# %%
duration_timestamp = pd.to_datetime(df_merged['duration_ms'], unit='ms')
df_merged['duration_ms'] = duration_timestamp.apply(lambda x : x.strftime('%H:%M:%S'))

duration_timestamp = pd.to_datetime(df_tracks_exploded['duration_ms'], unit='ms')
df_tracks_exploded['duration_ms'] = duration_timestamp.apply(lambda x : x.strftime('%H:%M:%S'))

# %%
df_merged.rename(columns={'duration_ms' : 'duration'}, inplace = True)
df_tracks_exploded.rename(columns={'duration_ms' : 'duration'}, inplace = True)

# %% [markdown]
# # - explicit track : indica se uma música tem conteúdo explícito ou não

# %% [markdown]
# *   0 - sem conteúdo explícito
# *   1 - com conteúdo explícito

# %%
# Plot das faixas explícitas no DataFrame original, df_tracks

df_tracks['explicit'].value_counts().plot(kind='bar', color=['teal', 'orange'])

# %%
explicit_songs = df_merged.loc[df_merged['explicit'] == 1]

# %%
len(explicit_songs)
# Out:
# 108122

# %%
# Os 50 gêneros com mais faixas explícitas

explicit_songs.groupby('genre').size().sort_values(ascending=False).head(50)
# Out:
# genre
# rap                    4896
# hip hop                4328
# pop rap                3165
# gangster rap           2473
# not specified          2229
# trap                   1988
# southern hip hop       1813
# trap latino            1597
# pop                    1458
# czsk hip hop           1443
# french hip hop         1393
# russian hip hop        1354
# italian hip hop        1346
# hardcore hip hop       1346
# dance pop              1317
# pop urbaine            1301
# reggaeton              1279
# east coast hip hop     1168
# latin                  1135
# latin hip hop           892
# german hip hop          848
# dutch hip hop           847
# west coast rap          824
# r&b                     793
# rap francais            777
# russian trap            769
# reggaeton flow          748
# alternative metal       734
# dirty south rap         703
# tropical                671
# dutch rap pop           664
# greek hip hop           662
# atl hip hop             660
# polish hip hop          655
# urban contemporary      652
# rock                    642
# nu metal                642
# greek trap              641
# hip pop                 627
# conscious hip hop       598
# post-teen pop           581
# italian pop             578
# g funk                  568
# francoton               552
# rap conscient           541
# melodic rap             539
# alternative hip hop     521
# czech hip hop           513
# trap italiana           475
# slovak hip hop          468
# dtype: int64

# %% [markdown]
# *OBS.: O somatório dentre os gêneros superará a quantidade de faixas totais, pois a consulta por gêneros conta mais de uma vez cada faixa por artista e seu gênero. O ojetivo desta lista não é de apresentar valores exatos, mas sim, de mostrar um overview sobre os gêneros encontrados nas músicas explícitas

# %% [markdown]
# **Conclusões:**
#
# 1.   O dataset possui mais de 100.000 músicas com conteúdo explícito
# 2.   Os gêneros com mais músicas explícitas são rap, hip hop e seus subgêneros

# %% [markdown]
# # - track artists : artistas que cantam/participam da faixa

# %% [markdown]
# *   A coluna *artists* será removida do DataFrame ***df_merged***, visto que já temos a coluna *artist*, oriunda do DataFrame ***df_artists***, e pode gerar confusão de interpretação

# %%
df_merged.drop(['artists'], axis = 1, inplace = True)

# %% [markdown]
# **Conclusões:**
#
# 1.   Observa-se, com ajuda da coluna artists, que ainda possuimos mais itens no DataFrame Tracks que não se tratam de músicas, mas sim, de audiolivros divididos em faixas
# 2.   Chegamos a esta conclusão ao pesquisar, no próprio Spotify, pelos artistas com maior quantidade de faixas
# 3.   É provável que hajam, porém, mais faixas de audiolivros além daqueles já encontrados
# 4.   **IMPORTANTE: construímos abaixo uma estratégia para limpar estes itens do dataset, para evitar que o modelo os leve em consideração**

# %% [markdown]
# # - track id_artists : id dos artistas que cantam/participam da faixa

# %% [markdown]
# *   A coluna *id_artist* foi usada para segregar o *df_tracks*, pois, para cada faixa do DataFrame, existiam mais de um artista em vários registros

# %%
tracks_id_artists = df_tracks_exploded.groupby('id_artist')

# %%
tracks_id_artists.size().sort_values(ascending=False).head(50)
# Out:
# id_artist
# 61JrslREXq98hurYL2hYoc    1966
# 2maQMqxNnlRrBrS1oAsrX9    1946
# 4NJhFmfw43RLBLjQvxDuRS    1649
# 5aIqB5nVVvmFsvSdExz408    1442
# 0gXDpqwYNDODn7fB0RDN8J    1133
# 2ae6PxICSOZHvjqiCcgon8    1052
# 003f4bk13c6Q3gAUXv7dGJ    1022
# 2wOqMjp9TyABvtHdOSOTUS    1015
# 5as8A4G47Ohu9NSWs3Je8U     982
# 1JOQXgYdQV2yfrhewqx96o     957
# 0aFGod7DM6b3O5l1AmvFwK     923
# 5V0MlUE1Bft0mbLlND7FJz     912
# 66pXJ6MhX37ZLneiwUWZf3     796
# 0GF4shudTAFv8ak9eWdd4Y     786
# 7y97mc3bZRFXzT2szRM4L4     774
# 7JdPe4gzrYmbcko3FTav57     752
# 0OzxPXyowUEQ532c9AmHUR     682
# 1Mxqyy3pSjf8kZZL4QVxS0     630
# 0bjdfjE8XbLa2Odstu6E1E     608
# 3gacryguGmpmCvgPGt2CBI     595
# 43ZHCT0cAZBISjO8DG9PnE     572
# 3UYZxxxrntUxxEeRycqHvq     568
# 4eeMulNeqpZGBxybCxZOdC     546
# 2LmyJyCF5V1eQyvHgJNbTn     522
# 3gBKY0y3dFFVRqicLnVZYz     514
# 13dkPjqmbcchm8cXjEJQeP     514
# 71ADe4Zg9UyE8WQEHbJSXM     503
# 5LiOoJbxVSAMkBS2fUm3X2     502
# 5zCaQxjl110XTrm4LQ1CxY     498
# 7HjbJ8V87zrxkSzL1KieQk     494
# 6aMD1KAa5i3Myy61cR8FiW     494
# 4xpgBZSojKNEQqQHXrwSXA     488
# 70B80Lwx2sxti0M1Ng9e8K     485
# 7yaBUcdjmqPP2vIv6F5bFD     475
# 5Xpg6PBSUOoho2lI9qLjiu     461
# 09KZU0NsS7jRa5p0SflmGY     460
# 6kACVPfCOnqzgfEF5ryl0x     459
# 7p5EwRiUqxJxnOCcULTHex     450
# 2IUtwMti1OiT3lkW6RubgH     447
# 3Lcu93LjKagluamCDOJc9R     443
# 1YzCsTRb22dQkh9lghPIrp     442
# 2spmKkD1aaIwksnFrAghRL     441
# 4y01WeCT5mNIAYRPjJ4sgj     436
# 5yxyJsFanEAuwSM5kOuZKc     404
# 7ie36YytMoKtPiL7tUvmoE     394
# 49e4v89VmlDcFCMyDv9wQ9     391
# 0kbYTNQb4Pb1rPbbaF0pT4     384
# 4etv0ut4ws0GbXBtolzf5e     382
# 1Uff91EOsvd99rtAupatMP     377
# 4Ws5hSoABAwvGJ4LhHwHgq     374
# dtype: int64

# %% [markdown]
# *   Observe que o agrupamento entre *artists* gera um resultado diferente daquele feito com base no *id_artists*
# *   Isto porque o DataFrame *df_tracks* foi dividido em relação aos ids de artista que estavam em lista, e daí surgiu o *df_tracks_exploded*
# *   Assim, no agrupamento feito com base no *id_artists*, estão mencionados separadamente os artistas que eventualmente possuem faixas em comum com algum outro cantor

# %% [markdown]
# # - track release_date : data de lançamento da faixa

# %% [markdown]
# PADRONIZANDO A COLUNA COM O ANO DE LANÇAMENTO

# %%
release = pd.to_datetime(df_tracks['release_date'])
df_tracks['release_date'] = release.apply(lambda x : x.year)

# %%
df_tracks.rename(columns={'release_date' : 'release_year'}, inplace = True)

# %%
df_tracks['release_year'].hist()

# %% [markdown]
# REPLICANDO AS ALTERAÇÕES NO *DF_TRACKS_EXPLODED* E *DF_MERGED*

# %%
release = pd.to_datetime(df_tracks_exploded['release_date'])
df_tracks_exploded['release_date'] = release.apply(lambda x : x.year)
df_tracks_exploded.rename(columns={'release_date' : 'release_year'}, inplace = True)

# %%
release = pd.to_datetime(df_merged['release_date'])
df_merged['release_date'] = release.apply(lambda x : x.year)
df_merged.rename(columns={'release_date' : 'release_year'}, inplace = True)

# %% [markdown]
# DIVIDINDO AS FAIXAS DE ACORDO COM AS DÉCADAS

# %%
decades = range(1920, 2030, 10)

tracks_by_decades = {}
for d in decades:
  years = f'the_{str(d)}s'
  df = df_tracks.loc[(df_tracks["release_year"] >= d) & (df_tracks["release_year"] < ( d+10 ))]
  tracks_by_decades.update({ years : df })

# %%
print(f'*OBS.: Este somatório dentre os gêneros superará a quantidade de faixas totais, pois a busca por gêneros conta mais de uma vez cada faixa por artista e gênero\n')

for years, df in tracks_by_decades.items():
  print(years)

  df_by_genre = df_merged.loc[(df_merged['release_year'] >= df['release_year'].min()) 
                            & (df_merged['release_year'] <= df['release_year'].max())
                            & (df_merged['genre'] != 'not specified')]

  print(f'Possui {len(df)} faixas')
  print(f'Média Popularidade das Faixas: {round(df["popularity"].mean(), 2)}')
  print(f'Gêneros mais comuns: {df_by_genre.groupby("genre").size().sort_values(ascending=False).head(10)} \n\n')  

print(f'*OBS.: Este somatório dentre os gêneros superará a quantidade de faixas totais, pois a busca por gêneros conta mais de uma vez cada faixa por artista e gênero\n')
# Out:
# *OBS.: Este somatório dentre os gêneros superará a quantidade de faixas totais, pois a busca por gêneros conta mais de uma vez cada faixa por artista e gênero
#
# the_1920s
# Possui 6428 faixas
# Média Popularidade das Faixas: 1.01
# Gêneros mais comuns: genre
# vintage tango            1577
# tango                    1538
# vintage jazz             1020
# big band                  710
# swing                     651
# stride                    528
# classical                 519
# tin pan alley             425
# harlem renaissance        371
# classical performance     283
# dtype: int64
#
#
# the_1930s
# Possui 11012 faixas
# Média Popularidade das Faixas: 1.8
# Gêneros mais comuns: genre
# big band                 1577
# swing                    1553
# vintage tango            1426
# tango                    1123
# classical                1082
# stride                    992
# vintage jazz              884
# vocal jazz                831
# adult standards           759
# classical performance     665
# dtype: int64
#
#
# the_1940s
# Possui 14662 faixas
# Média Popularidade das Faixas: 1.86
# Gêneros mais comuns: genre
# classical                 3692
# classical performance     2414
# classic bollywood         1781
# filmi                     1575
# swing                     1238
# orchestral performance    1181
# adult standards           1058
# ghazal                    1036
# sufi                       983
# vocal jazz                 932
# dtype: int64
#
#
# the_1950s
# Possui 30245 faixas
# Média Popularidade das Faixas: 8.47
# Gêneros mais comuns: genre
# adult standards          6074
# classical                6063
# vocal jazz               5101
# classical performance    4576
# opera                    4381
# lounge                   4333
# cool jazz                4208
# jazz                     4207
# bebop                    2997
# swing                    2741
# dtype: int64
#
#
# the_1960s
# Possui 40266 faixas
# Média Popularidade das Faixas: 17.94
# Gêneros mais comuns: genre
# adult standards       7267
# brill building pop    5025
# folk rock             4156
# lounge                3891
# classic rock          3715
# soul                  3257
# vocal jazz            3112
# filmi                 3107
# rock                  2977
# rock-and-roll         2954
# dtype: int64
#
#
# the_1970s
# Possui 51268 faixas
# Média Popularidade das Faixas: 23.74
# Gêneros mais comuns: genre
# classic rock       6913
# rock               6453
# mellow gold        5818
# album rock         5396
# soft rock          5115
# folk rock          4959
# art rock           4092
# country rock       4012
# adult standards    2749
# hard rock          2746
# dtype: int64
#
#
# the_1980s
# Possui 65152 faixas
# Média Popularidade das Faixas: 24.89
# Gêneros mais comuns: genre
# rock            5296
# soft rock       3859
# mellow gold     3594
# album rock      3582
# new wave pop    3375
# classic rock    3225
# new wave        2899
# hard rock       2864
# new romantic    2479
# art rock        2440
# dtype: int64
#
#
# the_1990s
# Possui 90657 faixas
# Média Popularidade das Faixas: 29.05
# Gêneros mais comuns: genre
# rock                 3592
# filmi                3499
# rock en espanol      2904
# latin                2764
# c-pop                2650
# ranchera             2322
# latin alternative    2218
# classic mandopop     2194
# latin rock           2187
# latin pop            2132
# dtype: int64
#
#
# the_2000s
# Possui 72363 faixas
# Média Popularidade das Faixas: 36.13
# Gêneros mais comuns: genre
# filmi              3883
# latin              3092
# dance pop          2397
# sufi               2257
# j-pop              2159
# tropical           2156
# desi pop           2146
# rock en espanol    2091
# latin pop          1953
# mandopop           1898
# dtype: int64
#
#
# the_2010s
# Possui 91009 faixas
# Média Popularidade das Faixas: 39.85
# Gêneros mais comuns: genre
# pop                 4912
# latin               4277
# dance pop           3641
# filmi               3350
# trap latino         3026
# pop dance           2814
# desi pop            2730
# modern bollywood    2714
# edm                 2677
# reggaeton           2658
# dtype: int64
#
#
# the_2020s
# Possui 16880 faixas
# Média Popularidade das Faixas: 45.26
# Gêneros mais comuns: genre
# trap latino           1258
# latin                  964
# pop                    938
# reggaeton              862
# pop dance              611
# progressive house      586
# italian hip hop        582
# dance pop              569
# progressive trance     547
# edm                    545
# dtype: int64
#
#
# *OBS.: Este somatório dentre os gêneros superará a quantidade de faixas totais, pois a busca por gêneros conta mais de uma vez cada faixa por artista e gênero

# %% [markdown]
# **Conclusões:**
#
#
# 1.   A quantidade de faixas disponíveis no dataset aumentam proporcionalmente conforme a passagem dos anos (as últimas décadas possuem mais registros do que das décadas antigas)
# 2.   Referente à evolução dos gêneros musicais:
#
#
# > Nas décadas de 20 e 30 eram mais comuns as músicas de tango;
#
#
# > Entre os anos 40 e 50, as músicas mais clássicas e o jazz estavam em voga;
#
#
# > O rock começou a tomar protagonismo nos anos 60, e dominou até os anos 80, começando a dar espaço para outros gêneros a partir dos anos 90
#
#
# > Nos anos 90, a música latina começou a ganhar espaço, e vem em destaque até os dias atuais
#
#
# > A partir dos anos 2000, o dance pop começou a se destacar, e até hoje ocupa espaço no pódio da maior quantidade de faixas

# %% [markdown]
# ### DataFrame Tracks - **audio features**

# %%
audio_features_by_genres = df_merged.groupby('genre')
mean_by_genres = audio_features_by_genres.mean()

# %%
mean_by_genres
# Out:
#                         popularity_track  explicit  release_year  \
# genre
# 21st century classical          1.000000  0.000000   2016.500000
# 432hz                          30.000000  0.000000   2012.000000
# 48g                            37.964286  0.000000   2010.285714
# a cappella                     31.113402  0.000000   1990.268041
# abstract                       30.941176  0.000000   1989.764706
# ...                                  ...       ...           ...
# zouglou                        38.107143  0.000000   1999.500000
# zouk                           31.005848  0.029240   1997.479532
# zouk riddim                    39.246753  0.090909   2006.974026
# zurich indie                   54.000000  0.000000   2018.000000
# zydeco                         20.814815  0.000000   1969.777778
#
#                         danceability    energy       key   loudness      mode  \
# genre
# 21st century classical      0.094250  0.018600  2.000000 -30.150500  0.500000
# 432hz                       0.570667  0.798333  9.333333  -6.146000  0.000000
# 48g                         0.477643  0.874500  6.142857  -4.153107  0.821429
# a cappella                  0.548557  0.343656  5.257732 -13.376876  0.680412
# abstract                    0.434365  0.462482  5.235294 -17.141706  0.500000
# ...                              ...       ...       ...        ...       ...
# zouglou                     0.731357  0.806500  6.107143  -6.259000  0.535714
# zouk                        0.700053  0.736117  5.298246  -9.119526  0.614035
# zouk riddim                 0.669831  0.718325  5.298701  -7.499247  0.610390
# zurich indie                0.439000  0.473000  2.000000  -9.584000  0.000000
# zydeco                      0.554926  0.500889  5.222222 -10.356444  0.888889
#
#                         speechiness  acousticness  instrumentalness  liveness  \
# genre
# 21st century classical     0.040800      0.817000          0.448755  0.220500
# 432hz                      0.097267      0.011497          0.002401  0.328500
# 48g                        0.070771      0.165956          0.039811  0.237889
# a cappella                 0.082580      0.629511          0.014131  0.182685
# abstract                   0.053247      0.403481          0.821783  0.172156
# ...                             ...           ...               ...       ...
# zouglou                    0.095789      0.137883          0.058257  0.169164
# zouk                       0.059963      0.187422          0.094023  0.143051
# zouk riddim                0.102613      0.239184          0.040493  0.158104
# zurich indie               0.032300      0.533000          0.000306  0.133000
# zydeco                     0.052807      0.529133          0.112982  0.255889
#
#                          valence       tempo  time_signature      followers  \
# genre
# 21st century classical  0.033300   80.355000        2.500000     838.000000
# 432hz                   0.389333  133.669667        4.000000   10113.000000
# 48g                     0.520325  140.892821        4.000000  281411.642857
# a cappella              0.504787  116.059938        3.855670  220348.773196
# abstract                0.257303  121.582382        3.970588   99482.852941
# ...                          ...         ...             ...            ...
# zouglou                 0.852571  125.656929        4.035714   73105.928571
# zouk                    0.799158  122.217474        4.000000   19086.847953
# zouk riddim             0.643468  131.007468        4.064935   43136.194805
# zurich indie            0.462000  152.855000        4.000000   79811.000000
# zydeco                  0.641459  127.117259        3.703704    4692.074074
#
#                         popularity_artist
# genre
# 21st century classical          13.000000
# 432hz                           57.000000
# 48g                             54.357143
# a cappella                      47.958763
# abstract                        44.235294
# ...                                   ...
# zouglou                         43.750000
# zouk                            38.058480
# zouk riddim                     42.324675
# zurich indie                    48.000000
# zydeco                          24.370370
#
# [4662 rows x 17 columns]

# %% [markdown]
# # - track danceability : indica o quão dançante é uma faixa

# %% [markdown]
# *   Valores variam entre 0.0 até 1.0
# *   Baseado em uma combinação de elementos musicais, incluindo andamento, estabilidade do ritmo, intensidade da batida e regularidade geral

# %% [markdown]
# ANÁLISE DE OUTLIERS

# %%
df_tracks.boxplot(column=['danceability'])

# %%
q1 = df_tracks['danceability'].quantile(0.25)
q3 = df_tracks['danceability'].quantile(0.75)

IQR = q3 - q1

lower_danceability_outliers = q1 - 1.5 * IQR

# %% [markdown]
# *   Não existem outliers acima do limite do 3º quartil

# %%
lower_danceability_outliers
# Out:
# 0.10099999999999992

# %% [markdown]
# OUTLIERS ABAIXO DO PRIMEIRO QUARTIL

# %%
outliers = df_tracks[df_tracks['danceability'] < lower_danceability_outliers]

# %%
outliers.head()
# Out:
#                           id  \
# 817   2WTtJDfCUjAyCZHRSfCLDn
# 1013  5tQsQaMquCXBREb1FNymi7
# 1043  6VweawuAyN9Ad9ikn9f5W3
# 3773  6XH3KreFXUImbVYPTN0nvT
# 5492  1a1hj9ASUFcNTC1Fd3xIF4
#
#                                                    name  popularity  duration  \
# 817                                    La Mina del Ford           1  00:02:13
# 1013                                     Oh Mujer Mujer           0  00:02:50
# 1043                                        Shangai Bay           0  00:02:09
# 3773                                   Tango in B Minor           0  00:02:25
# 5492  From Holberg's Time, Suite for String Orchestr...           0  00:06:27
#
#       explicit                                            artists  \
# 817          0                                  [Ignacio Corsini]
# 1013         0                                 [Francisco Canaro]
# 1043         0                                  [Ignacio Corsini]
# 3773         0                           [Franz Fedor Alexandros]
# 5492         0  [Edvard Grieg, RIAS-Symphonie-Orchester, Herbe...
#
#                                              id_artists  release_year  \
# 817                            [5LiOoJbxVSAMkBS2fUm3X2]          1924
# 1013                           aQMqxNnlRrBrS1oAsrX9]          1924
# 1043                           [5LiOoJbxVSAMkBS2fUm3X2]          1924
# 3773                           [7aFE2T8wEVfoLNgjTtUKab]          1927
# 5492  [5ihY290YPGc3aY2xTyx7Gy, 0NZ45pVCulww4G9z09oz4...          1929
#
#       danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 817         0.0000  0.0258    5   -24.894     1       0.0000         0.996
# 1013        0.0000  0.3150    8   -15.969     0       0.0000         0.996
# 1043        0.0000  0.0829    6   -24.272     1       0.0000         0.996
# 3773        0.0682  0.4480   11   -11.731     0       0.0394         0.837
# 5492        0.0912  0.1540    7   -16.669     0       0.0407         0.953
#
#       instrumentalness  liveness  valence   tempo  time_signature
# 817            0.76800    0.0831   0.0000   0.000               0
# 1013           0.95600    0.3750   0.0000   0.000               0
# 1043           0.89300    0.1230   0.0000   0.000               0
# 3773           0.00744    0.1330   0.2470  58.130               5
# 5492           0.85500    0.1310   0.0351  77.509               3

# %%
outliers.shape
# Out:
# (1430, 20)

# %% [markdown]
# ANÁLISE DA *DANCEABILITY* DE ACORDO COM A PASSAGEM DAS DÉCADAS

# %%
danceability_by_decades = pd.DataFrame(index=range(len(df_tracks)))

for years, df in tracks_by_decades.items():
  danceability_by_decades[years] = df['danceability']

# %%
danceability_by_decades.boxplot(figsize=(15,10))
# Out:
# /usr/local/lib/python3.7/dist-packages/matplotlib/cbook/__init__.py:1376: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   X = np.atleast_1d(X.T if isinstance(X, np.ndarray) else np.asarray(X))

# %% [markdown]
# ANÁLISE DA MÉDIA DE *DANCEABILITY* DAS FAIXAS, DE ACORDO COM O GÊNERO

# %%
danceability_by_genres = df_merged.groupby('genre').danceability.agg(['mean', 'size']).sort_values(by=['mean'])

# %% [markdown]
# Gêneros com menores médias de *danceability*

# %%
danceability_by_genres.head()
# Out:
#                                    mean  size
# genre
# spa                            0.000000     1
# singing bowl                   0.056900     1
# german contemporary classical  0.079300     1
# white noise                    0.089046    50
# 21st century classical         0.094250     2

# %% [markdown]
# Gêneros com maiores médias de *danceability*

# %%
danceability_by_genres.tail()
# Out:
#                           mean  size
# genre
# boston electronic        0.880     2
# alberta hip hop          0.885     1
# togolese pop             0.916     1
# proto-rap                0.947     1
# native american hip hop  0.957     1

# %% [markdown]
# *   Como visto acima, danceability tem uma correlação positiva com valence
# *   Observaremos esta correlação graficamente

# %%
df_tracks_sample = df_tracks.sample(frac=0.004)

# %%
plt.figure(figsize=(10,6))
plt.scatter(df_tracks_sample['danceability'], df_tracks_sample['valence'], c=['teal'])

plt.title('Correlação entre Danceability e Valence')
plt.xlabel('Danceability')
plt.ylabel('Valence');

# %% [markdown]
# **Conclusões:**
#
# 1.   A cada década aumenta-se a mediana do *danceability* das faixas
# 2.   Quanto mais se aumenta a média de *danceability*, porém, aumenta-se também, o número de faixas abaixo do limite inferior [faixas não dançantes]
# 3.   Existe uma tendência (moderada) de que, quanto maior o *danceability* das faixas, maior é o atributo *valence*
# 4.   As faixas com a menor mediana de *danceability*, porém, são as faixas da década de 1940 (menor do que nas décadas anteriores, inclusive). Vamos observar, mais adiante, que outros atributos também foram mais baixos nesta década
# 5.   Concidentemente ou não, neste período ocorreu a Segunda Guerra Mundial (de 1939 a 1945)
# *   OBS.:   O período da Primeira Guerra Mundial não está contemplado no dataset (1914 a 1918), para podermos traçar um paralelo entre os dois períodos
# 6.   Considerando os gêneros que contém, no mínimo, 10 faixas distintas, aqueles de maior média de *danceability* são *rave funk*, *miami bass* e *detroit trap*
# 7.   Os de menor *danceability* são *white noise*, *sound* e *water*. Olhando apenas pelo nome, provavelmente são faixas instrumentais, com sons e ruídos de fundo

# %% [markdown]
# # - track energy : mede a intensidade e atividade da faixa

# %% [markdown]
# *   Valores variam entre 0.0 até 1.0
# *   As características que contribuem para este atributo incluem: dinâmica da faixa, intensidade percebida, timbre, taxa de início e entropia geral

# %% [markdown]
# ANÁLISE DE OUTLIERS

# %%
df_tracks.boxplot(column=['energy'])

# %% [markdown]
# *   Não existem outliers neste atributo

# %% [markdown]
# ANÁLISE DE *ENERGY* DE ACORDO COM A PASSAGEM DAS DÉCADAS

# %%
energy_by_decades = pd.DataFrame(index=range(len(df_tracks)))

for years, df in tracks_by_decades.items():
  energy_by_decades[years] = df['energy']

# %%
energy_by_decades.boxplot(figsize=(15,10))
# Out:
# /usr/local/lib/python3.7/dist-packages/matplotlib/cbook/__init__.py:1376: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   X = np.atleast_1d(X.T if isinstance(X, np.ndarray) else np.asarray(X))

# %% [markdown]
# ANÁLISE DA MÉDIA DE *ENERGY* DAS FAIXAS, DE ACORDO COM O GÊNERO

# %%
energy_by_genres = df_merged.groupby('genre').energy.agg(['mean', 'size']).sort_values(by=['mean'])

# %% [markdown]
# Gêneros com menores médias de *energy*

# %%
energy_by_genres.head()
# Out:
#                                    mean  size
# genre
# spa                            0.000062     1
# abstract idm                   0.002910     1
# singing bowl                   0.004130     1
# massage                        0.004520     1
# german contemporary classical  0.007710     1

# %% [markdown]
# Gêneros com maiores médias de *energy*

# %%
energy_by_genres.tail()
# Out:
#                      mean  size
# genre
# persian hip hop    0.9910     1
# acidcore           0.9910     1
# singaporean metal  0.9935     2
# singaporean punk   0.9935     2
# rhythm game        0.9940     2

# %% [markdown]
# *   Como visto acima, *energy* tem uma correlação positiva com *loudness*
# *   Observaremos esta correlação graficamente

# %%
plt.figure(figsize=(10,6))
plt.scatter(df_tracks_sample['energy'], df_tracks_sample['loudness'], c=['teal'])

plt.title('Correlação entre Energy e Loudness')
plt.xlabel('Energy')
plt.ylabel('Loudness');

# %% [markdown]
# **Conclusões:**
#
# 1.   O atributo *energy* segue uma tendência de aumento conforme o decorrer das décadas
# 2.   A menor mediana de *energy* ocorre na década de 1940
# 3.   Existe uma tendência (forte) de que, quanto maior o *energy* das faixas, maior é o atributo *loudness*
# 4.   Considerando os gêneros que contém, no mínimo, 10 faixas distintas, aqueles de maior média de energy são *buffalo ny metal*, *speedcore*, *frenchcore* e *colombian hardcore*
# 5.   Os gêneros de menor média de *energy* são *ukrainian choir*, *native american flute* e *baltic choir*

# %% [markdown]
# # - track key : chave musical à qual cada faixa pertence

# %% [markdown]
# *   Números inteiros indicando um valor padrão na notação Pitch Class
# *   "Embora não haja um limite superior ou inferior formal para essa sequência, apenas alguns desses tons são audíveis ao ouvido humano" (WIKIPEDIA, Pitch Class)

# %% [markdown]
# ![pitch class.PNG](data:image/png;base64,...)

# %%
df_tracks['key'].hist(bins=range(13))

# %%
df_tracks['key'].value_counts()
# Out:
# 0     62785
# 7     62133
# 2     56057
# 9     55104
# 5     44769
# 4     40785
# 1     33384
# 11    32408
# 10    31436
# 8     27423
# 6     25536
# 3     18123
# Name: key, dtype: int64

# %% [markdown]
# ANÁLISE DE *KEY* DE ACORDO COM A PASSAGEM DAS DÉCADAS

# %%
key_by_decades = pd.DataFrame(index=range(len(df_tracks)))

for years, df in tracks_by_decades.items():
  key_by_decades[years] = df['key']

# %%
fig, axs = plt.subplots(4, 3, figsize=(14, 13))
plt.subplots_adjust(hspace=0.5)
ax = axs.ravel()

fig.text(0.5, 0.03, 'Valores atributo KEY', ha='center', fontsize=13)

i = 0
for years, df in key_by_decades.items():
  df.hist(bins=range(13), ax=ax[i]).set_title(years, y=1.08)
  i += 1

fig.delaxes(axs[3][2])
plt.show()

# %% [markdown]
# ANÁLISE DE *KEY* DAS FAIXAS, DE ACORDO COM O GÊNERO

# %%
key_by_genres = df_merged.groupby('genre').key.value_counts().sort_values()

# %% [markdown]
# Gêneros com menores agrupamentos de *key*

# %%
key_by_genres.head(30)
# Out:
# genre                             key
# 21st century classical            0      1
# icelandic black metal             3      1
# icelandic classical               6      1
# icelandic experimental            4      1
#                                   8      1
#                                   11     1
# icelandic metal                   3      1
#                                   6      1
#                                   8      1
# icelandic traditional             1      1
#                                   10     1
# idaho indie                       0      1
#                                   4      1
#                                   5      1
#                                   11     1
# idol                              6      1
#                                   7      1
#                                   11     1
# idol rock                         10     1
# igbo traditional                  3      1
# icelandic black metal             2      1
# igbo traditional                  5      1
# hypnosis mic                      10     1
#                                   3      1
# hungarian choir                   4      1
#                                   7      1
# hungarian contemporary classical  3      1
#                                   5      1
#                                   8      1
#                                   10     1
# Name: key, dtype: int64

# %% [markdown]
# Gêneros com maiores agrupamentos de *key*

# %%
key_by_genres.tail(30)
# Out:
# genre            key
# classic rock     0       2206
# rock             4       2284
# classic rock     7       2322
# classical        0       2323
#                  7       2343
# filmi            5       2355
#                  2       2427
# classical        2       2445
# classic rock     2       2495
#                  9       2557
# rock             0       2693
# adult standards  7       2785
# rock             7       2834
# adult standards  5       2845
# filmi            7       2969
# rock             2       3074
# adult standards  0       3252
# rock             9       3317
# not specified    6       3982
#                  3       4426
#                  11      4704
#                  8       5213
#                  4       5765
#                  10      5840
#                  1       6300
#                  9       7427
#                  5       8199
#                  2       8411
#                  7       9784
#                  0      10692
# Name: key, dtype: int64

# %% [markdown]
# **Conclusões:**
#
# 1.   Os níveis 0 [DÓ], 2 [RÉ], 7 [SOL] e 9 [LÁ] foram preponderantes em todas as décadas, de forma parecida
# 2.   Quanto à divisão por gêneros, aparentemente não há tendência definida; existem maiores agrupamentos nas canções de rock, e menores no gênero indie e seus derivados, mas isso se deve mais ao fato da quantidade de faixas no dataset p/ cada gênero em si, do que devido ao atributo *key*

# %% [markdown]
# # - track loudness :  volume geral de uma faixa medido em decibéis (dB)

# %% [markdown]
# *   Valores geralmente variam entre -60 e 0 db.

# %% [markdown]
# ANÁLISE DE OUTLIERS

# %%
df_tracks.boxplot(column=['loudness'])

# %%
q1 = df_tracks['loudness'].quantile(0.25)
q3 = df_tracks['loudness'].quantile(0.75)

IQR = q3 - q1


lower_loudness_outliers = q1 - 1.5 * IQR
higher_loudness_outliers = q3 + 1.5 * IQR

# %% [markdown]
# *   Existem outliers tanto acima, quanto abaixo dos limites dos quartis

# %% [markdown]
# OUTLIERS ABAIXO DO PRIMEIRO QUARTIL

# %%
lower_loudness_outliers
# Out:
# -22.294

# %% [markdown]
# *   OBS.: Neste caso, vamos considerar como outliers de limite inferior, todos
# aqueles com valor abaixo de -60, devido à natureza do atributo

# %%
outliers = df_tracks[df_tracks['loudness'] < -60.0]

# %%
outliers.head()
# Out:
# Empty DataFrame
# Columns: [id, name, popularity, duration, explicit, artists, id_artists, release_year, danceability, energy, key, loudness, mode, speechiness, acousticness, instrumentalness, liveness, valence, tempo, time_signature]
# Index: []

# %%
outliers.shape
# Out:
# (0, 20)

# %% [markdown]
# OUTLIERS ACIMA DO TERCEIRO QUARTIL

# %%
higher_loudness_outliers
# Out:
# 3.082

# %% [markdown]
# *   OBS.: Neste caso, vamos considerar como outliers de limite superior, todos aqueles com valor acima de 0, devido à natureza do atributo

# %%
outliers = df_tracks[df_tracks['loudness'] > 0.0]

# %%
outliers.head()
# Out:
#                            id                     name  popularity  duration  \
# 10869  050FXMyCrQJG01AT55Jvk1                     Sold           0  00:02:32
# 18301  5a1zE4Pl5Y0pEMstZMJlBH                     drag           0  00:03:28
# 31716  4VEyXU24FiXNeanFm1FMgm                 Suzie Q.          35  00:02:16
# 32527  2yOXKIU9YtBSWjI3OA8tqj  Little Bitty Pretty One          57  00:02:23
# 32967  60ZK0nnSbOQDZdCufMwps6            Hey Baba Leba          27  00:02:27
#
#        explicit            artists                id_artists  release_year  \
# 10869         0     [Apocolothoth]  [5YRGJurHafkpJKCRDZrRtP]          1936
# 18301         0      [DYING SPASM]  [7EkuekiTt0lwIjTLKBoON3]          1944
# 31716         0     [Dale Hawkins]  [7kcPzHlsyJm5tDv7JMcr6T]          1958
# 32527         0  [Thurston Harris]  [61VpPyyJn2bitby8tbafzT]          1959
# 32967         0  [Thurston Harris]  [61VpPyyJn2bitby8tbafzT]          1959
#
#        danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 10869         0.000   0.114    0     3.855     0       0.0000      0.000047
# 18301         0.316   0.529   11     1.830     0       0.1390      0.024300
# 31716         0.431   0.898    9     0.439     1       0.0904      0.636000
# 32527         0.706   0.883    8     1.085     1       0.2400      0.777000
# 32967         0.555   0.958    5     2.087     0       0.0492      0.896000
#
#        instrumentalness  liveness  valence    tempo  time_signature
# 10869          0.998000    0.5780   0.0000    0.000               0
# 18301          0.704000    0.1110   0.0368   99.418               5
# 31716          0.000073    0.3230   0.8420  143.177               4
# 32527          0.000002    0.0562   0.8870   88.351               4
# 32967          0.033600    0.1110   0.9660   98.295               4

# %%
outliers.shape
# Out:
# (194, 20)

# %% [markdown]
# ANÁLISE DE *LOUDNESS* DE ACORDO COM A PASSAGEM DAS DÉCADAS

# %%
loudness_by_decades = pd.DataFrame(index=range(len(df_tracks)))

for years, df in tracks_by_decades.items():
  loudness_by_decades[years] = df['loudness']

# %%
loudness_by_decades.boxplot(figsize=(15,10))
# Out:
# /usr/local/lib/python3.7/dist-packages/matplotlib/cbook/__init__.py:1376: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   X = np.atleast_1d(X.T if isinstance(X, np.ndarray) else np.asarray(X))

# %% [markdown]
# ANÁLISE DA MÉDIA DE *LOUDNESS* DAS FAIXAS, DE ACORDO COM O GÊNERO

# %%
loudness_by_genres = df_merged.groupby('genre').loudness.agg(['mean', 'size']).sort_values(by=['mean'])

# %% [markdown]
# Gêneros com menores médias de *loudness*

# %%
loudness_by_genres.head()
# Out:
#                               mean  size
# genre
# welsh choir               -42.1370     1
# abstract idm              -37.5180     1
# caucasian classical piano -36.2520     1
# korean classical piano    -35.5040     4
# binaural                  -35.0846     5

# %% [markdown]
# Gêneros com maiores médias de *loudness*

# %%
loudness_by_genres.tail()
# Out:
#                           mean  size
# genre
# mainland se asia metal -1.4900     1
# belgian dnb            -0.5510     2
# aikatsu                 0.2390     1
# singaporean metal       2.3895     2
# singaporean punk        2.3895     2

# %% [markdown]
# **Conclusões:**
#
# 1.   Temos 194 faixas com volume maior que 0 dB, e nenhuma com menos de -60dB
# 2.   As faixas da década de 1930 possuem, na mediana, o *loudness* maior que seus contemporâneos
# 3.   *Loudness* é um atributo que tende a aumentar com o passar das décadas, porém, quanto mais se aumenta a mediana deste atributo, aumenta-se, também, a 'cauda' de outliers abaixo do limite inferior
# 4.   Considerando os gêneros que contém, no mínimo, 10 faixas distintas, aqueles de maior média de *loudness* são *japanese metalcore*, *yaoi* e *speedcore*
# 5.   Os gêneros de menor média são *ukrainian choir*, *orthodox chant* e *native american flute*

# %% [markdown]
# # - track mode : modo da faixa (maior ou menor)

# %% [markdown]
# *   0 - modo (acorde) menor
# *   1 - modo (acorde) maior

# %%
df_tracks['mode'].value_counts().plot(kind='bar', color=['teal', 'orange'])

# %%
df_tracks['mode'].value_counts()
# Out:
# 1    321716
# 0    168227
# Name: mode, dtype: int64

# %% [markdown]
# ANÁLISE DE *MODE* DE ACORDO COM A PASSAGEM DAS DÉCADAS

# %%
mode_by_decades = pd.DataFrame(index=range(len(df_tracks)))

for years, df in tracks_by_decades.items():
  mode_by_decades[years] = df['mode']

# %%
fig, axs = plt.subplots(1, 11, figsize=(25, 8))
plt.subplots_adjust(wspace=1.0)
ax = axs.ravel()

fig.text(0.5, 0.03, '0 - mode menor | 1 - mode maior', ha='center', fontsize=13)

i = 0
for years, df in mode_by_decades.items():
  df.hist(bins=range(3), ax=ax[i]).set_title(years, y=1.03)
  i += 1

plt.show()

# %% [markdown]
# ANÁLISE DE *MODE* DAS FAIXAS, DE ACORDO COM O GÊNERO

# %%
menor_mode_by_genres = df_merged[df_merged['mode'] == 0].groupby('genre').size().sort_values(ascending=False)
maior_mode_by_genres = df_merged[df_merged['mode'] == 1].groupby('genre').size().sort_values(ascending=False)

# %% [markdown]
# Gêneros com mais faixas de *mode* menor

# %%
menor_mode_by_genres.head(10)
# Out:
# genre
# not specified            25988
# filmi                     9456
# rock                      5660
# classical                 5247
# adult standards           5236
# desi pop                  5085
# sufi                      5054
# latin                     4535
# classic bollywood         4436
# classical performance     3977
# dtype: int64

# %% [markdown]
# Gêneros com mais faixas de *mode* maior

# %%
maior_mode_by_genres.head(10)
# Out:
# genre
# not specified            54755
# adult standards          16295
# rock                     15427
# filmi                    13809
# classical                13568
# classic rock             12131
# mellow gold              11210
# classical performance    10768
# folk rock                 9673
# soft rock                 9485
# dtype: int64

# %% [markdown]
# **Conclusões:**
#
#
# 1.   Em todas as décadas, foram lançadas mais faixas de modo (acorde) maior, do que menor
# 2.   Os gêneros *rock* e *classic rock* estão tanto entre os que mais têm faixas de acorde menor, quanto os que mais têm faixas de acorde maior
# 3.   Músicas de gênero *latin* e *dance pop* também figuram entre os que mais têm faixas de modo menor
# 4.   Enquanto que outros subgêneros do rock estão entre os que mais têm faixas de modo maior, como *soft rock*, *album rock* e *folk rock*

# %% [markdown]
# # - track speechiness : o quão 'falada' é uma faixa

# %% [markdown]
# *   Valores variam de 0.0 até 1.0, sendo que:
# *   Acima de 0,66: faixas que provavelmente são compostas inteiramente de palavras faladas
# *   Entre 0,33 e 0,66: faixas que podem conter música e fala,  incluindo casos como música rap
# *   Abaixo de 0,33: provavelmente representam música e outras faixas não semelhantes à fala

# %% [markdown]
# EXCLUSÃO DE FAIXAS NÃO MUSICAIS (POR EX.: AUDIOBOOKS)

# %% [markdown]
# *   Como identificado anteriormente, temos registros no DataFrame Tracks que são, na verdade, faixas de audiobooks
# *   Essas faixas devem ser excluídas dos datasets, pois não é escopo deste projeto gerar playlists para este tipo de artefato
# *   Para isso, vamos usar o atributo *speechiness*, excluindo todos aqueles que possuem valor acima de 0,66

# %%
df_tracks = df_tracks[df_tracks['speechiness'] < 0.66]

# %% [markdown]
# REPLICANDO A EXCLUSÃO NOS DEMAIS DATAFRAMES

# %%
df_tracks_exploded = df_tracks_exploded[df_tracks_exploded['speechiness'] < 0.66]
df_merged = df_merged[df_merged['speechiness'] < 0.66]

# %%
for yrs in range(1920, 2030, 10):
  years = f'the_{str(yrs)}s'
  tracks_by_decades[years] = tracks_by_decades[years][tracks_by_decades[years].speechiness < 0.66]

# %% [markdown]
# ANÁLISE DE OUTLIERS

# %%
df_tracks.boxplot(column=['speechiness'])

# %%
q1 = df_tracks['speechiness'].quantile(0.25)
q3 = df_tracks['speechiness'].quantile(0.75)

IQR = q3 - q1

lower_speechiness_outliers = q1 - 1.5 * IQR
higher_speechiness_outliers = q3 + 1.5 * IQR

# %% [markdown]
# *   Não existem outliers abaixo do limite do 1º quartil

# %% [markdown]
# OUTLIERS ACIMA DO TERCEIRO QUARTIL

# %%
higher_speechiness_outliers
# Out:
# 0.12210000000000001

# %%
outliers = df_tracks[df_tracks['speechiness'] > higher_speechiness_outliers]

# %%
outliers.head()
# Out:
#                         id                  name  popularity  duration  \
# 0   35iwgR4jXetI318WEWsa1Q                 Carve           6  00:02:06
# 6   0Dd9ImXtAtGwsmsAD69KZT        La Butte Rouge           0  00:02:14
# 9   0JV4iqw2lSKJaHBQZ0e5zK         Martín Fierro           0  00:03:01
# 12  0PH9AACae1f957JAavhOl2              Lazy Boi           0  00:02:37
# 13  0QiT0Oo5QdLXdFw6RDOj7h  Tu Verras Montmartre           1  00:03:06
#
#     explicit            artists                id_artists  release_year  \
# 0          0              [Uli]  [45tIt06XoI0Iio4LBEVpls]          1922
# 6          0    [Francis Marty]  [2nuMRGzeJ5jJEKlfS7rZ0W]          1922
# 9          0  [Ignacio Corsini]  [5LiOoJbxVSAMkBS2fUm3X2]          1922
# 12         0              [Uli]  [45tIt06XoI0Iio4LBEVpls]          1922
# 13         0     [Lucien Boyer]  SouLpNSEY1d7OdIjlFiP]          1922
#
#     danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0          0.645  0.4450    0   -13.338     1        0.451         0.674
# 6          0.510  0.3550    4   -12.833     1        0.124         0.965
# 9          0.548  0.0391    6   -23.228     1        0.153         0.996
# 12         0.298  0.4600    1   -18.645     1        0.453         0.521
# 13         0.703  0.2800    0   -15.390     1        0.174         0.995
#
#     instrumentalness  liveness  valence    tempo  time_signature
# 0           0.744000     0.151    0.127  104.851               3
# 6           0.000000     0.155    0.727   85.754               5
# 9           0.933000     0.148    0.612   75.595               3
# 12          0.856000     0.436    0.402   87.921               4
# 13          0.000068     0.163    0.897  127.531               4

# %%
outliers.shape
# Out:
# (59998, 20)

# %% [markdown]
# ANÁLISE DO *SPEECHINESS* DE ACORDO COM A PASSAGEM DAS DÉCADAS

# %%
speechiness_by_decades = pd.DataFrame(index=range(len(df_tracks)))

# %%
for years, df in tracks_by_decades.items():
  speechiness_by_decades[years] = df['speechiness']

# %%
speechiness_by_decades.boxplot(figsize=(15,10))
# Out:
# /usr/local/lib/python3.7/dist-packages/matplotlib/cbook/__init__.py:1376: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   X = np.atleast_1d(X.T if isinstance(X, np.ndarray) else np.asarray(X))

# %% [markdown]
# ANÁLISE DA MÉDIA DE *SPEECHINESS* DAS FAIXAS, DE ACORDO COM O GÊNERO

# %%
speechiness_by_genres = df_merged.groupby('genre').speechiness.agg(['mean', 'size']).sort_values(by=['mean'])

# %% [markdown]
# Gêneros com menores médias de *speechiness*

# %%
speechiness_by_genres.head()
# Out:
#                      mean  size
# genre
# spa                0.0000     1
# modern jangle pop  0.0255     1
# fort worth indie   0.0255     2
# lowercase          0.0260     1
# german shoegaze    0.0260     1

# %% [markdown]
# Gêneros com maiores médias de *speechiness*

# %%
speechiness_by_genres.tail()
# Out:
#                 mean  size
# genre
# maracatu      0.4520     1
# rap nortista  0.4530     1
# piada         0.5165     2
# comedia       0.5502    10
# baithak gana  0.6290     1

# %% [markdown]
# **Conclusões:**
#
#
# 1.   Dos anos 1920 até 1960, houve uma queda na média de *speechiness* das faixas, isto é, com o passar do tempo, as músicas foram ficando menos faladas
# 2.   Apartir a década de 1960, porém, houve uma inversão nesta característica, e, na década de 2020 temos a maior média em valor de *speechiness* entre todos os períodos
# 3.   Isso levanta um questionamento, pois, músicas muito faladas não estão, necessariamente, "em voga". O que pode caracterizar que ainda existe uma quantidade considerável de faixas não musicais no dataset
# 4.   Considerando os gêneros que contém, no mínimo, 10 faixas distintas, os gêneros de maior média de *speechiness* são *beat poetry*, *poetry*, *reading* e *comedia*
# 5.   Assim sendo, observamos que ainda temos registros em nosso dataset que se tratam, na verdade, de faixas faladas, e que não foram excluídas anteriormente
# 6.   Faremos uma combinação destas faixas ainda presentes (*speechiness* abaixo de 0.66) com outros atributos, como, por exemplo, *acousticness*, para descartar mais faixas faladas (gênero comédia, poesia, etc)
# 7.   Os gêneros de menor média de *speechiness* são *pop minang*, *trio batak* e *chinese indie pop*

# %% [markdown]
# # - track acousticness : medida que indica a probabilidade da faixa ser acústica

# %% [markdown]
# *   Valores variam entre 0.0 até 1.0

# %% [markdown]
# EXCLUSÃO DE FAIXAS NÃO MUSICAIS (POR EX.: AUDIOBOOKS)

# %% [markdown]
# *   Como observamos na relação dos gêneros de maior média de *speechiness*, após a exclusão das faixas cujo tal atributo seja superior a 0.66, ainda temos várias faixas não musicais, como, por exemplo, faixas dos gêneros "*comedia*", "*poetry*" e "*piada*"
# *   Como o atributo de *speechiness* (superior a 0.66) não foi suficiente para capturar estes itens, vamos combinar as faixas do segundo nível de *speechiness* (entre 0.33 e 0.66) com o atributo *acousticness*, que também faz alusão a faixas não cantadas (quanto maior seu valor, maiores as chances da faixa ser falada)
# *   Já que não temos uma divisão clara para este atributo, assim como tínhamos p/ o anterior, vamos combinar as canções com o 3º quartil de *acousticness* das faixas que temos

# %%
df_tracks['acousticness'].describe()
# Out:
# count    480659.000000
# mean          0.446288
# std           0.349545
# min           0.000000
# 25%           0.094600
# 50%           0.411000
# 75%           0.783000
# max           0.996000
# Name: acousticness, dtype: float64

# %%
df_tracks = df_tracks.loc[ (df_tracks['speechiness'] < 0.33)  &  (df_tracks['acousticness'] < 0.783) ]

# %% [markdown]
# REPLICANDO A EXCLUSÃO NOS DEMAIS DATAFRAMES

# %%
df_tracks_exploded = df_tracks_exploded[ (df_tracks_exploded['speechiness'] < 0.33)  &  (df_tracks_exploded['acousticness'] < 0.783) ]
df_merged = df_merged[ (df_merged['speechiness'] < 0.33)  &  (df_merged['acousticness'] < 0.783) ]

# %%
for yrs in range(1920, 2030, 10):
  years = f'the_{str(yrs)}s'
  tracks_by_decades[years] = tracks_by_decades[years][ (tracks_by_decades[years]['speechiness'] < 0.33)  &  (tracks_by_decades[years]['acousticness'] < 0.783) ]

# %% [markdown]
# Até este ponto da análise, retiramos do dataset principal (e dos resultantes) as faixas:
#
# *   Cujo conjunto [nome, artista e gênero] se repete integralmente
# *   Cuja duração é menor de 1 minuto
# *   Cuja duração é de 20 minutos ou mais
# *   Cujo atributo *speechiness* era acima de 0.66
# *   Cujo atributo *speechiness* era acima de 0.33, e com *acousticness* maior que 0.786

# %% [markdown]
# ANÁLISE DE OUTLIERS

# %%
df_tracks.boxplot(column=['acousticness'])

# %% [markdown]
# *   Não existem outliers neste atributo

# %% [markdown]
# ANÁLISE DE *ACOUSTICNESS* DE ACORDO COM A PASSAGEM DAS DÉCADAS

# %%
acousticness_by_decades = pd.DataFrame(index=range(len(df_tracks)))

# %%
for years, df in tracks_by_decades.items():
  acousticness_by_decades[years] = df['acousticness']

# %%
acousticness_by_decades.boxplot(figsize=(15,10))
# Out:
# /usr/local/lib/python3.7/dist-packages/matplotlib/cbook/__init__.py:1376: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   X = np.atleast_1d(X.T if isinstance(X, np.ndarray) else np.asarray(X))

# %% [markdown]
# ANÁLISE DA MÉDIA DE *ACOUSTICNESS* DAS FAIXAS, DE ACORDO COM O GÊNERO

# %%
acousticness_by_genres = df_merged.groupby('genre').acousticness.agg(['mean', 'size']).sort_values(by=['mean'])

# %% [markdown]
# Gêneros com menores médias de *acousticness*

# %%
acousticness_by_genres.head()
# Out:
#                                    mean  size
# genre
# irish experimental electronic  0.000001     1
# binaural                       0.000003     1
# brain waves                    0.000003     1
# grisly death metal             0.000004     1
# quebec death metal             0.000005     2

# %% [markdown]
# Gêneros com maiores médias de *acousticness*

# %%
acousticness_by_genres.tail()
# Out:
#                             mean  size
# genre
# sarod                      0.779     1
# vintage classical singing  0.779     1
# demoscene                  0.780     1
# brass quintet              0.781     1
# galante era                0.782     1

# %% [markdown]
# *   Como visto acima, *acousticness* tem uma correlação negativa com *loudness* e *energy*
# *   Observaremos esta correlação graficamente

# %%
plt.figure(figsize=(10,6))
plt.scatter(df_tracks_sample['acousticness'], df_tracks_sample['loudness'], c=['salmon'])

plt.title('Correlação entre Acousticness e Loudness')
plt.xlabel('Acousticness')
plt.ylabel('Loudness');

# %%
plt.figure(figsize=(10,6))
plt.scatter(df_tracks_sample['acousticness'], df_tracks_sample['energy'], c=['salmon'])

plt.title('Correlação entre Acousticness e Energy')
plt.xlabel('Acousticness')
plt.ylabel('Energy');

# %% [markdown]
# **Conclusões:**
#
# 1.   Até a década de 1950, as faixas eram quase sempre acústicas, isto é, com o atributo *acousticness* muito próximo de 1.0, porém, haviam exceções
# 2.   A partir da década de 1960, as faixas foram ficando menos acústicas, com valores mais bem distribuídos entre 0.0 e 1.0
# 3.   Considerando os gêneros que contém, no mínimo, 10 faixas distintas, aqueles de menor média de *acousticness* são *british death metal*, *death n roll*, *technical thrash* e *buffallo ny metal*
# 4.   Já os gêneros de maior média de *acousticness* são em maioria subgêneros de *classical piano*
# 5.  Existe uma tendência de que, quanto maior o *acousticness* das faixas, menor é o atributo *energy*

# %% [markdown]
# # - track instrumentalness : medida que indica a probabilidade da faixa ser instrumental

# %% [markdown]
# *   Valores variam entre 0.0 até 1.0

# %% [markdown]
# ANÁLISE DE OUTLIERS

# %%
df_tracks.boxplot(column=['instrumentalness'])

# %%
q1 = df_tracks['instrumentalness'].quantile(0.25)
q3 = df_tracks['instrumentalness'].quantile(0.75)

IQR = q3 - q1

lower_instrumentalness_outliers = q1 - 1.5 * IQR
higher_instrumentalness_outliers = q3 + 1.5 * IQR

# %% [markdown]
# *   Não existem outliers abaixo do limite do 1º quartil

# %% [markdown]
# OUTLIERS ACIMA DO TERCEIRO QUARTIL

# %%
higher_instrumentalness_outliers
# Out:
# 0.00515

# %%
outliers = df_tracks[df_tracks['instrumentalness'] >= higher_instrumentalness_outliers]

# %%
outliers.head()
# Out:
#                          id                name  popularity  duration  \
# 8    0IgI1UCz84pYeVetnl1lGP  Old Fashioned Girl           0  00:05:10
# 46   1l1Wk0nOkuMCzioN6l2yfJ  Carol of the Bells           0  00:04:46
# 112  598LlBn6jpEpVbLjmZPsYV            Graphite           0  00:01:44
# 131  6MD9XSLD4VmVI5SFRPm6By           Car Loans           0  00:02:52
# 403  2l56fKIIrgfHWndcbkBAta       The C00L Song           0  00:02:00
#
#      explicit            artists                id_artists  release_year  \
# 8           0      [Greg Fieler]  [5nWlsH5RDgFuRAiDeOFVmf]          1922
# 46          0  [Grandcubby Trio]  [4XVZpokXbUzg6QeomBANY9]          1922
# 112         0              [Uli]  [45tIt06XoI0Iio4LBEVpls]          1922
# 131         0              [Uli]  [45tIt06XoI0Iio4LBEVpls]          1922
# 403         1       [Dampfwalzi]  [41GUFwc0gpqt495qHXpxFB]          1923
#
#      danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 8           0.488   0.475    0   -16.222     0       0.0399      0.620000
# 46          0.382   0.750   10   -11.599     1       0.0742      0.123000
# 112         0.644   0.684    7    -8.247     1       0.1990      0.144000
# 131         0.651   0.574   10   -11.999     0       0.1040      0.474000
# 403         0.503   0.823    9   -12.871     0       0.0640      0.000243
#
#      instrumentalness  liveness  valence    tempo  time_signature
# 8             0.00645    0.1070    0.544  139.952               4
# 46            0.75100    0.7250    0.346  149.787               3
# 112           0.80200    0.0847    0.138  100.031               4
# 131           0.71300    0.0597    0.412   99.878               4
# 403           0.64000    0.4730    0.401   97.019               4

# %%
outliers.shape
# Out:
# (75305, 20)

# %% [markdown]
# ANÁLISE DE *INSTRUMENTALNESS* DE ACORDO COM A PASSAGEM DAS DÉCADAS

# %%
instrumentalness_by_decades = pd.DataFrame(index=range(len(df_tracks)))

# %%
for years, df in tracks_by_decades.items():
  instrumentalness_by_decades[years] = df['instrumentalness']

# %%
instrumentalness_by_decades.boxplot(figsize=(15,10))
# Out:
# /usr/local/lib/python3.7/dist-packages/matplotlib/cbook/__init__.py:1376: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   X = np.atleast_1d(X.T if isinstance(X, np.ndarray) else np.asarray(X))

# %% [markdown]
# ANÁLISE DA MÉDIA DE *INSTRUMENTALNESS* DAS FAIXAS, DE ACORDO COM O GÊNERO

# %%
instrumentalness_by_genres = df_merged.groupby('genre').instrumentalness.agg(['mean', 'size']).sort_values(by=['mean'])

# %% [markdown]
# Gêneros com menores médias de *instrumentalness*

# %%
instrumentalness_by_genres.head()
# Out:
#                     mean  size
# genre
# gothic alternative   0.0     1
# indie canario        0.0     1
# balalaika            0.0     1
# indiana hip hop      0.0     3
# modern uplift        0.0     2

# %% [markdown]
# Gêneros com maiores médias de *instrumentalness*

# %%
instrumentalness_by_genres.tail()
# Out:
#                      mean  size
# genre
# organic ambient     0.951     1
# musica antigua      0.952     1
# celtic harp         0.956     2
# british brass band  0.968     1
# spa                 0.999     1

# %% [markdown]
# **Conclusões:**
#
#
# 1.   Até a década de 1940, havia uma considerável distribuição entre faixas de alto e baixo índice de *instrumentalness*
# 2.   A partir da década de 1950 aumentou-se consideravelmente a concentração das faixas em níveis baixos de *instrumentalness*, contudo, existindo conjuntamente a muitos outliers
# 3.   Considerando os gêneros que contém, no mínimo, 10 faixas distintas, aqueles de maior média de *instrumentalness* são *focus*, *background piano* e *ancient mediterranean*
# 4.   Os gêneros de menor média são *detroit trap*, *frevo* e *funk evangelico*

# %% [markdown]
# # - track liveness : indica a probabilidade da faixa ser ao vivo, ou não

# %% [markdown]
# *   Valores variam entre 0.0 até 1.0
# *   Identifica a presença ou ausência de uma platéia

# %% [markdown]
# ANÁLISE DE OUTLIERS

# %%
df_tracks.boxplot(column=['liveness'])

# %%
q1 = df_tracks['liveness'].quantile(0.25)
q3 = df_tracks['liveness'].quantile(0.75)

IQR = q3 - q1

lower_liveness_outliers = q1 - 1.5 * IQR
higher_liveness_outliers = q3 + 1.5 * IQR

# %% [markdown]
# *   Não existem outliers abaixo do limite do 1º quartil

# %% [markdown]
# OUTLIERS ACIMA DO TERCEIRO QUARTIL

# %%
higher_liveness_outliers
# Out:
# 0.52785

# %%
outliers = df_tracks[df_tracks['liveness'] >= higher_liveness_outliers]

# %%
outliers.head()
# Out:
#                           id                   name  popularity  duration  \
# 46    1l1Wk0nOkuMCzioN6l2yfJ     Carol of the Bells           0  00:04:46
# 1839  7lTGnqo3hLHbVJNqExZGuE            Liebestraum           4  00:03:26
# 2033  02R3JMuw0E8uloMBpHG3Yz  Submission Accomplice           0  00:01:18
# 2124  0r5xvEZEjDarFkomOBHjdT         Sati Rawn Tana           0  00:02:25
# 2615  4xe9n6IXfr6Acz6eEogyYT     Strip Down Suit Up           0  00:01:38
#
#       explicit            artists                id_artists  release_year  \
# 46           0  [Grandcubby Trio]  [4XVZpokXbUzg6QeomBANY9]          1922
# 1839         0     [Tommy Dorsey]  [4WoGga7UeRcmjD4ufif4nG]          1925
# 2033         0    [Future Rapper]  [2la3t6tT3UzEJaENsqudLP]          1926
# 2124         0    [Future Rapper]  [2la3t6tT3UzEJaENsqudLP]          1926
# 2615         0    [Future Rapper]  [2la3t6tT3UzEJaENsqudLP]          1926
#
#       danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 46           0.382   0.750   10   -11.599     1       0.0742      0.123000
# 1839         0.496   0.418    5    -9.183     0       0.1970      0.774000
# 2033         0.401   0.610    2   -12.807     1       0.0277      0.031100
# 2124         0.868   0.626    1   -13.414     1       0.2210      0.035000
# 2615         0.719   0.439    9    -9.524     1       0.0637      0.000881
#
#       instrumentalness  liveness  valence    tempo  time_signature
# 46              0.7510     0.725    0.346  149.787               3
# 1839            0.6370     0.678    0.735  172.257               4
# 2033            0.9700     0.637    0.270  160.240               4
# 2124            0.0502     0.715    0.561  112.532               4
# 2615            0.6580     0.613    0.401  120.085               4

# %%
outliers.shape
# Out:
# (20864, 20)

# %% [markdown]
# ANÁLISE DE *LIVENESS* DE ACORDO COM A PASSAGEM DAS DÉCADAS

# %%
liveness_by_decades = pd.DataFrame(index=range(len(df_tracks)))

# %%
for years, df in tracks_by_decades.items():
  liveness_by_decades[years] = df['liveness']

# %%
liveness_by_decades.boxplot(figsize=(15,10))
# Out:
# /usr/local/lib/python3.7/dist-packages/matplotlib/cbook/__init__.py:1376: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   X = np.atleast_1d(X.T if isinstance(X, np.ndarray) else np.asarray(X))

# %% [markdown]
# ANÁLISE DA MÉDIA DE *LIVENESS* DAS FAIXAS, DE ACORDO COM O GÊNERO

# %%
liveness_by_genres = df_merged.groupby('genre').liveness.agg(['mean', 'size']).sort_values(by=['mean'])

# %% [markdown]
# Gêneros com menores médias de *liveness*

# %%
liveness_by_genres.head()
# Out:
#                      mean  size
# genre
# deep smooth r&b    0.0235     1
# tulum              0.0338     1
# chennai indie      0.0351     1
# bangladeshi rock   0.0389     1
# bangladeshi indie  0.0389     1

# %% [markdown]
# Gêneros com maiores médias de *liveness*

# %%
liveness_by_genres.tail()
# Out:
#                        mean  size
# genre
# south carolina metal  0.925     1
# new comedy            0.926     1
# wind symphony         0.937     1
# italian doom metal    0.949     1
# comptine africaine    0.955     1

# %% [markdown]
# **Conclusões:**
#
# 1.   Relativo ao item *livess*, existe uma distribuição comum entre as décadas (tanto da média, quanto do limite dos quartis)
# 2.   Considerando os gêneros que contém, no mínimo, 10 faixas distintas, aqueles de maior média de *liveness* são *seattle metal*, *traditional ska*, *water* e *environmental*
# 3.   Os gêneros de menor média são *amapiano*, *vogue* e *brazilian modern jazz*

# %% [markdown]
# # - track valence : descreve a positividade transmitida pela faixa

# %% [markdown]
# *   Valores variam entre 0.0 até 1.0
# *   Alta valência indica faixas que soam mais positivas (por ex.: feliz, alegre, eufórico)
# *   Faixas com baixa valência soam mais negativas (por ex.: triste, deprimido, com raiva)

# %% [markdown]
# ANÁLISE DE OUTLIERS

# %%
df_tracks.boxplot(column=['valence'])

# %% [markdown]
# *   Não existem outliers neste atributo

# %% [markdown]
# ANÁLISE DE *VALENCE* DE ACORDO COM A PASSAGEM DAS DÉCADAS

# %%
valence_by_decades = pd.DataFrame(index=range(len(df_tracks)))

# %%
for years, df in tracks_by_decades.items():
  valence_by_decades[years] = df['valence']

# %%
valence_by_decades.boxplot(figsize=(15,10))
# Out:
# /usr/local/lib/python3.7/dist-packages/matplotlib/cbook/__init__.py:1376: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   X = np.atleast_1d(X.T if isinstance(X, np.ndarray) else np.asarray(X))

# %% [markdown]
# ANÁLISE DA MÉDIA DE *VALENCE* DAS FAIXAS, DE ACORDO COM O GÊNERO

# %%
valence_by_genres = df_merged.groupby('genre').valence.agg(['mean', 'size']).sort_values(by=['mean'])

# %% [markdown]
# Gêneros com menores médias de *valence*

# %%
valence_by_genres.head()
# Out:
#                               mean  size
# genre
# american classical piano  0.000000     1
# spa                       0.000000     1
# neru                      0.000010     4
# world meditation          0.006370     4
# white noise               0.013639    18

# %% [markdown]
# Gêneros com maiores médias de *valence*

# %%
valence_by_genres.tail()
# Out:
#                            mean  size
# genre
# slovenian folk           0.9705     2
# gumbe                    0.9710     1
# christmas product        0.9720     1
# spanish classical piano  0.9748     5
# ngoni                    0.9760     1

# %% [markdown]
# **Conclusões:**
#
# 1.   O dataset é composto tanto por faixas de alta positividade, quanto de baixa positividade, sem uma inclinação significativa pra qualquer um dos dois extremos
# 2.   A mediana, em todas as décadas, gira em torno de 0.6, porém a partir dos anos 2000 ela vem se deslocando pra baixo, isto é, canções de menor positividade vem sendo lançadas desde o início do século
# 3.   A maior mediana de *valence* ocorreu nas décadas de 1950 e 1960
# 4.   Considerando os gêneros que contém, no mínimo, 10 faixas distintas, aqueles de menor média de *valence* são *water*, *white noise* e *environmental*, isto é, estilos de musicas mais meditativos
# 5.   Já os gêneros de maior média de *valence* são *music box*, *piseiro* e *tecnobanda*

# %% [markdown]
# # - track tempo : tempo geral estimado de uma faixa, em batidas por minuto (BPM)

# %% [markdown]
# *   Valor igual ou maior que 0
# *   Velocidade ou ritmo de uma determinada peça e deriva diretamente da duração média do tempo

# %% [markdown]
# ANÁLISE DE OUTLIERS

# %%
df_tracks.boxplot(column=['tempo'])

# %% [markdown]
# *   Existem outliers tanto acima, quanto abaixo dos limites dos quartis

# %%
q1 = df_tracks['tempo'].quantile(0.25)
q3 = df_tracks['tempo'].quantile(0.75)

IQR = q3 - q1

lower_tempo_outliers = q1 - 1.5 * IQR
higher_tempo_outliers = q3 + 1.5 * IQR

# %% [markdown]
# OUTLIERS ABAIXO DO PRIMEIRO QUARTIL

# %%
lower_tempo_outliers
# Out:
# 40.87099999999999

# %%
outliers = df_tracks[df_tracks['tempo'] <= lower_tempo_outliers]

# %%
outliers.head()
# Out:
#                            id  \
# 8823   6cnAsKhXq5X1BFiDTdSp4W
# 10869  050FXMyCrQJG01AT55Jvk1
# 15304  24mFr4NTDNpYYUtlsfy4Y1
# 18347  6CMBpPcW5HH8VM5mpwCzRS
# 18850  0BEGv9OVHC33uI0jBeWMIZ
#
#                                                     name  popularity  \
# 8823     Prelude and Fugue in G Major BWV 541: II. Fugue           0
# 10869                                               Sold           0
# 15304                                    Das Vermächtnis           0
# 18347                            Suno Suno Tumhen Sunaye           0
# 18850  Sonata No. 7 in B-Flat, Op. 83: Allegro inquie...           0
#
#        duration  explicit                                     artists  \
# 8823   00:05:30         0  [Johann Sebastian Bach, Albert Schweitzer]
# 10869  00:02:32         0                              [Apocolothoth]
# 15304  00:02:09         0                            [Mathias Wieman]
# 18347  00:02:43         0                                   [K Dutta]
# 18850  00:08:17         0          [Sergei Prokofiev, William Kapell]
#
#                                              id_artists  release_year  \
# 8823   [5aIqB5nVVvmFsvSdExz408, 4n3YrsJmeY6qTYJyGwGCRI]          1933
# 10869                          [5YRGJurHafkpJKCRDZrRtP]          1936
# 15304                          [7lStlBlWQuV8jkY6mjNG9T]          1941
# 18347                          [2sOPDx3ICYZJspPHFZNysM]          1944
# 18850  [4kHtgiRnpmFIV5Tm4BIs8l, 5qsrEqlTIFVbXBB2xd7qoh]          1945
#
#        danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 8823         0.0796  0.2700    7   -12.306     1       0.0384      0.735000
# 10869        0.0000  0.1140    0     3.855     0       0.0000      0.000047
# 15304        0.0000  0.0134    8   -26.028     1       0.0000      0.493000
# 18347        0.0000  1.0000    1    -4.363     1       0.0000      0.202000
# 18850        0.0000  0.1290    5   -20.528     0       0.0000      0.773000
#
#        instrumentalness  liveness  valence   tempo  time_signature
# 8823             0.8270     0.164    0.176  33.944               4
# 10869            0.9980     0.578    0.000   0.000               0
# 15304            0.0000     0.504    0.000   0.000               0
# 18347            0.9990     0.647    0.000   0.000               0
# 18850            0.0988     0.284    0.000   0.000               0

# %%
outliers.shape
# Out:
# (138, 20)

# %% [markdown]
# OUTLIERS ACIMA DO TERCEIRO QUARTIL

# %%
higher_tempo_outliers
# Out:
# 198.36700000000002

# %%
outliers = df_tracks[df_tracks['tempo'] >= higher_tempo_outliers]

# %%
outliers.head()
# Out:
#                           id                                name  popularity  \
# 6143  275EeuRyuxgNJjAhvvVY50                 Roll Over Beethoven           0
# 7020  55R3IoTiGpdcT3w9YXtvy7                          Summer Bay           0
# 7304  2a8JpO3JP8atv9bNuVibHS      Sleigh Ride (with Paula Kelly)           8
# 7659  3N4D5t5X6AJZ1vdbszwoC0  Go Santa Oh / Go Daddy oh (medley)           0
# 7773  4d1omCDRzg5p4ajpWjgtBB                    Oooh-Dahdily-Dah           2
#
#       duration  explicit                                            artists  \
# 6143  00:03:11         0                                 [The Penetraitors]
# 7020  00:05:35         0                               [Sax Man Mike Clark]
# 7304  00:03:01         0  [Tex Beneke, Ray Eberle, The Modernaires, Paul...
# 7659  00:04:11         0                              [Cocktail de Nervios]
# 7773  00:02:19         0                         [Louis Prima, Keely Smith]
#
#                                              id_artists  release_year  \
# 6143                           [1T1uvwxmGNuyHOPICU8jB6]          1930
# 7020                           [77zGY6H5ikrI96LmBZRcVG]          1931
# 7304  [7e9843xr17L5hRYAti3dtG, 1ZFyAaDK4vvhDg3JeR8Hi...          1932
# 7659                           [6OpudeoBfcvBoV0UjfdGCE]          1932
# 7773   [52lBOxCxbJg0ttXEW9CQpW, 0vQqxnQk1G32RtjSAFq3z1]          1932
#
#       danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 6143         0.186   0.963    7    -4.894     1       0.1050        0.0437
# 7020         0.334   0.658    2    -6.113     0       0.0348        0.0806
# 7304         0.423   0.417    3   -12.682     1       0.0404        0.5940
# 7659         0.477   0.370    5   -18.507     0       0.2140        0.3830
# 7773         0.502   0.799    7    -4.375     1       0.1810        0.7750
#
#       instrumentalness  liveness  valence    tempo  time_signature
# 6143          0.000000    0.1890    0.514  201.563               4
# 7020          0.866000    0.0748    0.513  199.931               4
# 7304          0.000088    0.3110    0.873  201.613               4
# 7659          0.587000    0.0687    0.722  198.769               4
# 7773          0.000017    0.2730    0.940  207.370               4

# %%
outliers.shape
# Out:
# (3034, 20)

# %% [markdown]
# ANÁLISE DE *TEMPO* DE ACORDO COM A PASSAGEM DAS DÉCADAS

# %%
tempo_by_decades = pd.DataFrame(index=range(len(df_tracks)))

# %%
for years, df in tracks_by_decades.items():
  tempo_by_decades[years] = df['tempo']

# %%
tempo_by_decades.boxplot(figsize=(15,10))
# Out:
# /usr/local/lib/python3.7/dist-packages/matplotlib/cbook/__init__.py:1376: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   X = np.atleast_1d(X.T if isinstance(X, np.ndarray) else np.asarray(X))

# %% [markdown]
# ANÁLISE DA MÉDIA DE *TEMPO* DAS FAIXAS, DE ACORDO COM O GÊNERO

# %%
tempo_by_genres = df_merged.groupby('genre').tempo.agg(['mean', 'size']).sort_values(by=['mean'])

# %% [markdown]
# Gêneros com menores médias de *tempo*

# %%
tempo_by_genres.head()
# Out:
#                                  mean  size
# genre
# american classical piano     0.000000     1
# spa                          0.000000     1
# world meditation            44.441250     4
# historic piano performance  50.797500     2
# white noise                 53.961944    18

# %% [markdown]
# Gêneros com maiores médias de *tempo*

# %%
tempo_by_genres.tail()
# Out:
#                        mean  size
# genre
# punk mexicano       188.466     1
# tijuana indie       189.277     1
# kaba gaida          189.315     1
# musica piemonteisa  191.704     1
# manitoba indie      207.576     1

# %% [markdown]
# **Conclusões:**
#
# 1.   A mediana das faixas, em todas as décadas, gira em torno de 125 BPM
# 2.   A década com canções de menor BPM foi, de novo, a década de 1940
# 5.   Considerando os gêneros que contém, no mínimo, 10 faixas distintas, aqueles de menor média de *valence* são *sound*, *white noise* e *middle eastern traditional*
# 6.   Já os gêneros de maior média de *tempo* são *piseiro*, *neurofunk* e *surf punk*

# %%
df_tracks
# Out:
#                             id                          name  popularity  \
# 8       0IgI1UCz84pYeVetnl1lGP            Old Fashioned Girl           0
# 46      1l1Wk0nOkuMCzioN6l2yfJ            Carol of the Bells           0
# 51      1v0HtSUeQOu3ba28pvYE5y  Chicago (That Toddlin' Town)           0
# 112     598LlBn6jpEpVbLjmZPsYV                      Graphite           0
# 131     6MD9XSLD4VmVI5SFRPm6By                     Car Loans           0
# ...                        ...                           ...         ...
# 586664  1Kzjk1EyngBcP4T8x3fyqv      同行 (新加坡電視劇《愛...沒有距離》主題曲)          43
# 586666  1ZwZsVZUiyFwIHMNpI3ERt                    Skyscraper           4
# 586668  0NuWgxEp51CutD2pJoF4OM                         blind          72
# 586670  45XJsGpFTyzbzeWK8VzR8S               A Day At A Time          58
# 586671  5Ocn6dZ3BJFPWh4ylwFXtn              Mar de Emociones          38
#
#         duration  explicit                      artists  \
# 8       00:05:10         0                [Greg Fieler]
# 46      00:04:46         0            [Grandcubby Trio]
# 51      00:01:51         0                [Jim Chapman]
# 112     00:01:44         0                        [Uli]
# 131     00:02:52         0                        [Uli]
# ...          ...       ...                          ...
# 586664  00:03:25         0                [Boon Hui Lu]
# 586666  00:01:46         0                [Emilie Chin]
# 586668  00:02:33         0                 [ROLE MODEL]
# 586670  00:02:22         0  [Gentle Bones, Clara Benin]
# 586671  00:03:34         0                  [Afrosound]
#
#                                               id_artists  release_year  \
# 8                               [5nWlsH5RDgFuRAiDeOFVmf]          1922
# 46                              [4XVZpokXbUzg6QeomBANY9]          1922
# 51                              [0DhFxctImIYNNSEHuLQi5U]          1922
# 112                             [45tIt06XoI0Iio4LBEVpls]          1922
# 131                             [45tIt06XoI0Iio4LBEVpls]          1922
# ...                                                  ...           ...
# 586664                          [6PWJWwEm8BSBFAIAUWlwe4]          2020
# 586666                          [4USdOnfLczwUglA3TrdHs2]          2020
# 586668                          [1dy5WNgIKQU6ezkpZs4y8z]          2020
# 586670  [4jGPdu95icCKVF31CcFKbS, 5ebPSE9YI5aLeZ1Z2gkqjn]          2021
# 586671                          [0i4Qda0k4nf7jnNHmSNpYv]          2015
#
#         danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 8              0.488   0.475    0   -16.222     0       0.0399         0.620
# 46             0.382   0.750   10   -11.599     1       0.0742         0.123
# 51             0.491   0.439    4   -11.356     0       0.1050         0.626
# 112            0.644   0.684    7    -8.247     1       0.1990         0.144
# 131            0.651   0.574   10   -11.999     0       0.1040         0.474
# ...              ...     ...  ...       ...   ...          ...           ...
# 586664         0.743   0.679    8    -3.952     1       0.0323         0.269
# 586666         0.626   0.530    5   -13.117     0       0.0284         0.113
# 586668         0.765   0.663    0    -5.223     1       0.0652         0.141
# 586670         0.696   0.615   10    -6.212     1       0.0345         0.206
# 586671         0.686   0.723    6    -7.067     1       0.0363         0.105
#
#         instrumentalness  liveness  valence    tempo  time_signature
# 8               0.006450    0.1070    0.544  139.952               4
# 46              0.751000    0.7250    0.346  149.787               3
# 51              0.000000    0.3210    0.792  180.653               4
# 112             0.802000    0.0847    0.138  100.031               4
# 131             0.713000    0.0597    0.412   99.878               4
# ...                  ...       ...      ...      ...             ...
# 586664          0.000000    0.1330    0.395  126.070               4
# 586666          0.856000    0.1040    0.215  120.113               4
# 586668          0.000297    0.0924    0.686  150.091               4
# 586670          0.000003    0.3050    0.438   90.029               4
# 586671          0.000000    0.2640    0.975  112.204               4
#
# [351101 rows x 20 columns]

# %% [markdown]
# # - track time_signature : compasso geral da faixa

# %% [markdown]
# *   Convenção que especifica quantas batidas existem no compasso geral da faixa
# *   Não foi encontrada indicação de qual compasso indica cada valor (0, 1, 2, 3, 4 ou 5) do dataset do Spotify
# *   Temos, porém, a indicação que o compasso 4/4 ou C é o mais amplamente utilizado na maioria das músicas ocidentais (WIKIPEDIA, Time Signature). Observando os dados, *supomos* que ele se refira ao valor '4' no dataset
# *   Para os demais, não foi encontrada fonte que possa identificá-los

# %% [markdown]
# ![time signature.png](data:image/png;base64,...)

# %%
df_tracks['time_signature'].value_counts()
# Out:
# 4    323912
# 3     23157
# 5      2441
# 1      1471
# 0       120
# Name: time_signature, dtype: int64

# %% [markdown]
# ANÁLISE DE *TIME SIGNATURE* DE ACORDO COM A PASSAGEM DAS DÉCADAS

# %%
time_signature_by_decades = pd.DataFrame(index=range(len(df_tracks)))

# %%
for years, df in tracks_by_decades.items():
  time_signature_by_decades[years] = df['time_signature']

# %%
fig, axs = plt.subplots(4, 3, figsize=(14, 13))
plt.subplots_adjust(hspace=0.5)
ax = axs.ravel()

fig.text(0.5, 0.03, 'Valores atributo TIME SIGNATURE', ha='center', fontsize=13)

i = 0
for years, df in time_signature_by_decades.items():
  df.hist(bins=range(7), ax=ax[i]).set_title(years, y=1.08)
  i += 1

fig.delaxes(axs[3][2])
plt.show()

# %% [markdown]
# ANÁLISE DE KEY DAS FAIXAS, DE ACORDO COM O GÊNERO

# %%
time_signature_by_genres = df_merged.groupby('genre').time_signature.value_counts().sort_values()

# %% [markdown]
# Gêneros com menores agrupamentos de *time signature*

# %%
time_signature_by_genres.head(30)
# Out:
# genre                        time_signature
# 21st century classical       1                 1
# indie r&b                    1                 1
#                              5                 1
# indie rock italiano          5                 1
# indie rock mexicano          5                 1
# indie rock peruano           3                 1
# indie rockism                4                 1
# indie siciliano              3                 1
# indie triste                 3                 1
# indiecoustica                1                 1
#                              5                 1
# indietronica                 1                 1
# indonesian alternative rock  1                 1
# indonesian bamboo            3                 1
# indonesian city pop          5                 1
# indonesian death metal       3                 1
# indonesian deathcore         3                 1
# indonesian emo rap           4                 1
# indonesian experimental      4                 1
# indonesian idol pop          5                 1
# indonesian indie             1                 1
# indonesian indie rock        1                 1
# indonesian indigenous        4                 1
# indonesian r&b               3                 1
# indie quebecois              5                 1
# indonesian shoegaze          4                 1
# indie psych-pop              4                 1
# indie pop rock               4                 1
# impressionism                1                 1
#                              5                 1
# Name: time_signature, dtype: int64

# %% [markdown]
# Gêneros com maiores agrupamentos de *time signature*

# %%
time_signature_by_genres.tail(30)
# Out:
# genre               time_signature
# psychedelic rock    4                  5090
# new wave pop        4                  5170
# brill building pop  4                  5239
# mpb                 4                  5317
# latin alternative   4                  5484
# latin rock          4                  5633
# modern bollywood    4                  5715
# c-pop               4                  6201
# sufi                4                  6262
# j-pop               4                  6361
# soul                4                  6454
# desi pop            4                  7049
# pop                 4                  7098
# country rock        4                  7202
# rock en espanol     4                  7322
# art rock            4                  7473
# hard rock           4                  7485
# latin pop           4                  7698
# dance pop           4                  7789
# tropical            4                  8684
# folk rock           4                  8826
# adult standards     4                  9264
# soft rock           4                 10271
# album rock          4                 10427
# filmi               4                 11127
# mellow gold         4                 11222
# latin               4                 11943
# classic rock        4                 13090
# rock                4                 18101
# not specified       4                 34984
# Name: time_signature, dtype: int64

# %% [markdown]
# **Conclusões:**
#
# 1.   O tipo 4 de *time signature* foi o mais comum, independente de divisão por gêneros, ou décadas
# 2.   Em relação à divisão pro gêneros, os agrupamentos se devem mais ao fato da quantidade de faixas no dataset p/ cada gênero em si, do que devido ao atributo *time signature* em si

# %% [markdown]
# # DataFrame **RelatedArtists**

# %%
related_artists
# Out:
#                      id_artist                       0  \
# 0       0DheY5irMjBUeLybbCUEZ2                    None
# 1       0DlhY15l3wsrnlfGio2bjU                    None
# 2       0DmRESX2JknGPQyO15yxg7                    None
# 3       0DmhnbHjm1qw6NCYPeZNgJ                    None
# 4       0Dn11fWM7vHQ3rinvWEl4E                    None
# ...                        ...                     ...
# 527363  1qDkZo6EZO7prhbTyh0kjE                    None
# 527364  52E1p1CjGZPzI8qdbIodGs  5BPsbp0hZTomLFlVTgdbuj
# 527365  0yfrJ4JXXcChkrcFr5l8nN  70xqsSaFzoHsDjzaQnjvTW
# 527366  6HvBQpMiWSkISfHF39vqXV                    None
# 527367  0jm2LG0drmDo48H3glziUD  0qtCZoFConPbcPfkwtqpx6
#
#                              1                       2  \
# 0                         None                    None
# 1                         None                    None
# 2                         None                    None
# 3                         None                    None
# 4                         None                    None
# ...                        ...                     ...
# 527363                    None                    None
# 527364  0qtCZoFConPbcPfkwtqpx6  0g3fnSe3212EM0H45zVQvr
# 527365  02rbtsxmzmlWKtEZ4DLZr8  5BPsbp0hZTomLFlVTgdbuj
# 527366                    None                    None
# 527367  1q9C5XlekzXbRLIuLCDTre  6ejhJjv5gHGP3QwsY0bhL8
#
#                              3                       4  \
# 0                         None                    None
# 1                         None                    None
# 2                         None                    None
# 3                         None                    None
# 4                         None                    None
# ...                        ...                     ...
# 527363                    None                    None
# 527364  6IllWwuEZXv8D8Z3zq41Uu  3UqGUvLLvbbxxpg2GUTwnL
# 527365  0g3fnSe3212EM0H45zVQvr  5E1U3plwlms90a9BBgVijN
# 527366                    None                    None
# 527367  2s6wQuBYgYcwwvqdQrPEkk  4fh2BIKYPFvXFsQLhaeVJp
#
#                              5                       6  \
# 0                         None                    None
# 1                         None                    None
# 2                         None                    None
# 3                         None                    None
# 4                         None                    None
# ...                        ...                     ...
# 527363                    None                    None
# 527364  7vhukwVHbJwCHgzaobUlXG  0jm2LG0drmDo48H3glziUD
# 527365  0qtCZoFConPbcPfkwtqpx6  6IllWwuEZXv8D8Z3zq41Uu
# 527366                    None                    None
# 527367  4JB4wwtwiQsFgnPjqkcfD1  6IllWwuEZXv8D8Z3zq41Uu
#
#                              7                       8  ...  \
# 0                         None                    None  ...
# 1                         None                    None  ...
# 2                         None                    None  ...
# 3                         None                    None  ...
# 4                         None                    None  ...
# ...                        ...                     ...  ...
# 527363                    None                    None  ...
# 527364  6ejhJjv5gHGP3QwsY0bhL8  1qDkZo6EZO7prhbTyh0kjE  ...
# 527365  4LFolM6aCwLIqzOS0soUp4  3UqGUvLLvbbxxpg2GUTwnL  ...
# 527366                    None                    None  ...
# 527367  0E6jksQQ3B9JbhkWQsgz8M  0Pj3uVv8Xe7WWQO8QEnBlv  ...
#
#                             10                      11  \
# 0                         None                    None
# 1                         None                    None
# 2                         None                    None
# 3                         None                    None
# 4                         None                    None
# ...                        ...                     ...
# 527363                    None                    None
# 527364  0tD28H4LMua0acGEN1Bytg  0vtvMFEVjyZUkjZZjUN8Pw
# 527365  1qDkZo6EZO7prhbTyh0kjE  103XEYtNA5jJRI49x3USJI
# 527366                    None                    None
# 527367  0g3fnSe3212EM0H45zVQvr  3UqGUvLLvbbxxpg2GUTwnL
#
#                             12                      13  \
# 0                         None                    None
# 1                         None                    None
# 2                         None                    None
# 3                         None                    None
# 4                         None                    None
# ...                        ...                     ...
# 527363                    None                    None
# 527364  114rf5BAHSpTOuHiHJ8AoH  2rjjDkYiXzWfGDwhkgtCwu
# 527365  3VLXw7Phdo2mLlUoB5B59j  6n6VmhZHlbwcyxAMTHkfff
# 527366                    None                    None
# 527367  5BPsbp0hZTomLFlVTgdbuj  7akMsd2vb4xowNTehv3gsY
#
#                             14                      15  \
# 0                         None                    None
# 1                         None                    None
# 2                         None                    None
# 3                         None                    None
# 4                         None                    None
# ...                        ...                     ...
# 527363                    None                    None
# 527364  3cMoJnLJinh3xdO6OHuwE6  3qhVkLrZo0YV8HJKbVdCwC
# 527365  5J2sUIAE7PJNuPy6tbfGFF  2UmX87M1XsXn3p3mcabGN0
# 527366                    None                    None
# 527367  6n6VmhZHlbwcyxAMTHkfff  35m7AJrUCtHYHyIUhCzmgi
#
#                             16                      17  \
# 0                         None                    None
# 1                         None                    None
# 2                         None                    None
# 3                         None                    None
# 4                         None                    None
# ...                        ...                     ...
# 527363                    None                    None
# 527364  3P3ctFURUm4yNRZeuvJzpv  3QqzpemmnuEXaCJo3MkPwq
# 527365  2zBogoEKvaZ8PoBASHBvzZ  6ejhJjv5gHGP3QwsY0bhL8
# 527366                    None                    None
# 527367  2wP4tvQDBAX7REsAvJ29ch  0NXsB0AJL1EezoivKemnvn
#
#                             18                      19
# 0                         None                    None
# 1                         None                    None
# 2                         None                    None
# 3                         None                    None
# 4                         None                    None
# ...                        ...                     ...
# 527363                    None                    None
# 527364  4pWwoZtFdq4zPfyCMH10xs  4Rc8pP91qbI45rw3fLCeq5
# 527365  5iJ2SjQmyUNo68vLqqniAo  14UrUpszFj0N97hpFk7jyo
# 527366                    None                    None
# 527367  05yjEK9Tpu6X6pwCae00nO  723ZQOt6itOVoTEx3VXUeP
#
# [527368 rows x 21 columns]

# %% [markdown]
# *   Vamos excluir os registros que não contenham Artistas Relacionados, isto é, aqueles que contém desde a primeira coluna nula

# %%
related_artists = related_artists[related_artists[0].notnull()]

# %%
related_artists.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 405709 entries, 14 to 527367
# Data columns (total 21 columns):
#  #   Column     Non-Null Count   Dtype
# ---  ------     --------------   -----
#  0   id_artist  405709 non-null  object
#  1   0          405709 non-null  object
#  2   1          405436 non-null  object
#  3   2          405199 non-null  object
#  4   3          405001 non-null  object
#  5   4          404820 non-null  object
#  6   5          404654 non-null  object
#  7   6          404483 non-null  object
#  8   7          404296 non-null  object
#  9   8          404107 non-null  object
#  10  9          403854 non-null  object
#  11  10         403023 non-null  object
#  12  11         402279 non-null  object
#  13  12         401520 non-null  object
#  14  13         400865 non-null  object
#  15  14         400211 non-null  object
#  16  15         399594 non-null  object
#  17  16         398963 non-null  object
#  18  17         398350 non-null  object
#  19  18         397757 non-null  object
#  20  19         397164 non-null  object
# dtypes: object(21)
# memory usage: 68.1+ MB

# %% [markdown]
# # Feature Engineering - Textual Features

# %% [markdown]
# *   Para cada um dos artistas, vamos unir suas informações de gêneros, juntamente com os gêneros de todos seus artistas relacionados

# %%
def collect_genres(artist):
  result = []
  if artist['genres'] != ['not specified'] : result.extend(artist['genres'])

  return result

# %%
df_artists['related_genres_tags'] = df_artists.apply(collect_genres, axis=1)

# %%
df_artists
# Out:
#                              id  followers               genres  \
# 0        0DheY5irMjBUeLybbCUEZ2          0      [not specified]
# 1        0DlhY15l3wsrnlfGio2bjU          5      [not specified]
# 2        0DmRESX2JknGPQyO15yxg7          0      [not specified]
# 3        0DmhnbHjm1qw6NCYPeZNgJ          0      [not specified]
# 4        0Dn11fWM7vHQ3rinvWEl4E          2      [not specified]
# ...                         ...        ...                  ...
# 1104344  6rJIG42vcWAf1UBdRFlQxB       3345      [not specified]
# 1104345  1ljurfXKPlGncNdW3J8zJ8       2123  [deep acoustic pop]
# 1104346  2vnT9YhKIvjVo9LnVjWmr2         26      [not specified]
# 1104347  3ID0E5XCvnJIYZEq043ZoB        406      [not specified]
# 1104348  5m0Y4WSYyai2BU752lCASy        146      [not specified]
#
#                                                    name  popularity  \
# 0        Armid & Amir Zare Pashai feat. Sara Rouzbehani           0
# 1                                           ปูนา ภาวิณี           0
# 2                                                 Sadaa           0
# 3                                             Tra'gruda           0
# 4                                Ioannis Panoutsopoulos           0
# ...                                                 ...         ...
# 1104344                                      Cody Longo           8
# 1104345                                 Right the Stars          18
# 1104346                                  Jesse Giddings           0
# 1104347                            The Boy Band Project           0
# 1104348                                      10 Reasons           1
#
#          related_genres_tags
# 0                         []
# 1                         []
# 2                         []
# 3                         []
# 4                         []
# ...                      ...
# 1104344                   []
# 1104345  [deep acoustic pop]
# 1104346                   []
# 1104347                   []
# 1104348                   []
#
# [1104349 rows x 6 columns]

# %% [markdown]
# Agora vamos organizar o Dataframe **RelatedArtists**, para buscarmos todas as informações dos artistas relacionados e integrá-las. Para isso, vamos:
#
# 1.   Criar uma copia do *df_artists* que possua o id_artist como index (para melhor busca e otimização do tempo de execução)
# 2.   Segregar a lista de RelatedArtists entre o artista principal e seus relacionados
# 3.   Coletar os dados de gêneros dos artistas relacionados
# 4.   Transferir o resultado acima para os respectivos artistas

# %% [markdown]
# PREPARAÇÃO DOS DATASETS

# %%
df_artists_indexed = df_artists.set_index('id').rename(columns={'related_genres_tags' : 'tags'})

original_arts = related_artists['id_artist']
rltd_arts = related_artists.drop(['id_artist'], axis=1)

# %% [markdown]
# COLETA E INTEGRAÇÃO DE DADOS DOS ARTISTAS RELACIONADOS

# %%
def concatenate_tags(id_artist, data = data):

	return data.at[id_artist, 'tags'] if id_artist in data.index else ['']

# %%
rltd_infos = rltd_arts.applymap(lambda x: concatenate_tags(x, data = df_artists_indexed))

# %%
rltd_infos
# Out:
#                                                  0  \
# 14                                              []
# 44                                              []
# 45                                [carnaval cadiz]
# 46                                [carnaval cadiz]
# 47                                [carnaval cadiz]
# ...                                            ...
# 527359  [metallic hardcore, pennsylvania hardcore]
# 527362                                          []
# 527364                                          []
# 527365              [australian singer-songwriter]
# 527367                                          []
#
#                                                 1  \
# 14                                             []
# 44                                             []
# 45                               [carnaval cadiz]
# 46                               [carnaval cadiz]
# 47                               [carnaval cadiz]
# ...                                           ...
# 527359           [emoviolence, metallic hardcore]
# 527362                                         []
# 527364                                         []
# 527365  [australian indie, australian indie folk]
# 527367               [social media pop, teen pop]
#
#                                                   2  \
# 14                                   [spanish rock]
# 44                    [italian disco, new wave pop]
# 45                                 [carnaval cadiz]
# 46                                 [carnaval cadiz]
# 47                                 [carnaval cadiz]
# ...                                             ...
# 527359  [nz hardcore, nz punk, vegan straight edge]
# 527362                                           []
# 527364                                           []
# 527365                                           []
# 527367                                           []
#
#                                                         3  \
# 14                                         [spanish rock]
# 44                                        [italian disco]
# 45                                       [carnaval cadiz]
# 46                                       [carnaval cadiz]
# 47                                       [carnaval cadiz]
# ...                                                   ...
# 527359  [chaotic hardcore, post-doom metal, screamo, s...
# 527362                                                 []
# 527364                                                 []
# 527365                                                 []
# 527367                                                 []
#
#                                                         4  \
# 14                                         [spanish rock]
# 44                                                     []
# 45                                       [carnaval cadiz]
# 46                                       [carnaval cadiz]
# 47                                       [carnaval cadiz]
# ...                                                   ...
# 527359  [australian post-hardcore, metallic hardcore, ...
# 527362                                                 []
# 527364                                                 []
# 527365                                                 []
# 527367                                         [la indie]
#
#                                                   5  \
# 14                                   [spanish rock]
# 44                                               []
# 45                                 [carnaval cadiz]
# 46                                 [carnaval cadiz]
# 47                                 [carnaval cadiz]
# ...                                             ...
# 527359  [long island punk, metallic hardcore, nyhc]
# 527362                                           []
# 527364                                           []
# 527365                                           []
# 527367                                           []
#
#                                                     6                       7  \
# 14                                                 []                      []
# 44                                        [soft rock]  [swedish melodic rock]
# 45                                   [carnaval cadiz]        [carnaval cadiz]
# 46                                   [carnaval cadiz]        [carnaval cadiz]
# 47                                   [carnaval cadiz]        [carnaval cadiz]
# ...                                               ...                     ...
# 527359  [australian post-hardcore, metallic hardcore]  [australian metalcore]
# 527362                                             []                      []
# 527364                                             []                      []
# 527365                                             []                      []
# 527367                                             []                      []
#
#                                                  8  \
# 14                                              []
# 44                                 [italian disco]
# 45                                [carnaval cadiz]
# 46                                [carnaval cadiz]
# 47                                [carnaval cadiz]
# ...                                            ...
# 527359  [metallic hardcore, progressive deathcore]
# 527362                                          []
# 527364                                          []
# 527365                                          []
# 527367                                          []
#
#                                             9  \
# 14                                         []
# 44                            [italian disco]
# 45                           [carnaval cadiz]
# 46                           [carnaval cadiz]
# 47                           [carnaval cadiz]
# ...                                       ...
# 527359                     [mathcore, skramz]
# 527362  [alternative pop rock, neon pop punk]
# 527364                                     []
# 527365                                     []
# 527367                                     []
#
#                                                        10  \
# 14                                                     []
# 44                                                     []
# 45                                       [carnaval cadiz]
# 46                                       [carnaval cadiz]
# 47                                       [carnaval cadiz]
# ...                                                   ...
# 527359                                                 []
# 527362  [alternative pop rock, neon pop punk, pixie, p...
# 527364                                                 []
# 527365                                                 []
# 527367                                                 []
#
#                            11  \
# 14                         []
# 44                         []
# 45           [carnaval cadiz]
# 46           [carnaval cadiz]
# 47           [carnaval cadiz]
# ...                       ...
# 527359  [australian hardcore]
# 527362                     []
# 527364                     []
# 527365                     []
# 527367                     []
#
#                                                        12  \
# 14                                                     []
# 44                                                     []
# 45                                       [carnaval cadiz]
# 46                                       [carnaval cadiz]
# 47                                       [carnaval cadiz]
# ...                                                   ...
# 527359                              [australian hardcore]
# 527362                                                 []
# 527364                                                 []
# 527365  [australian indie folk, australian pop, indie ...
# 527367                                                 []
#
#                                                        13  \
# 14                                                     []
# 44                                         [new wave pop]
# 45                                       [carnaval cadiz]
# 46                                       [carnaval cadiz]
# 47                                       [carnaval cadiz]
# ...                                                   ...
# 527359                      [mathcore, metallic hardcore]
# 527362  [alternative pop rock, neon pop punk, pop emo,...
# 527364                                                 []
# 527365                                                 []
# 527367                                    [indie rockism]
#
#                                                   14                      15  \
# 14                                                []          [spanish rock]
# 44                                                []                      []
# 45                                  [carnaval cadiz]        [carnaval cadiz]
# 46                                  [carnaval cadiz]        [carnaval cadiz]
# 47                                  [carnaval cadiz]        [carnaval cadiz]
# ...                                              ...                     ...
# 527359  [australian post-hardcore, melodic hardcore]  [australian metalcore]
# 527362                                            []                      []
# 527364                                            []                      []
# 527365                                            []                      []
# 527367                                            []         [indie rockism]
#
#                          16  \
# 14      [spanish folk rock]
# 44                       []
# 45         [carnaval cadiz]
# 46         [carnaval cadiz]
# 47         [carnaval cadiz]
# ...                     ...
# 527359            [emo rap]
# 527362                   []
# 527364                   []
# 527365                   []
# 527367                   []
#
#                                                        17  \
# 14                                         [spanish rock]
# 44                                                     []
# 45                                       [carnaval cadiz]
# 46                                       [carnaval cadiz]
# 47                                       [carnaval cadiz]
# ...                                                   ...
# 527359            [australian hardcore, melodic hardcore]
# 527362  [alternative pop rock, neon pop punk, pixie, p...
# 527364                                                 []
# 527365                                                 []
# 527367                                                 []
#
#                                    18  \
# 14                     [spanish rock]
# 44                                 []
# 45                   [carnaval cadiz]
# 46                   [carnaval cadiz]
# 47                   [carnaval cadiz]
# ...                               ...
# 527359  [mathcore, metallic hardcore]
# 527362                             []
# 527364                             []
# 527365                             []
# 527367                             []
#
#                                                        19
# 14      [murcia indie, spanish modern rock, spanish rock]
# 44      [classic italian pop, europop, italian adult p...
# 45                                       [carnaval cadiz]
# 46                                       [carnaval cadiz]
# 47                                       [carnaval cadiz]
# ...                                                   ...
# 527359                         [australian post-hardcore]
# 527362  [alternative pop rock, neon pop punk, pixie, p...
# 527364                                                 []
# 527365                                                 []
# 527367                                                 []
#
# [405709 rows x 20 columns]

# %%
related = rltd_infos[0] + rltd_infos[1] + rltd_infos[2] + rltd_infos[3] + rltd_infos[4] + rltd_infos[5] + rltd_infos[6] + rltd_infos[7] + rltd_infos[8] + rltd_infos[9] + rltd_infos[10] + rltd_infos[11] + rltd_infos[12] + rltd_infos[13] + rltd_infos[14] + rltd_infos[15] + rltd_infos[16] + rltd_infos[17] + rltd_infos[18] + rltd_infos[19]

# %%
related_informations = pd.DataFrame(data = {'artist' : original_arts, 'tags' : related}).set_index('artist')

# %%
related_informations
# Out:
#                                                                      tags
# artist
# 0DvvojCMIqsOT1Btiwvq1h  [spanish rock, spanish rock, spanish rock, spa...
# 6S3nAGEmdt4nhPrtBJ56Ga  [italian disco, new wave pop, italian disco, s...
# 0VLMVnVbJyJ4oyZs2L3Yl2  [carnaval cadiz, carnaval cadiz, carnaval cadi...
# 0dt23bs4w8zx154C5xdVyl  [carnaval cadiz, carnaval cadiz, carnaval cadi...
# 0pGhoB99qpEJEsBQxgaskQ  [carnaval cadiz, carnaval cadiz, carnaval cadi...
# ...                                                                   ...
# 3LeJRcb6dmaemRpbnNXjeO  [metallic hardcore, pennsylvania hardcore, emo...
# 587OTrMEOVrnWxnNMAVQlJ  [alternative pop rock, neon pop punk, alternat...
# 52E1p1CjGZPzI8qdbIodGs                                                 []
# 0yfrJ4JXXcChkrcFr5l8nN  [australian singer-songwriter, australian indi...
# 0jm2LG0drmDo48H3glziUD  [social media pop, teen pop, la indie, indie r...
#
# [405709 rows x 1 columns]

# %%
df_artists['related_genres_tags'] = df_artists['related_genres_tags'] + df_artists['id'].apply(lambda x : concatenate_tags(x, data = related_informations))

# Atualiza o df_artists_indexed, para replicar a nova concatenação
df_artists_indexed = df_artists.set_index('id').rename(columns={'related_genres_tags' : 'tags'})

# %%
df_artists
# Out:
#                              id  followers               genres  \
# 0        0DheY5irMjBUeLybbCUEZ2          0      [not specified]
# 1        0DlhY15l3wsrnlfGio2bjU          5      [not specified]
# 2        0DmRESX2JknGPQyO15yxg7          0      [not specified]
# 3        0DmhnbHjm1qw6NCYPeZNgJ          0      [not specified]
# 4        0Dn11fWM7vHQ3rinvWEl4E          2      [not specified]
# ...                         ...        ...                  ...
# 1104344  6rJIG42vcWAf1UBdRFlQxB       3345      [not specified]
# 1104345  1ljurfXKPlGncNdW3J8zJ8       2123  [deep acoustic pop]
# 1104346  2vnT9YhKIvjVo9LnVjWmr2         26      [not specified]
# 1104347  3ID0E5XCvnJIYZEq043ZoB        406      [not specified]
# 1104348  5m0Y4WSYyai2BU752lCASy        146      [not specified]
#
#                                                    name  popularity  \
# 0        Armid & Amir Zare Pashai feat. Sara Rouzbehani           0
# 1                                           ปูนา ภาวิณี           0
# 2                                                 Sadaa           0
# 3                                             Tra'gruda           0
# 4                                Ioannis Panoutsopoulos           0
# ...                                                 ...         ...
# 1104344                                      Cody Longo           8
# 1104345                                 Right the Stars          18
# 1104346                                  Jesse Giddings           0
# 1104347                            The Boy Band Project           0
# 1104348                                      10 Reasons           1
#
#            related_genres_tags
# 0                           []
# 1                           []
# 2                           []
# 3                           []
# 4                           []
# ...                        ...
# 1104344                     []
# 1104345  [deep acoustic pop, ]
# 1104346                     []
# 1104347                     []
# 1104348                     []
#
# [1104349 rows x 6 columns]

# %% [markdown]
# INTEGRAÇÃO DAS *TAGS* DE FAIXAS

# %% [markdown]
# *   Este comando (atualmente desabilitado) serve pra juntar todos os gêneros dos artistas p/ cada faixa
# *   Para reabailitá-lo, basta 'descomentar' a chamada *apply* abaixo

# %%
def tracks_tags_composer(track_artists):
  result = []

  for id in track_artists:
    result.extend(concatenate_tags(id, data = df_artists_indexed))

  return result

# %%
#df_tracks['textual_tags'] = df_tracks['id_artists'].apply(lambda x : tracks_tags_composer(x))

# %% [markdown]
# ORGANIZAÇÃO DAS *TAGS* GERADAS

# %%
def organize_tags(artist):
  tags = []

  # Marca com letra maíuscula todas as tags e retira todos os espaços entre as palavras
  # Descarta as tags nulas, isto é, aquelas sem conteúdo 
  for tag in artist['related_genres_tags']:
    if tag != "" : tags.append(tag.title().replace(" ", ""))

  # Descarta tags repetidas para um mesmo artista
  tags = list(dict.fromkeys(tags))

  # Converte a lista de tags numa string única, para ser usada na criação do modelo mais adiante
  tags = ' '.join([str(tg) for tg in tags])

  return tags

# %%
df_artists['related_genres_tags'] = df_artists.apply(organize_tags, axis=1)

# %%
df_artists['related_genres_tags']
# Out:
# 0
# 1
# 2
# 3
# 4
#                 ...
# 1104344
# 1104345    DeepAcousticPop
# 1104346
# 1104347
# 1104348
# Name: related_genres_tags, Length: 1104349, dtype: object

# %%
df_artists_resulted = df_artists.copy()

# %%
df_artists_resulted.to_csv('df_artists_resulted.csv', index=False)

# %% [markdown]
# # Feature Engineering - Numerical Features

# %% [markdown]
# *   Para fins de uso no modelo de Machine Learning, todos os *Features* Numéricos serão convertidos para uma mesma escala
# *   Tal escala vai de 0 até 1

# %%
df_tracks
# Out:
#                             id                          name  popularity  \
# 8       0IgI1UCz84pYeVetnl1lGP            Old Fashioned Girl           0
# 46      1l1Wk0nOkuMCzioN6l2yfJ            Carol of the Bells           0
# 51      1v0HtSUeQOu3ba28pvYE5y  Chicago (That Toddlin' Town)           0
# 112     598LlBn6jpEpVbLjmZPsYV                      Graphite           0
# 131     6MD9XSLD4VmVI5SFRPm6By                     Car Loans           0
# ...                        ...                           ...         ...
# 586664  1Kzjk1EyngBcP4T8x3fyqv      同行 (新加坡電視劇《愛...沒有距離》主題曲)          43
# 586666  1ZwZsVZUiyFwIHMNpI3ERt                    Skyscraper           4
# 586668  0NuWgxEp51CutD2pJoF4OM                         blind          72
# 586670  45XJsGpFTyzbzeWK8VzR8S               A Day At A Time          58
# 586671  5Ocn6dZ3BJFPWh4ylwFXtn              Mar de Emociones          38
#
#         duration  explicit                      artists  \
# 8       00:05:10         0                [Greg Fieler]
# 46      00:04:46         0            [Grandcubby Trio]
# 51      00:01:51         0                [Jim Chapman]
# 112     00:01:44         0                        [Uli]
# 131     00:02:52         0                        [Uli]
# ...          ...       ...                          ...
# 586664  00:03:25         0                [Boon Hui Lu]
# 586666  00:01:46         0                [Emilie Chin]
# 586668  00:02:33         0                 [ROLE MODEL]
# 586670  00:02:22         0  [Gentle Bones, Clara Benin]
# 586671  00:03:34         0                  [Afrosound]
#
#                                               id_artists  release_year  \
# 8                               [5nWlsH5RDgFuRAiDeOFVmf]          1922
# 46                              [4XVZpokXbUzg6QeomBANY9]          1922
# 51                              [0DhFxctImIYNNSEHuLQi5U]          1922
# 112                             [45tIt06XoI0Iio4LBEVpls]          1922
# 131                             [45tIt06XoI0Iio4LBEVpls]          1922
# ...                                                  ...           ...
# 586664                          [6PWJWwEm8BSBFAIAUWlwe4]          2020
# 586666                          [4USdOnfLczwUglA3TrdHs2]          2020
# 586668                          [1dy5WNgIKQU6ezkpZs4y8z]          2020
# 586670  [4jGPdu95icCKVF31CcFKbS, 5ebPSE9YI5aLeZ1Z2gkqjn]          2021
# 586671                          [0i4Qda0k4nf7jnNHmSNpYv]          2015
#
#         danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 8              0.488   0.475    0   -16.222     0       0.0399         0.620
# 46             0.382   0.750   10   -11.599     1       0.0742         0.123
# 51             0.491   0.439    4   -11.356     0       0.1050         0.626
# 112            0.644   0.684    7    -8.247     1       0.1990         0.144
# 131            0.651   0.574   10   -11.999     0       0.1040         0.474
# ...              ...     ...  ...       ...   ...          ...           ...
# 586664         0.743   0.679    8    -3.952     1       0.0323         0.269
# 586666         0.626   0.530    5   -13.117     0       0.0284         0.113
# 586668         0.765   0.663    0    -5.223     1       0.0652         0.141
# 586670         0.696   0.615   10    -6.212     1       0.0345         0.206
# 586671         0.686   0.723    6    -7.067     1       0.0363         0.105
#
#         instrumentalness  liveness  valence    tempo  time_signature
# 8               0.006450    0.1070    0.544  139.952               4
# 46              0.751000    0.7250    0.346  149.787               3
# 51              0.000000    0.3210    0.792  180.653               4
# 112             0.802000    0.0847    0.138  100.031               4
# 131             0.713000    0.0597    0.412   99.878               4
# ...                  ...       ...      ...      ...             ...
# 586664          0.000000    0.1330    0.395  126.070               4
# 586666          0.856000    0.1040    0.215  120.113               4
# 586668          0.000297    0.0924    0.686  150.091               4
# 586670          0.000003    0.3050    0.438   90.029               4
# 586671          0.000000    0.2640    0.975  112.204               4
#
# [351101 rows x 20 columns]

# %%
df_tracks_resulted = df_tracks.copy()

# %%
min_max_scaler = preprocessing.MinMaxScaler()

features = ['danceability', 'energy', 'key', 'loudness', 
            'mode', 'speechiness', 'acousticness', 'instrumentalness', 
            'liveness', 'valence', 'tempo', 'time_signature']

for f in features:
  df_tracks_resulted[f] = min_max_scaler.fit_transform(df_tracks[f].to_numpy().reshape(-1, 1))

# %%
df_tracks_resulted
# Out:
#                             id                          name  popularity  \
# 8       0IgI1UCz84pYeVetnl1lGP            Old Fashioned Girl           0
# 46      1l1Wk0nOkuMCzioN6l2yfJ            Carol of the Bells           0
# 51      1v0HtSUeQOu3ba28pvYE5y  Chicago (That Toddlin' Town)           0
# 112     598LlBn6jpEpVbLjmZPsYV                      Graphite           0
# 131     6MD9XSLD4VmVI5SFRPm6By                     Car Loans           0
# ...                        ...                           ...         ...
# 586664  1Kzjk1EyngBcP4T8x3fyqv      同行 (新加坡電視劇《愛...沒有距離》主題曲)          43
# 586666  1ZwZsVZUiyFwIHMNpI3ERt                    Skyscraper           4
# 586668  0NuWgxEp51CutD2pJoF4OM                         blind          72
# 586670  45XJsGpFTyzbzeWK8VzR8S               A Day At A Time          58
# 586671  5Ocn6dZ3BJFPWh4ylwFXtn              Mar de Emociones          38
#
#         duration  explicit                      artists  \
# 8       00:05:10         0                [Greg Fieler]
# 46      00:04:46         0            [Grandcubby Trio]
# 51      00:01:51         0                [Jim Chapman]
# 112     00:01:44         0                        [Uli]
# 131     00:02:52         0                        [Uli]
# ...          ...       ...                          ...
# 586664  00:03:25         0                [Boon Hui Lu]
# 586666  00:01:46         0                [Emilie Chin]
# 586668  00:02:33         0                 [ROLE MODEL]
# 586670  00:02:22         0  [Gentle Bones, Clara Benin]
# 586671  00:03:34         0                  [Afrosound]
#
#                                               id_artists  release_year  \
# 8                               [5nWlsH5RDgFuRAiDeOFVmf]          1922
# 46                              [4XVZpokXbUzg6QeomBANY9]          1922
# 51                              [0DhFxctImIYNNSEHuLQi5U]          1922
# 112                             [45tIt06XoI0Iio4LBEVpls]          1922
# 131                             [45tIt06XoI0Iio4LBEVpls]          1922
# ...                                                  ...           ...
# 586664                          [6PWJWwEm8BSBFAIAUWlwe4]          2020
# 586666                          [4USdOnfLczwUglA3TrdHs2]          2020
# 586668                          [1dy5WNgIKQU6ezkpZs4y8z]          2020
# 586670  [4jGPdu95icCKVF31CcFKbS, 5ebPSE9YI5aLeZ1Z2gkqjn]          2021
# 586671                          [0i4Qda0k4nf7jnNHmSNpYv]          2015
#
#         danceability  energy       key  loudness  mode  speechiness  \
# 8           0.492432   0.475  0.000000  0.677846   0.0     0.121277
# 46          0.385469   0.750  0.909091  0.749427   1.0     0.225532
# 51          0.495459   0.439  0.363636  0.753190   0.0     0.319149
# 112         0.649849   0.684  0.636364  0.801329   1.0     0.604863
# 131         0.656912   0.574  0.909091  0.743234   0.0     0.316109
# ...              ...     ...       ...       ...   ...          ...
# 586664      0.749748   0.679  0.727273  0.867831   1.0     0.098176
# 586666      0.631685   0.530  0.454545  0.725923   0.0     0.086322
# 586668      0.771948   0.663  0.000000  0.848151   1.0     0.198176
# 586670      0.702321   0.615  0.909091  0.832838   1.0     0.104863
# 586671      0.692230   0.723  0.545455  0.819599   1.0     0.110334
#
#         acousticness  instrumentalness  liveness  valence     tempo  \
# 8           0.792839          0.006450    0.1070    0.544  0.568031
# 46          0.157289          0.751000    0.7250    0.346  0.607949
# 51          0.800512          0.000000    0.3210    0.792  0.733226
# 112         0.184143          0.802000    0.0847    0.138  0.406001
# 131         0.606138          0.713000    0.0597    0.412  0.405380
# ...              ...               ...       ...      ...       ...
# 586664      0.343990          0.000000    0.1330    0.395  0.511687
# 586666      0.144501          0.856000    0.1040    0.215  0.487509
# 586668      0.180307          0.000297    0.0924    0.686  0.609183
# 586670      0.263427          0.000003    0.3050    0.438  0.365406
# 586671      0.134271          0.000000    0.2640    0.975  0.455408
#
#         time_signature
# 8                  0.8
# 46                 0.6
# 51                 0.8
# 112                0.8
# 131                0.8
# ...                ...
# 586664             0.8
# 586666             0.8
# 586668             0.8
# 586670             0.8
# 586671             0.8
#
# [351101 rows x 20 columns]

# %%
df_tracks_resulted.to_csv('df_tracks_resulted.csv', index=False)
